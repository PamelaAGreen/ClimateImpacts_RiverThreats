# %% [markdown]
# # Climate Impacts on Water Security Threats and Green/Gray Infrastructure Threat Reduction Capacity
#
#
# ***
# <font color=red>Title: Climate Impacts on Water Security Threats and Green/Gray Infrastructure Threat Reduction Capacity
# Author: Pamela A. Green
# Date: February 13, 2023
#
# This code has been modified from original code developed between March 11 and December 31, 2022 by Pamela Green, Senior Research Associate, CUNY Advanced Science Research Center, New York, NY. Code has been updated to be generically applicable to any raster water balance model output although end user will need to ensure all raster data are in a consistent resolution and projection.  </font>
# ***
#
# The following global data for River Threats and Green/Gray Engineering Threat Rediction Capacity were downloaded from https://www.water-sustainable-infrastructure.com/index.html and downscaled to 6-minute resolution.
#
# Green-Gray water threat indicators from Vörösmarty et al 2021
# - Ti: Incident threat (for years 2000, 2030, 2050, 2080)
# - TRnat: Threat reduced by existing natural capital (for years 2000, 2030, 2050, 2080)
# - TReng: Threat reduced by engineering (for years 2000, 2030, 2050, 2080)
#
# Vörösmarty, Charles J., Ben Stewart-Koster, Pamela A. Green, Edward L. Boone, Martina Flörke, Günther Fischer, David A. Wiberg, et al. “A Green-Gray Path to Global Water Security and Sustainable Infrastructure.” Global Environmental Change 70 (September 1, 2021): 102344. https://doi.org/10.1016/j.gloenvcha.2021.102344.
#
# TerraClimate multi-decadal climate forecasts for contemporary and future climate conditions were downloaded via the TerraClimate website and downscaled to 6-minute using the Jupyter Notebook script <b><i>TerraClimate_Downscaling_Runoff+Discharge.ipynb</i></b> in the WaterBalanceModel_TimeSeries repository located at https://github.com/PamelaAGreen/WaterBalanceModel_TimeSeries.
#
# 1.	Contemporary (Runoff, Precipitation, actual Evapotranspiration, monthly totals), units = mm, years 1985-2015
# 2.	+2C Climate Futures (Precipitation, actual Evapotranspiration, monthly totals), units = mm, years 1985-2015
# 3.	+4C Climate Futures (Precipitation, actual Evapotranspiration, monthly totals), units = mm, years 1985-2015
#
# Qin, Y., Abatzoglou, J.T., Siebert, S. et al. Agricultural risks from changing snowmelt. Nat. Clim. Chang. 10, 459–465 (2020). https://doi.org/10.1038/s41558-020-0746-8.
#
# Contemporary and Future Climate:
#
# Contemporary and future Climate Variability indicators, ClimVarcontemp and ClimVarfuture, were developed using intra- and inter annual variability in available water resources from the TerraClimate multi-decadal discharge flow datasets. The ClimVarcontemp and ClimVarfuture indicators are ranked on a continuous 0-1 scale of low to high climate variability threat identifying areas most vulnerable to large shifts in water availability due to seasonality (intra-annual) and longer term (30-year inter-annual) climate patterns.
#
# Datasets produced:
# - ClimVarcontemp : Global gridded 6-min resolution climate variability indicator scores ranked 0-1 for contemporary time period
# - ClimVarfuture+2C : Global gridded 6-min resolution climate variability indicator scores ranked 0-1 for future (2080, +2C climate run) time period
# - ClimVarfuture+4C : Global gridded 6-min resolution climate variability indicator scores ranked 0-1 for future (2080, +4C climate run) time period
#
# Population and Downstream Population for contemporary and future years downloaded via CIESIN website and processed via routing algorithms using the CUNY WBM RGIS system.
#
# Contemporary Population (2020):
# - Center for International Earth Science Information Network - CIESIN - Columbia University. 2018. Gridded Population of the World, Version 4 (GPWv4): Population Density, Revision 11. Palisades, NY: NASA Socioeconomic Data and Applications Center (SEDAC).
#
# Future Population (2030, 2050, 2080):
# - Gao, J. 2020. Global 1-km Downscaled Population Base Year and Projection Grids Based on the Shared Socioeconomic Pathways, Revision 01. Palisades, New York: NASA Socioeconomic Data and Applications Center (SEDAC). https://doi.org/10.7927/q7z9-9r69. Accessed April 2022
#
# All datasets listed above have been resampled from their native formats to 6-minute resolution GeoTIFF raster format using a standard reprojection and warping utility (GDAL Warp). Reprojected climate forcing data from TerraClimate were converted to 6-minute resolution discharge flow via routing algorithms using the CUNY WBM RGIS system.
#
# Water Threat and Threat Reduction Impact Indicators:
#
# The contemporary and future Climate Variability indicators (ClimVarcontemp and ClimVarfuture) were applied to the human water security and green-gray water threat indicator from Vörösmarty et al 2021 (Ti, TRnat, TReng) to create indicators measuring the impact of climate variability on (a) human water security threat (Climate Impacted Ti),  (b) green infrastructure condition (Climate Impacted TRnat), and (c) gray infrastructure condition (Climate Impacted TReng) for contemporary and future (year 2080, +2C and +4C climate run) conditions. These indicators were ranked on a continuous 0-1 scale of low to high threats and threat reduction capacity.
#
# Datasets produced:
# - Climate Impacted Ticontemp : Global gridded 6-min resolution indicator scores measuring water security threats impacted by climate variability, ranked 0-1 for contemporary time period
# - Climate Impacted Tifuture+2C: Global gridded 6-min resolution indicator scores measuring water security threats impacted by climate variability, ranked 0-1 for future (2080, +2C climate run) time period
# - Climate Impacted Tifuture+4C: Global gridded 6-min resolution indicator scores measuring water security threats impacted by climate variability, ranked 0-1 for future (2080, +4C climate run) time period
# - Climate Impacted TRnatcontemp: Global gridded 6-min resolution indicator scores measuring threat reduction by natural capital impacted by climate variability, ranked 0-1 for contemporary time period
# - Climate Impacted TRnatfuture+2C: Global gridded 6-min resolution indicator scores measuring threat reduction by natural capital impacted by climate variability, ranked 0-1 for future (2080, +2C climate run) time period
# - Climate Impacted TRnatfuture+4C: Global gridded 6-min resolution indicator scores measuring threat reduction by natural capital impacted by climate variability, ranked 0-1 for future (2080, +4C climate run) time period
# - Climate Impacted TRengcontemp: Global gridded 6-min resolution indicator scores measuring threat reduction by engineering impacted by climate variability, ranked 0-1 for contemporary time period
# - Climate Impacted TRengfuture+2C: Global gridded 6-min resolution indicator scores measuring threat reduction by engineering impacted by climate variability, ranked 0-1 for future (2080, +2C climate run) time period
# - Climate Impacted TRengfuture+4C: Global gridded 6-min resolution indicator scores measuring threat reduction by engineering impacted by climate variability, ranked 0-1 for future (2080, +4C climate run) time period
#
# Casting Water Flow, Threats and Threat Reduction in Terms of Water Resource Areas Supporting Downstream Populations
#
# We use the contemporary and future Climate Impacted Ticontemp/future , Climate Impacted TRnatcontemp/future and Climate Impacted TRengcontemp/future described above to map population downstream of water source areas under the four climate impacts. We map the geography of population downstream of water source areas under low, moderate, and high scores for each of the indicators under contemporary and year 2080 (+2C and +4C) conditions.
#
# The following steps were carried out to develop the indicators for this analysis:
# - Aggregating Monthly Data to Annual values
# - Creating Coefficient of Variation for Annual TerraClimate Discharge
# - Creating Coefficient of Variation for Monthly TerraClimate Discharge (LTM and for each year)
# - Created CDF of Annual and Monthly CVs, Inter- and Intra- Annual variability indicators
# - Combine Inter- and Intra- Annual variability indicators into single Climate Vulnerability indicator
# - Calculate Adjusted Water Threat and Threat reduction indicators by applying Climate Vulnerability Indicator
# - Apply CDF calculation to Adjusted Water Threat and Threat Reduction indicators
# - Calculate downstream population under adjusted CV, Ti, TRnat and TReng for 2020 and future year
# - Overlay Extremely Dry and Extremely Wet Drought Analysis with results
# - Aggregate to global, continental, and administrative unit levels

# %% [markdown]
# # Modules and Functions

# %%
import numpy as np
import pandas as pd
import scipy

from scipy import stats
from scipy.stats import rankdata
from osgeo import gdal, gdal_array, osr, ogr
from osgeo.gdalconst import *
import scipy.ndimage as nd
import xarray as xr

from math import floor

# %% [markdown]
# ## Single band numpy array to GeoTiff file function

# %%
def save2File(rA, outname, nrows, ncols, geo_transform):  # Resolution for the 6min
    # create the output image
    # Note that in the geo transform the third and sixth parameters are equal to the Arc/Info generate fishnet
    # Y-coordinate paramenter (defining the rotation of the final grid)
    # LCORD
    outDs = gdal.GetDriverByName('GTiff').Create(outname, ncols, nrows, 1, gdal.GDT_Float32)
    outBand = outDs.GetRasterBand(1)
    outBand.WriteArray(rA)
    outDs.SetGeoTransform(geo_transform)
    srs = osr.SpatialReference()
    srs.ImportFromEPSG(4326)
    outDs.SetProjection(srs.ExportToWkt())
    outDs = None

    """
    geotransform[0] = top left x
    geotransform[1] = w-e pixel resolution
    geotransform[2] = 0
    geotransform[3] = top left y
    geotransform[4] = 0
    geotransform[5] = n-s pixel resolution (negative value)
    """

# %% [markdown]
# ## MultiBand numpy array to GeoTiff function

# %%
def CreateMultiGeoTiff(Array, Name, driver, NDV, GeoT, Projection, DataType):
    Array[np.isnan(Array)] = NDV
    DataSet = gdal.GetDriverByName(driver).Create(Name, Array.shape[2], Array.shape[1], Array.shape[0], DataType)
    DataSet.SetGeoTransform(GeoT)
    srs = osr.SpatialReference()
    srs.ImportFromEPSG(Projection)
    DataSet.SetProjection(srs.ExportToWkt() )
    for i, image in enumerate(Array, 1):
        DataSet.GetRasterBand(i).WriteArray( image )
        DataSet.GetRasterBand(i).SetNoDataValue(NDV)
    DataSet.FlushCache()
    return Name

# %% [markdown]
# ## Rank Cumulative Distribution Function (CDF)

# %%
def rankCDF(array):
    array[np.isnan(array)] = 0    
    rank = np.reshape((rankdata(array, method='dense') - 1), array.shape)
    rank = np.where(array == 0.000, 0.000, rank)
    cdf = rank / np.amax(rank)
    
    return cdf

# %% [markdown]
# # Global Variables, Definitions, Datasets

# %% [markdown]
# ## Define Global Directory Variables; paths on ASRC server

# %%
main = os.getcwd( ) + '/'

in_dir = str(main) + 'ModelInput/'
out_dir = str(main) + 'ModelOutput/'

TC_dir = str(in_dir) + 'TerraClimate/raw'
TC_FutClim = str(in_dir) + 'TerraClimate/ClimateFutures/'

gec_2021 = str(in_dir) + 'GEC_Vorosmarty_etal_2021/
gadm_dir = str(in_dir) + 'gadm/'
cellarea = str(in_dir) + 'cellarea/CellArea_6m.tif'

net_dir = str(in_dir) + 'RiverBasin/'

pop_dir = str(in_dir) + 'population/'
ssp_pop_dir = str(pop_dir) + 'ciesin_popdynamics/'
gwp4_pop_dir = str(pop_dir) + 'gpw4/'
dwn_pop_dir = str(pop_dir) + 'dwnpop/'

# %% [markdown]
# ## Set Future Year variable for analysis
#
# This refers to the year chosen for future threat and population runs. Vorosmarty et al, 2021 provides future river threat estimates for 2030, 2050, and 2080. Scaled population for these years are also imported.

# %%
#year_fut = 2030
#year_fut = 2050
year_fut = 2080

# %% [markdown]
# ## Read in River Basin and Subbasin, Cellarea, and GADM Continent grids at 6min resolution

# %%
n = 300
fin = str(net_dir) + 'HydroSTN06_Subbasin.tif'
ds = gdal.Open(str(fin))
subbas = np.array(ds.GetRasterBand(1).ReadAsArray())

del ds

fin = str(net_dir) + 'Global_Basin_HydroSTN30_06min_GHAAS3.tif'
ds = gdal.Open(str(fin))
basin = np.array(ds.GetRasterBand(1).ReadAsArray())
basin[np.isnan(basin)] = 0

basin_name_file = 'MajorBasinLookUp.xlsx'
pd_basin_name = pd.read_excel(net_dir + basin_name_file, sheet_name='LookupVALUES')
del pd_basin_name['BasinName']
pd_basin_name = pd_basin_name[(pd_basin_name['ID'] != 0)]

fin = str(cellarea)
ds = gdal.Open(str(fin))
CellArea6m = np.array(ds.GetRasterBand(1).ReadAsArray())
CellArea6m[np.isnan(CellArea6m)] = 0

fin = gadm_dir + 'gadm_continent.tif'
ds = gdal.Open(str(fin))
gadm_cont = np.array(ds.GetRasterBand(1).ReadAsArray())
gadm_cont[np.isnan(gadm_cont)] = 0

flowmask = TC_dir + 'UpROmask_1985-2015.tif'
fin = str(flowmask)
ds = gdal.Open(str(fin))
flow_mask = np.array(ds.GetRasterBand(1).ReadAsArray())
flow_mask[np.isnan(flow_mask)] = 0

# %% [markdown]
# ## Explicitely define projection information for 6min rasters

# %%
ncols6m = 3600
nrows6m = 1500
xll6m = -180
yll6m = -60
xur6m = 180
yur6m = 90
cellsize6m = 0.1
cellang = cellsize6m * -1
nodata = -9999
geotr6m = ([ xll6m, cellsize6m, 0, yur6m, 0, cellang ])

geodriver = 'GTiff'
geoproj = 4326

head6m = 'ncols ' + str(ncols6m) + '\nnrows ' + str(nrows6m) + '\nxllcorner ' + str(xll6m) + '\nyllcorner ' + str(yll6m) + '\ncellsize ' + str(cellsize6m) + '\nNODATA_value ' + str(nodata)

# %% [markdown]
# # Read  water balance time series data into XArrays

# %% [markdown]
# ## Establish Time Series Variables
#
# Options are to work with Discharge, Runoff (RO, mm/time period), or Runoff Volume (ROV, m3/time period)

# %%
StartYear = 1985
EndYear = 2016
size = EndYear - StartYear

#ts_var = 'ROV'
#ts_var = 'RO'
ts_var = 'Discharge'

# %% [markdown]
# ## Read in Contemporary and Future (2C,4C) TerraClimate Time Series Data from GeoTIFF files
#
# TerraClimate data was downloaded from https://www.climatologylab.org/terraclimate.html, downscaled to 6-minute resolution rasters, and flow accumulated to discharge using the scripts below:
# - Contemporary script: /asrc/ecr/pamela/TerraClimate/scripts/TerraClimate_Downscaling+Discharge_Contemp_6min.ipynb
# - Future Climate script: /asrc/ecr/pamela/TerraClimate/scripts/TerraClimate_Downscaling+Discharge_Future_6min.ipynb
#
# To be consistent with future runoff and discharge calculations, I have chosen to establish runoff as the difference between precipitation and actual evapotranspiration (PPT - AET) in lieu of using the contemporaray runoff data provided on the TerraClimate website. The runoff data provided for the contemporaray state is retained in the commented code for any future reference or comparison.
#
# Qin, Y., Abatzoglou, J.T., Siebert, S. et al. Agricultural risks from changing snowmelt. Nat. Clim. Chang. 10, 459–465 (2020). https://doi.org/10.1038/s41558-020-0746-8.![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Contemporary

# %%
print("Annual")
#filepath = TC_dir + 'raw/TerraClimate_' + str(ts_var) + '_Ann1985-2015.tif'
filepath = TC_dir + 'raw/TerraClimate_' + str(ts_var) + '_PPT-AET_Ann1985-2015.tif'
dataset = gdal.Open(filepath)
TS_Contemp_ann = dataset.ReadAsArray()

print("Monthly")
for x in range(StartYear, EndYear):
    print(str(x) + " .. ", end='')
#    filepath = TC_dir + 'raw/TerraClimate_' + str(ts_var) + '_' + str(x) + '_Monthly.tif'
    filepath = TC_dir + 'raw/TerraClimate_' + str(ts_var) + '_PPT-AET_' + str(x) + '_Monthly.tif'
    dataset = gdal.Open(filepath)
    TS_Contemp_mo = dataset.ReadAsArray()
    
    if x == StartYear:
        array_TS_Contemp_mo = TS_Contemp_mo        
    else:
        array_TS_Contemp_mo = np.concatenate(([array_TS_Contemp_mo, TS_Contemp_mo]), axis=0)

# %% [markdown]
# ## 2C

# %%
print("Annual")
filepath = TC_FutClim + '2C/TerraClimate_' + str(ts_var) + '_2C_Ann1985-2015.tif'
dataset = gdal.Open(filepath)
TS_FutClim_2C_ann = dataset.ReadAsArray()

print("Monthly")
for x in range(StartYear, EndYear):
    print(str(x) + " .. ", end='')
    filepath = TC_FutClim + '2C/TerraClimate_' + str(ts_var) + '_2C_' + str(x) + '_Monthly.tif'
    dataset = gdal.Open(filepath)
    TS_FutClim_2C_mo = dataset.ReadAsArray()
    
    if x == StartYear:
        array_TS_FutClim_2C_mo = TS_FutClim_2C_mo        
    else:
        array_TS_FutClim_2C_mo = np.concatenate(([array_TS_FutClim_2C_mo, TS_FutClim_2C_mo]), axis=0)

# %% [markdown]
# ## 4C

# %%
print("Annual")
filepath = TC_FutClim + '4C/TerraClimate_' + str(ts_var) + '_4C_Ann1985-2015.tif'
dataset = gdal.Open(filepath)
TS_FutClim_4C_ann = dataset.ReadAsArray()

print("Monthly")
for x in range(StartYear, EndYear):
    print(str(x) + " .. ", end='')
    filepath = TC_FutClim + '4C/TerraClimate_' + str(ts_var) + '_4C_' + str(x) + '_Monthly.tif'
    dataset = gdal.Open(filepath)
    TS_FutClim_4C_mo = dataset.ReadAsArray()
    
    if x == StartYear:
        array_TS_FutClim_4C_mo = TS_FutClim_4C_mo        
    else:
        array_TS_FutClim_4C_mo = np.concatenate(([array_TS_FutClim_4C_mo, TS_FutClim_4C_mo]), axis=0)

# %% [markdown]
# # Create Climate Impacted River Threats and Green/Gray Threat Reduction Capacity

# %% [markdown]
# ## Annual and Monthly Long Term Mean (LTM) CV and CDF Calculations for contemporary (1985-2015) and future (year 2080, +2C and +4C) Climate Variability indicators, ClimVar<sub>contemp</sub> , ClimVar<sub>future+2C</sub> , and ClimVar<sub>future+4C</sub>

# %%
print("Creating Xarrays..")

lon_tup = np.arange(xll6m, xur6m, cellsize6m) + (cellsize6m / 2)
lat_tup = np.arange(yll6m, yur6m, cellsize6m)
lat_tup = lat_tup[::-1] + (cellsize6m / 2)

num_yrs = EndYear - StartYear
num_mos = num_yrs * 12

start_range = str(StartYear) + "-01-01"
time = pd.date_range(start_range, freq="Y", periods=num_yrs)
time_yr = pd.date_range(start_range, freq="Y", periods=num_yrs)
time_mo = pd.date_range(start_range, freq="M", periods=num_mos)
years = time.strftime('%Y')
months12 = time_mo.to_period('M')
months = time_mo.strftime('%Y-%m')

print("Contemporary ...")
print("  Annual ")
da_TS_ann_Contemp = xr.DataArray(data=TS_Contemp_ann,
                  coords=[years, lat_tup, lon_tup],
                  dims=["date", "lat", "lon"],
                  name="TS_Contemp_ann",
                  attrs=dict(description="TC Annual ' + str(ts_var) + ' Contmemporary", units="cms",)
                  )
TS_ann_Contemp_mean = da_TS_ann_Contemp.mean(dim = "date").values
TS_ann_Contemp_std = da_TS_ann_Contemp.std(dim = "date").values
TS_ann_Contemp_cv = (da_TS_ann_Contemp.std(dim = "date") / da_TS_ann_Contemp.mean(dim = "date")).values
TS_ann_Contemp_cv_CDF = rankCDF(TS_ann_Contemp_cv)

print("  Monthly ")
da_TS_mo_Contemp = xr.DataArray(data=array_TS_Contemp_mo,
                  coords=[time_mo, lat_tup, lon_tup],
                  dims=["date", "lat", "lon"],
                  name="array_TS_Contemp_mo",
                  attrs=dict(description="TC LTM Monthly ' + str(ts_var) + ' Contemporary", units="cms",)
                  )
TS_mo_Contemp_mean = da_TS_mo_Contemp.groupby("date.month").mean()
TS_mo_Contemp_CV = stats.variation(TS_mo_Contemp_mean, axis=0)
TS_mo_Contemp_cv_CDF = rankCDF(TS_mo_Contemp_CV)

outname = out_dir + 'TerraClimate_Q_Contemp_CDF_InterAnnual.tif'
save2File(TS_ann_Contemp_cv_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TerraClimate_Q_LTM_Contemp_CDF_IntraAnnual.tif'
save2File(TS_mo_Contemp_cv_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

print("Future Climates ...")
print("  Annual ")
da_TS_ann_FutClim_2C = xr.DataArray(data=TS_FutClim_2C_ann,
                  coords=[years, lat_tup, lon_tup],
                  dims=["date", "lat", "lon"],
                  name="TS_FutClim_2C_ann",
                  attrs=dict(description="TC Annual ' + str(ts_var) + ' Future Climate", units="cms",)
                  )

da_TS_ann_FutClim_4C = xr.DataArray(data=TS_FutClim_4C_ann,
                  coords=[years, lat_tup, lon_tup],
                  dims=["date", "lat", "lon"],
                  name="TS_FutClim_4C_ann",
                  attrs=dict(description="TC Annual ' + str(ts_var) + ' Future Climate", units="cms",)
                  )

TS_ann_FutClim_2C_mean = da_TS_ann_FutClim_2C.mean(dim = "date").values
TS_ann_FutClim_2C_std = da_TS_ann_FutClim_2C.std(dim = "date").values
TS_ann_FutClim_2C_cv = (da_TS_ann_FutClim_2C.std(dim = "date") / da_TS_ann_FutClim_2C.mean(dim = "date")).values
TS_ann_FutClim_2C_cv_CDF = rankCDF(TS_ann_FutClim_2C_cv)

TS_ann_FutClim_4C_mean = da_TS_ann_FutClim_4C.mean(dim = "date").values
TS_ann_FutClim_4C_std = da_TS_ann_FutClim_4C.std(dim = "date").values
TS_ann_FutClim_4C_cv = (da_TS_ann_FutClim_4C.std(dim = "date") / da_TS_ann_FutClim_4C.mean(dim = "date")).values
TS_ann_FutClim_4C_cv_CDF = rankCDF(TS_ann_FutClim_4C_cv)

print("  Monthly ")
da_TS_mo_FutClim_2C = xr.DataArray(data=array_TS_FutClim_2C_mo,
                  coords=[time_mo, lat_tup, lon_tup],
                  dims=["date", "lat", "lon"],
                  name="array_TS_FutClim_2C_mo",
                  attrs=dict(description="TC LTM Monthly ' + str(ts_var) + ' Future Climate", units="cms",)
                  )
da_TS_mo_FutClim_4C = xr.DataArray(data=array_TS_FutClim_4C_mo,
                  coords=[time_mo, lat_tup, lon_tup],
                  dims=["date", "lat", "lon"],
                  name="array_TS_FutClim_4C_mo",
                  attrs=dict(description="TC LTM Monthly ' + str(ts_var) + ' Future Climate", units="cms",)
                  )

TS_mo_FutClim_2C_mean = da_TS_mo_FutClim_2C.groupby("date.month").mean()
TS_mo_FutClim_2C_CV = stats.variation(TS_mo_FutClim_2C_mean, axis=0)
TS_mo_FutClim_2C_cv_CDF = rankCDF(TS_mo_FutClim_2C_CV)

TS_mo_FutClim_4C_mean = da_TS_mo_FutClim_4C.groupby("date.month").mean()
TS_mo_FutClim_4C_CV = stats.variation(TS_mo_FutClim_4C_mean, axis=0)
TS_mo_FutClim_4C_cv_CDF = rankCDF(TS_mo_FutClim_4C_CV)

outname = out_dir + 'TerraClimate_Q_FutClim_2C_CDF_InterAnnual.tif'
save2File(TS_ann_FutClim_2C_cv_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TerraClimate_Q_FutClim_4C_CDF_InterAnnual.tif'
save2File(TS_ann_FutClim_4C_cv_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TerraClimate_Q_LTM_FutClim_2C_CDF_IntraAnnual.tif'
save2File(TS_mo_FutClim_2C_cv_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TerraClimate_Q_LTM_FutClim_4C_CDF_IntraAnnual.tif'
save2File(TS_mo_FutClim_4C_cv_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

print("Combining Inter- and Intra- annual statistics..")
TS_Contemp_CV_mean = (TS_mo_Contemp_cv_CDF + TS_ann_Contemp_cv_CDF) / 2
TS_Contemp_CV_CDF = rankCDF(TS_Contemp_CV_mean)

TS_FutClim_2C_CV_mean = (TS_mo_FutClim_2C_cv_CDF + TS_ann_FutClim_2C_cv_CDF) / 2
TS_FutClim_2C_CV_CDF = rankCDF(TS_FutClim_2C_CV_mean)

TS_FutClim_4C_CV_mean = (TS_mo_FutClim_4C_cv_CDF + TS_ann_FutClim_4C_cv_CDF) / 2
TS_FutClim_4C_CV_CDF = rankCDF(TS_FutClim_4C_CV_mean)

TS_Contemp_CV_CDF = np.where(flow_mask == 0, TS_Contemp_CV_CDF, 0)
TS_FutClim_2C_CV_CDF = np.where(flow_mask == 0, TS_FutClim_2C_CV_CDF, 0)
TS_FutClim_4C_CV_CDF = np.where(flow_mask == 0, TS_FutClim_4C_CV_CDF, 0)

outname = out_dir + 'TerraClimate_Q_LTM_Contemp_CDF_InterIntra.tif'
save2File(TS_Contemp_CV_CDF[ :, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TerraClimate_Q_LTM_FutClim_2C_CDF_InterIntra.tif'
save2File(TS_FutClim_2C_CV_CDF[ :, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TerraClimate_Q_LTM_FutClim_4C_CDF_InterIntra.tif'
save2File(TS_FutClim_4C_CV_CDF[ :, :], outname, nrows6m, ncols6m, geotr6m)

# %% [markdown]
# ##  Resample Ti, TRnat and TReng (Vorosmarty et al, 2021) to 6 minute from native 30 minute resolution

# %%
chglist = ['T', 'TRnat', 'TReng']
yrs = ['2005', str(year_fut)]
for x in chglist:
    for y in yrs:
        infn = gec_2021 + str(x) + '_' + str(y) + '.tif'
        outfn = gec_2021 + str(x) + '_' + str(y) + '_6m.tif'
        xres=0.1
        yres=0.1
        resample_alg = 'near'
        options = gdal.WarpOptions(options=['tr'], xRes=xres, yRes=yres, resampleAlg=resample_alg)
        ds = gdal.Warp(outfn, infn, xRes=xres, yRes=yres, resampleAlg=resample_alg)
        ds = None
        ds = gdal.Open(str(outfn))
        if x == 'Ti':
            if y == '2005':
                Ti_2005 = np.array(ds.GetRasterBand(1).ReadAsArray())
                Threat_nan = Ti_2005
                Threat_nan = np.where(Threat_nan < 0, 1, 0)
                Threat_nan[np.isnan(Threat_nan)] = 1
                Threat_nan = Threat_nan[:-n, :]
                Ti_2005[np.isnan(Ti_2005)] = 0
                Ti_2005 = Ti_2005[:-n, :]
                Ti_2005 = np.where(Ti_2005 < 0, 0.00, Ti_2005)
            if y == str(year_fut):
                Ti_year_fut = np.array(ds.GetRasterBand(1).ReadAsArray())
                Ti_year_fut[np.isnan(Ti_year_fut)] = 0
                Ti_year_fut = Ti_year_fut[:-n, :]
                Ti_year_fut = np.where(Ti_year_fut < 0, 0.00, Ti_year_fut)
        if x == 'TRnat':
            if y == '2005':
                TRnat_2005 = np.array(ds.GetRasterBand(1).ReadAsArray())
                T_temp = TRnat_2005
                T_temp[np.isnan(T_temp)] = 0
                TRnat_2005 = np.where(TRnat_2005 < 0, np.amax(TRnat_2005), TRnat_2005)
                TRnat_2005 = TRnat_2005[:-n, :]
            if y == str(year_fut):
                TRnat_year_fut = np.array(ds.GetRasterBand(1).ReadAsArray())
                T_temp = TRnat_year_fut
                T_temp[np.isnan(T_temp)] = 0
                TRnat_year_fut = np.where(TRnat_year_fut < 0, np.amax(TRnat_year_fut), TRnat_year_fut)
                TRnat_year_fut = TRnat_year_fut[:-n, :]
        if x == 'TReng':
            if y == '2005':
                TReng_2005 = np.array(ds.GetRasterBand(1).ReadAsArray())
                T_temp = TReng_2005
                T_temp[np.isnan(T_temp)] = 0
                TReng_2005 = np.where(TReng_2005 < 0, np.amax(TReng_2005), TReng_2005)
                TReng_2005 = TReng_2005[:-n, :]
            if y == str(year_fut):
                TReng_year_fut = np.array(ds.GetRasterBand(1).ReadAsArray())
                T_temp = TReng_year_fut
                T_temp[np.isnan(T_temp)] = 0
                TReng_year_fut = np.where(TReng_year_fut < 0, np.amax(TReng_year_fut), TReng_year_fut)
                TReng_year_fut = TReng_year_fut[:-n, :]

# %% [markdown]
# ## Read in Downstream Population, Local Pop scaling from 2020 to Future Year
#
# Population datasets are from CIESIN (references below) and were resampled and scaled in DownstreamPopulation_gpw4_rev11_6min.ipynb and DownstreamPopulationFutureScaled.ipynb in /asrc/ecr/pamela/population/dwnpop directory.
#
# Contemporary Population:
# - Center for International Earth Science Information Network - CIESIN - Columbia University. 2018. Gridded Population of the World, Version 4 (GPWv4): Population Density, Revision 11. Palisades, NY: NASA Socioeconomic Data and Applications Center (SEDAC).
#
# Future Population:
# - Gao, J. 2020. Global 1-km Downscaled Population Base Year and Projection Grids Based on the Shared Socioeconomic Pathways, Revision 01. Palisades, New York: NASA Socioeconomic Data and Applications Center (SEDAC). https://doi.org/10.7927/q7z9-9r69. Accessed April 2022.

# %%
fin = gwp4_pop_dir + 'gpw_v4_population_count_rev11_2020_6min.tif'
ds = gdal.Open(str(fin))
pop2020 = np.array(ds.GetRasterBand(1).ReadAsArray())
pop2020[np.isnan(pop2020)] = 0
pop2020 = pop2020[ :-n, :]
np.savetxt(gwp4_pop_dir + 'gpw_v4_population_count_rev11_2020_6min.txt', pop2020[:, :], fmt='%1.9f', delimiter='  ', header=str(head6m), comments='')

fin = ssp_pop_dir + 'ssp2_total_2020_6m.tif'
ds = gdal.Open(str(fin))
ssp2_pop_2020 = np.array(ds.GetRasterBand(1).ReadAsArray())
ssp2_pop_2020[np.isnan(ssp2_pop_2020)] = 0

fin = ssp_pop_dir + 'ssp2_total_' + str(year_fut)+ '_6m.tif'
ds = gdal.Open(str(fin))
ssp2_pop_year_fut = np.array(ds.GetRasterBand(1).ReadAsArray())
ssp2_pop_year_fut[np.isnan(ssp2_pop_year_fut)] = 0

delta_pop = ssp2_pop_year_fut - ssp2_pop_2020
scaled_pop_year_fut = pop2020 + delta_pop
scaled_pop_year_fut = np.where(scaled_pop_year_fut < 0, 0, scaled_pop_year_fut)
scaled_pop_year_fut[np.isnan(scaled_pop_year_fut)] = 0
outname = gwp4_pop_dir + 'gpw_v4_population_count_rev11_' + str(year_fut) + 'scaledBySSP2_6min.tif'
save2File(scaled_pop_year_fut[:, :], outname, nrows6m, ncols6m, geotr6m)
np.savetxt(gwp4_pop_dir + 'gpw_v4_population_count_rev11_' + str(year_fut) + 'scaledBySSP2_6min.txt', scaled_pop_year_fut[:, :], fmt='%1.9f', delimiter='  ', header=str(head6m), comments='')

fin = dwn_pop_dir + 'gpw4_dwnpop_2020_TerraClimate_aLTM1985-2015_6min.tif'
#fin = dwn_pop_dir + 'gpw4_dwnpop_SSP2_2020_TerraClimate_aLTM1985-2015_6min.tif'
ds = gdal.Open(str(fin))
dwnp_2020 = np.array(ds.GetRasterBand(1).ReadAsArray())
dwnp_2020[np.isnan(dwnp_2020)] = 0

fin = dwn_pop_dir + 'gpw4_dwnpop_' + str(year_fut) + 'scaledBySSP2_TerraClimate_aLTM1985-2015_6min.tif'
#fin = dwn_pop_dir + 'gpw4_dwnpop_SSP2_year_fut_TerraClimate_aLTM1985-2015_6min.tif'
ds = gdal.Open(str(fin))
dwnp_year_fut = np.array(ds.GetRasterBand(1).ReadAsArray())
dwnp_year_fut[np.isnan(dwnp_year_fut)] = 0

# Mask all area without River Threats - no-flowing areas from GEC 2021 analysis
dwnp_2020_nan = np.where(Threat_nan == 1, 0, dwnp_2020)
dwnp_year_fut_nan = np.where(Threat_nan == 1, 0, dwnp_year_fut)
pop_2020_nan = np.where(Threat_nan == 1, 0, pop2020)
pop_year_fut_nan = np.where(Threat_nan == 1, 0, scaled_pop_year_fut)

# Create Population Density Rasters
popden_2020 = pop2020 / CellArea6m
popden_year_fut = scaled_pop_year_fut / CellArea6m

dwnpopden_2020 = dwnp_2020 / CellArea6m
dwnpopden_year_fut = dwnp_year_fut / CellArea6m

outname = gwp4_pop_dir + 'gpw_v4_population_Density_rev11_2020_6min.tif'
save2File(popden_2020[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = gwp4_pop_dir + 'gpw_v4_population_Density_rev11_' + str(year_fut) +'scaledBySSP2_6min.tif'
save2File(popden_year_fut[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = dwn_pop_dir + 'gpw4_dwnpop_Density_2020_TerraClimate_aLTM1985-2015_6min.tif'
save2File(dwnpopden_2020[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = dwn_pop_dir + 'gpw4_dwnpop_Density_' + str(year_fut) + '_TerraClimate_aLTM1985-2015_6min.tif'
save2File(dwnpopden_year_fut[:, :], outname, nrows6m, ncols6m, geotr6m)

# %% [markdown]
# ## Create Climate Impacted Water Threat (<i>Climate Impacted Ti</i>) and Green/Gray Threat Reduction Capacity (<i>Climate Impacted TRnat</i>, <i>Climate Impacted TReng</i>) Indicators
#
# The contemporary and future Climate Variability indicators (ClimVar<sub>contemp</sub> and ClimVar<sub>future</sub>) were applied to the human water security and green-gray water threat reduction data (Ti, TRnat, TReng) to create indicators measuring the impact of climate variability on (a) human water security threat (Climate Impacted Ti),  (b) green infrastructure condition (Climate Impacted TRnat), and (c) gray infrastructure condition (Climate Impacted TReng) for contemporary and future (year 2080, +2C and +4C climate run) conditions. These indicators were ranked on a continuous 0-1 scale of low to high threats and threat reduction capacity.

# %%
print("Contemporary..")

Ti_ClimVul_2005 = Ti_2005 + ((1 - Ti_2005) * TS_Contemp_CV_CDF)
Ti_ClimVul_2005_CDF = rankCDF(Ti_ClimVul_2005)

TRnat_ClimVul_2005 = TRnat_2005 * (1 - TS_Contemp_CV_CDF)
TRnat_ClimVul_2005_CDF = rankCDF(TRnat_ClimVul_2005)

TReng_ClimVul_2005 = TReng_2005 * (1 - TS_Contemp_CV_CDF)
TReng_ClimVul_2005_CDF = rankCDF(TReng_ClimVul_2005)

print("Future Climates..")
print("   2C")
Ti_ClimVul_year_fut_2C = Ti_year_fut + ((1 - Ti_year_fut) * TS_FutClim_2C_CV_CDF)
Ti_ClimVul_year_fut_2C_CDF = rankCDF(Ti_ClimVul_year_fut_2C)

TRnat_ClimVul_year_fut_2C = TRnat_year_fut * (1 - TS_FutClim_2C_CV_CDF)
TRnat_ClimVul_year_fut_2C_CDF = rankCDF(TRnat_ClimVul_year_fut_2C)

TReng_ClimVul_year_fut_2C = TReng_year_fut * (1 - TS_FutClim_2C_CV_CDF)
TReng_ClimVul_year_fut_2C_CDF = rankCDF(TReng_ClimVul_year_fut_2C)

print("   4C")
Ti_ClimVul_year_fut_4C = Ti_year_fut + ((1 - Ti_year_fut) * TS_FutClim_4C_CV_CDF)
Ti_ClimVul_year_fut_4C_CDF = rankCDF(Ti_ClimVul_year_fut_4C)

TRnat_ClimVul_year_fut_4C = TRnat_year_fut * (1 - TS_FutClim_4C_CV_CDF)
TRnat_ClimVul_year_fut_4C_CDF = rankCDF(TRnat_ClimVul_year_fut_4C)

TReng_ClimVul_year_fut_4C = TReng_year_fut * (1 - TS_FutClim_4C_CV_CDF)
TReng_ClimVul_year_fut_4C_CDF = rankCDF(TReng_ClimVul_year_fut_4C)


Ti_ClimVul_2005_CDF = np.where(Threat_nan == 1, np.nan, Ti_ClimVul_2005_CDF)
TRnat_ClimVul_2005_CDF = np.where(Threat_nan == 1, np.nan, TRnat_ClimVul_2005_CDF)
TReng_ClimVul_2005_CDF = np.where(Threat_nan == 1, np.nan, TReng_ClimVul_2005_CDF)

Ti_ClimVul_year_fut_2C_CDF = np.where(Threat_nan == 1, np.nan, Ti_ClimVul_year_fut_2C_CDF)
TRnat_ClimVul_year_fut_2C_CDF = np.where(Threat_nan == 1, np.nan, TRnat_ClimVul_year_fut_2C_CDF)
TReng_ClimVul_year_fut_2C_CDF = np.where(Threat_nan == 1, np.nan, TReng_ClimVul_year_fut_2C_CDF)

Ti_ClimVul_year_fut_4C_CDF = np.where(Threat_nan == 1, np.nan, Ti_ClimVul_year_fut_4C_CDF)
TRnat_ClimVul_year_fut_4C_CDF = np.where(Threat_nan == 1, np.nan, TRnat_ClimVul_year_fut_4C_CDF)
TReng_ClimVul_year_fut_4C_CDF = np.where(Threat_nan == 1, np.nan, TReng_ClimVul_year_fut_4C_CDF)

# %% [markdown]
# ## Population Totals under Climate Vulnerability (<i>ClimVar<sub>contemp</sub> , ClimVar<sub>future</sub>></i>), <i>Climate Impacted Ti</i>, <i>Climate Impacted TRnat</i> and <i>Climate Impacted TReng</i>

# %%
# > 0.7 for TRnat and TReng = HIGH Capacity (BLUE)
# < 0.3 for TRnat and TReng = LOW Capacity (RED)

print("Create Low-Mod-High arrays..")
print("  Contemporary")
dwnpop_TiORIG2020_low = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 < 0.3, dwnp_2020_nan, 0))
dwnpop_TiORIGyear_fut_low = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut < 0.3, dwnp_year_fut_nan, 0))
dwnpop_TiORIG2020_mod = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.3, np.where(Ti_2005 < 0.7, dwnp_2020_nan, 0), 0))
dwnpop_TiORIGyear_fut_mod = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.3, np.where(Ti_year_fut < 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_TiORIG2020_high = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.7, dwnp_2020_nan, 0))
dwnpop_TiORIGyear_fut_high = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_nan, 0))

dwnpop_CV2020_low = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.3, dwnp_2020_nan, 0))
dwnpop_Ti2020_low = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.3, dwnp_2020_nan, 0))
dwnpop_TRnat2020_high = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.7, dwnp_2020_nan, 0))
dwnpop_TReng2020_high = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.7, dwnp_2020_nan, 0))

dwnpop_CV2020_mod = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.3, np.where(TS_Contemp_CV_CDF < 0.7, dwnp_2020_nan, 0), 0))
dwnpop_Ti2020_mod = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.3, np.where(Ti_ClimVul_2005_CDF < 0.7, dwnp_2020_nan, 0), 0))
dwnpop_TRnat2020_mod = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.7, np.where(TRnat_ClimVul_2005_CDF >= 0.3, dwnp_2020_nan, 0), 0))
dwnpop_TReng2020_mod = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.7, np.where(TReng_ClimVul_2005_CDF >= 0.3, dwnp_2020_nan, 0), 0))

dwnpop_CV2020_high = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, dwnp_2020_nan, 0))
dwnpop_Ti2020_high = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, dwnp_2020_nan, 0))
dwnpop_TRnat2020_low = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, dwnp_2020_nan, 0))
dwnpop_TReng2020_low = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, dwnp_2020_nan, 0))

print("  2C")
dwnpop_CVyear_fut_2C_low = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF < 0.3, dwnp_year_fut_nan, 0))
dwnpop_Tiyear_fut_2C_low = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_nan, 0))
dwnpop_TRnatyear_fut_2C_high = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_nan, 0))
dwnpop_TRengyear_fut_2C_high = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_nan, 0))

dwnpop_CVyear_fut_2C_mod = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.3, np.where(TS_FutClim_2C_CV_CDF < 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_Tiyear_fut_2C_mod = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.3, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_TRnatyear_fut_2C_mod = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.7, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TRengyear_fut_2C_mod = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.7, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_nan, 0), 0))

dwnpop_CVyear_fut_2C_high = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut_nan, 0))
dwnpop_Tiyear_fut_2C_high = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_nan, 0))
dwnpop_TRnatyear_fut_2C_low = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_nan, 0))
dwnpop_TRengyear_fut_2C_low = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_nan, 0))

print("  4C")
dwnpop_CVyear_fut_4C_low = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF < 0.3, dwnp_year_fut_nan, 0))
dwnpop_Tiyear_fut_4C_low = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_nan, 0))
dwnpop_TRnatyear_fut_4C_high = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_nan, 0))
dwnpop_TRengyear_fut_4C_high = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_nan, 0))

dwnpop_CVyear_fut_4C_mod = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.3, np.where(TS_FutClim_4C_CV_CDF < 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_Tiyear_fut_4C_mod = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.3, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_TRnatyear_fut_4C_mod = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.7, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TRengyear_fut_4C_mod = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.7, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_nan, 0), 0))

dwnpop_CVyear_fut_4C_high = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut_nan, 0))
dwnpop_Tiyear_fut_4C_high = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_nan, 0))
dwnpop_TRnatyear_fut_4C_low = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_nan, 0))
dwnpop_TRengyear_fut_4C_low = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_nan, 0))

# print("Create Change Classes..")

dwnpop_TiORIG_StaysLowModThreat = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 < 0.7, np.where(Ti_year_fut < 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_TiORIG_StaysHiThreat = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.7, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_TiORIG_fromLowModThreat2Hi = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 < 0.7, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_TiORIG_ConH_FutL = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.7, np.where(Ti_year_fut < 0.7, dwnp_year_fut_nan, 0), 0))

# print("  2C")

TiClimVar_StaysHiThreat_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, 1, 0), 0))
TiClimVar_fromLowModThreat2Hi_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, 2, 0), 0))
TiClimVar_fromHiThreat2LowMod_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, 3, 0), 0))
TiClimVar_StaysLowModThreat_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, 4, 0), 0))
TiClimVar_Change_year_fut_2C = TiClimVar_StaysLowModThreat_2C + TiClimVar_StaysHiThreat_2C + TiClimVar_fromLowModThreat2Hi_2C + TiClimVar_fromHiThreat2LowMod_2C

TRnat_StaysLowCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, 1, 0), 0))
TRnat_fromModHiCapacity2Low_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, 2, 0), 0))
TRnat_fromLowCapacity2ModHi_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, 3, 0), 0))
TRnat_StaysModHiCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, 4, 0), 0))
TRnat_Change_year_fut_2C = TRnat_StaysLowCapacity_2C + TRnat_fromModHiCapacity2Low_2C + TRnat_fromLowCapacity2ModHi_2C + TRnat_StaysModHiCapacity_2C

TReng_StaysLowCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, 1, 0), 0))
TReng_fromModHiCapacity2Low_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, 2, 0), 0))
TReng_fromLowCapacity2ModHi_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, 3, 0), 0))
TReng_StaysModHiCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, 4, 0), 0))
TReng_Change_year_fut_2C = TReng_StaysLowCapacity_2C + TReng_fromModHiCapacity2Low_2C + TReng_fromLowCapacity2ModHi_2C + TReng_StaysModHiCapacity_2C

dwnpop_CV_StaysLowModThreat_2C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.7, np.where(TS_FutClim_2C_CV_CDF < 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_CV_StaysHiThreat_2C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_CV_fromLowModThreat2Hi_2C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.7, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_CV_fromHiThreat2LowMod_2C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, np.where(TS_FutClim_2C_CV_CDF < 0.7, dwnp_year_fut_nan, 0), 0))

dwnpop_TiCV_StaysLowModThreat_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_TiCV_StaysHiThreat_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_TiCV_fromLowModThreat2Hi_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_TiCV_fromHiThreat2LowMod_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, dwnp_year_fut_nan, 0), 0))

dwnpop_TRnat_StaysLowCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TRnat_StaysModHiCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TRnat_fromLowCapacity2ModHi_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TRnat_fromModHiCapacity2Low_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_nan, 0), 0))

dwnpop_TReng_StaysLowCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TReng_StaysModHiCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TReng_fromLowCapacity2ModHi_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TReng_fromModHiCapacity2Low_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_nan, 0), 0))

# print("  4C")

TiClimVar_StaysHiThreat_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, 1, 0), 0))
TiClimVar_fromLowModThreat2Hi_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, 2, 0), 0))
TiClimVar_fromHiThreat2LowMod_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, 3, 0), 0))
TiClimVar_StaysLowModThreat_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, 4, 0), 0))
TiClimVar_Change_year_fut_4C = TiClimVar_StaysLowModThreat_4C + TiClimVar_StaysHiThreat_4C + TiClimVar_fromLowModThreat2Hi_4C + TiClimVar_fromHiThreat2LowMod_4C

TRnat_StaysLowCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, 1, 0), 0))
TRnat_fromModHiCapacity2Low_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, 2, 0), 0))
TRnat_fromLowCapacity2ModHi_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, 3, 0), 0))
TRnat_StaysModHiCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, 4, 0), 0))
TRnat_Change_year_fut_4C = TRnat_StaysLowCapacity_4C + TRnat_fromModHiCapacity2Low_4C + TRnat_fromLowCapacity2ModHi_4C + TRnat_StaysModHiCapacity_4C

TReng_StaysLowCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, 1, 0), 0))
TReng_fromModHiCapacity2Low_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, 2, 0), 0))
TReng_fromLowCapacity2ModHi_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, 3, 0), 0))
TReng_StaysModHiCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, 4, 0), 0))
TReng_Change_year_fut_4C = TReng_StaysLowCapacity_4C + TReng_fromModHiCapacity2Low_4C + TReng_fromLowCapacity2ModHi_4C + TReng_StaysModHiCapacity_4C

dwnpop_CV_StaysLowModThreat_4C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.7, np.where(TS_FutClim_4C_CV_CDF < 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_CV_StaysHiThreat_4C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_CV_fromLowModThreat2Hi_4C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.7, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_CV_fromHiThreat2LowMod_4C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, np.where(TS_FutClim_4C_CV_CDF < 0.7, dwnp_year_fut_nan, 0), 0))

dwnpop_TiCV_StaysLowModThreat_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_TiCV_StaysHiThreat_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_TiCV_fromLowModThreat2Hi_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_nan, 0), 0))
dwnpop_TiCV_fromHiThreat2LowMod_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, dwnp_year_fut_nan, 0), 0))

dwnpop_TRnat_StaysLowCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TRnat_StaysModHiCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TRnat_fromLowCapacity2ModHi_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TRnat_fromModHiCapacity2Low_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_nan, 0), 0))

dwnpop_TReng_StaysLowCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TReng_StaysModHiCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TReng_fromLowCapacity2ModHi_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_nan, 0), 0))
dwnpop_TReng_fromModHiCapacity2Low_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_nan, 0), 0))

# %% [markdown]
# # Extremely Dry and Extremely Wet Anomalies Impacting River Threats and Green/Gray Threat Reduction Capacity
#
# Time Series anomalies developed with the Jupyter Notebook WaterBalanceModel_Variability_Indicators.ipynb in the WaterBalanceModel_TimeSeries repository located at https://github.com/PamelaAGreen/WaterBalanceModel_TimeSeries

# %%
fin = out_dir + 'TerraClimate_RO_Contemp_ZScore_XDry_cnt.tif'
ds = gdal.Open(str(fin))
msk_Contemp_XDry = np.array(ds.GetRasterBand(1).ReadAsArray())
msk_Contemp_XDry[np.isnan(msk_Contemp_XDry)] = 0
msk_Contemp_XDry = np.where(msk_Contemp_XDry >= 1, msk_Contemp_XDry / 32, 0)

fin = out_dir + 'TerraClimate_RO_Contemp_ZScore_XWet_cnt.tif'
ds = gdal.Open(str(fin))
msk_Contemp_XWet = np.array(ds.GetRasterBand(1).ReadAsArray())
msk_Contemp_XWet[np.isnan(msk_Contemp_XWet)] = 0
msk_Contemp_XWet = np.where(msk_Contemp_XWet > 1, msk_Contemp_XWet / 32, 0)

fin = out_dir + 'TerraClimate_RO_FutClim_2C_ZScore_XDry_cnt.tif'
ds = gdal.Open(str(fin))
msk_FutClim_2C_XDry = np.array(ds.GetRasterBand(1).ReadAsArray())
msk_FutClim_2C_XDry[np.isnan(msk_FutClim_2C_XDry)] = 0
msk_FutClim_2C_XDry = np.where(msk_FutClim_2C_XDry >= 1, msk_FutClim_2C_XDry / 32, 0)

fin = out_dir + 'TerraClimate_RO_FutClim_2C_ZScore_XWet_cnt.tif'
ds = gdal.Open(str(fin))
msk_FutClim_2C_XWet = np.array(ds.GetRasterBand(1).ReadAsArray())
msk_FutClim_2C_XWet[np.isnan(msk_FutClim_2C_XWet)] = 0
msk_FutClim_2C_XWet = np.where(msk_FutClim_2C_XWet > 1, msk_FutClim_2C_XWet / 32, 0)

fin = out_dir + 'TerraClimate_RO_FutClim_4C_ZScore_XDry_cnt.tif'
ds = gdal.Open(str(fin))
msk_FutClim_4C_XDry = np.array(ds.GetRasterBand(1).ReadAsArray())
msk_FutClim_4C_XDry[np.isnan(msk_FutClim_4C_XDry)] = 0
msk_FutClim_4C_XDry = np.where(msk_FutClim_4C_XDry >= 1, msk_FutClim_4C_XDry / 32, 0)

fin = out_dir + 'TerraClimate_RO_FutClim_4C_ZScore_XWet_cnt.tif'
ds = gdal.Open(str(fin))
msk_FutClim_4C_XWet = np.array(ds.GetRasterBand(1).ReadAsArray())
msk_FutClim_4C_XWet[np.isnan(msk_FutClim_4C_XWet)] = 0
msk_FutClim_4C_XWet = np.where(msk_FutClim_4C_XWet > 1, msk_FutClim_4C_XWet / 32, 0)

msk_Contemp_XDry_Binary = np.where(msk_Contemp_XDry > 0, 1, 0)
msk_FutClim_2C_XDry_Binary = np.where(msk_FutClim_2C_XDry > 0, 1, 0)
msk_FutClim_4C_XDry_Binary = np.where(msk_FutClim_4C_XDry > 0, 1, 0)
msk_Contemp_XWet_Binary = np.where(msk_Contemp_XWet > 0, 1, np.nan)
msk_FutClim_2C_XWet_Binary = np.where(msk_FutClim_2C_XWet > 0, 1, 0)
msk_FutClim_4C_XWet_Binary = np.where(msk_FutClim_4C_XWet > 0, 1, 0)

dwnp_2020_XDry = np.where(msk_Contemp_XDry > 0, dwnp_2020, 0)
dwnp_year_fut_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnp_year_fut, 0)
dwnp_year_fut_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnp_year_fut, 0)

dwnp_2020_XWet = np.where(msk_Contemp_XWet > 0, dwnp_2020, 0)
dwnp_year_fut_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnp_year_fut, 0)
dwnp_year_fut_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnp_year_fut, 0)

# %% [markdown]
# ## Extremely DRY: Downstream Population Totals under Climate Vulnerability (<i>ClimVar<sub>contemp</sub> , ClimVar<sub>future</sub>></i>), <i>Climate Impacted Ti</i>, <i>Climate Impacted TRnat</i> and <i>Climate Impacted TReng</i>

# %%
dwnp_2020_XDry_nan = np.where(Threat_nan == 1, 0, dwnp_2020_XDry)
dwnp_year_fut_2C_XDry_nan = np.where(Threat_nan == 1, 0, dwnp_year_fut_2C_XDry)
dwnp_year_fut_4C_XDry_nan = np.where(Threat_nan == 1, 0, dwnp_year_fut_4C_XDry)

# > 0.7 for TRnat and TReng = HIGH Capacity (BLUE)
# < 0.3 for TRnat and TReng = LOW Capacity (RED)

print("Create Low-Mod-High arrays..")
print("  Contemporary")
dwnpop_TiORIG2020_low_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 < 0.3, dwnp_2020_XDry_nan, 0))
dwnpop_TiORIG2020_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.3, np.where(Ti_2005 < 0.7, dwnp_2020_XDry_nan, 0), 0))
dwnpop_TiORIG2020_high_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.7, dwnp_2020_XDry_nan, 0))

dwnpop_TiORIGyear_fut_2C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut < 0.3, dwnp_year_fut_2C_XDry_nan, 0))
dwnpop_TiORIGyear_fut_2C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.3, np.where(Ti_year_fut < 0.7, dwnp_year_fut_2C_XDry_nan, 0), 0))
dwnpop_TiORIGyear_fut_2C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_2C_XDry_nan, 0))

dwnpop_TiORIGyear_fut_4C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut < 0.3, dwnp_year_fut_4C_XDry_nan, 0))
dwnpop_TiORIGyear_fut_4C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.3, np.where(Ti_year_fut < 0.7, dwnp_year_fut_4C_XDry_nan, 0), 0))
dwnpop_TiORIGyear_fut_4C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_4C_XDry_nan, 0))

dwnpop_CV2020_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.3, dwnp_2020_XDry_nan, 0))
dwnpop_Ti2020_low_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.3, dwnp_2020_XDry_nan, 0))
dwnpop_TRnat2020_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.7, dwnp_2020_XDry_nan, 0))
dwnpop_TReng2020_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.7, dwnp_2020_XDry_nan, 0))

dwnpop_CV2020_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.3, np.where(TS_Contemp_CV_CDF < 0.7, dwnp_2020_XDry_nan, 0), 0))
dwnpop_Ti2020_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.3, np.where(Ti_ClimVul_2005_CDF < 0.7, dwnp_2020_XDry_nan, 0), 0))
dwnpop_TRnat2020_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.7, np.where(TRnat_ClimVul_2005_CDF >= 0.3, dwnp_2020_XDry_nan, 0), 0))
dwnpop_TReng2020_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.7, np.where(TReng_ClimVul_2005_CDF >= 0.3, dwnp_2020_XDry_nan, 0), 0))

dwnpop_CV2020_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, dwnp_2020_XDry_nan, 0))
dwnpop_Ti2020_high_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, dwnp_2020_XDry_nan, 0))
dwnpop_TRnat2020_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, dwnp_2020_XDry_nan, 0))
dwnpop_TReng2020_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, dwnp_2020_XDry_nan, 0))

print("  2C")
dwnpop_CVyear_fut_2C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF < 0.3, dwnp_year_fut_2C_XDry_nan, 0))
dwnpop_Tiyear_fut_2C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_XDry_nan, 0))
dwnpop_TRnatyear_fut_2C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_XDry_nan, 0))
dwnpop_TRengyear_fut_2C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_XDry_nan, 0))

dwnpop_CVyear_fut_2C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.3, np.where(TS_FutClim_2C_CV_CDF < 0.7, dwnp_year_fut_2C_XDry_nan, 0), 0))
dwnpop_Tiyear_fut_2C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.3, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, dwnp_year_fut_2C_XDry_nan, 0), 0))
dwnpop_TRnatyear_fut_2C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.7, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_2C_XDry_nan, 0), 0))
dwnpop_TRengyear_fut_2C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.7, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_2C_XDry_nan, 0), 0))

dwnpop_CVyear_fut_2C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut_2C_XDry_nan, 0))
dwnpop_Tiyear_fut_2C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_XDry_nan, 0))
dwnpop_TRnatyear_fut_2C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_XDry_nan, 0))
dwnpop_TRengyear_fut_2C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_XDry_nan, 0))

print("  4C")
dwnpop_CVyear_fut_4C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF < 0.3, dwnp_year_fut_4C_XDry_nan, 0))
dwnpop_Tiyear_fut_4C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_XDry_nan, 0))
dwnpop_TRnatyear_fut_4C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_XDry_nan, 0))
dwnpop_TRengyear_fut_4C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_XDry_nan, 0))

dwnpop_CVyear_fut_4C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.3, np.where(TS_FutClim_4C_CV_CDF < 0.7, dwnp_year_fut_4C_XDry_nan, 0), 0))
dwnpop_Tiyear_fut_4C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.3, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, dwnp_year_fut_4C_XDry_nan, 0), 0))
dwnpop_TRnatyear_fut_4C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.7, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_4C_XDry_nan, 0), 0))
dwnpop_TRengyear_fut_4C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.7, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_4C_XDry_nan, 0), 0))

dwnpop_CVyear_fut_4C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut_4C_XDry_nan, 0))
dwnpop_Tiyear_fut_4C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_XDry_nan, 0))
dwnpop_TRnatyear_fut_4C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_XDry_nan, 0))
dwnpop_TRengyear_fut_4C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_XDry_nan, 0))

print("Create Change Classes..")

print("  2C")

dwnpop_CV_StaysLowModThreat_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_CV_StaysLowModThreat_2C, 0)
dwnpop_CV_StaysHiThreat_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_CV_StaysHiThreat_2C, 0)
dwnpop_CV_fromLowModThreat2Hi_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_CV_fromLowModThreat2Hi_2C, 0)
dwnpop_CV_fromHiThreat2LowMod_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_CV_fromHiThreat2LowMod_2C, 0)

dwnpop_TiCV_StaysLowModThreat_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_TiCV_StaysLowModThreat_2C, 0)
dwnpop_TiCV_StaysHiThreat_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_TiCV_StaysHiThreat_2C, 0)
dwnpop_TiCV_fromLowModThreat2Hi_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_TiCV_fromLowModThreat2Hi_2C, 0)
dwnpop_TiCV_fromHiThreat2LowMod_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_TiCV_fromHiThreat2LowMod_2C, 0)

dwnpop_TRnat_StaysLowCapacity_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_TRnat_StaysLowCapacity_2C, 0)
dwnpop_TRnat_StaysModHiCapacity_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_TRnat_StaysModHiCapacity_2C, 0)
dwnpop_TRnat_fromLowCapacity2ModHi_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_TRnat_fromLowCapacity2ModHi_2C, 0)
dwnpop_TRnat_fromModHiCapacity2Low_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_TRnat_fromModHiCapacity2Low_2C, 0)

dwnpop_TReng_StaysLowCapacity_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_TReng_StaysLowCapacity_2C, 0)
dwnpop_TReng_StaysModHiCapacity_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_TReng_StaysModHiCapacity_2C, 0)
dwnpop_TReng_fromLowCapacity2ModHi_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_TReng_fromLowCapacity2ModHi_2C, 0)
dwnpop_TReng_fromModHiCapacity2Low_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpop_TReng_fromModHiCapacity2Low_2C, 0)

print("  4C")

dwnpop_CV_StaysLowModThreat_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_CV_StaysLowModThreat_4C, 0)
dwnpop_CV_StaysHiThreat_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_CV_StaysHiThreat_4C, 0)
dwnpop_CV_fromLowModThreat2Hi_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_CV_fromLowModThreat2Hi_4C, 0)
dwnpop_CV_fromHiThreat2LowMod_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_CV_fromHiThreat2LowMod_4C, 0)

dwnpop_TiCV_StaysLowModThreat_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_TiCV_StaysLowModThreat_4C, 0)
dwnpop_TiCV_StaysHiThreat_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_TiCV_StaysHiThreat_4C, 0)
dwnpop_TiCV_fromLowModThreat2Hi_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_TiCV_fromLowModThreat2Hi_4C, 0)
dwnpop_TiCV_fromHiThreat2LowMod_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_TiCV_fromHiThreat2LowMod_4C, 0)

dwnpop_TRnat_StaysLowCapacity_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_TRnat_StaysLowCapacity_4C, 0)
dwnpop_TRnat_StaysModHiCapacity_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_TRnat_StaysModHiCapacity_4C, 0)
dwnpop_TRnat_fromLowCapacity2ModHi_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_TRnat_fromLowCapacity2ModHi_4C, 0)
dwnpop_TRnat_fromModHiCapacity2Low_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_TRnat_fromModHiCapacity2Low_4C, 0)

dwnpop_TReng_StaysLowCapacity_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_TReng_StaysLowCapacity_4C, 0)
dwnpop_TReng_StaysModHiCapacity_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_TReng_StaysModHiCapacity_4C, 0)
dwnpop_TReng_fromLowCapacity2ModHi_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_TReng_fromLowCapacity2ModHi_4C, 0)
dwnpop_TReng_fromModHiCapacity2Low_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpop_TReng_fromModHiCapacity2Low_4C, 0)

# %% [markdown]
# ## Extremely WET: Downtream Population Totals under Climate Vulnerability (<i>ClimVar<sub>contemp</sub> , ClimVar<sub>future</sub>></i>), <i>Climate Impacted Ti</i>, <i>Climate Impacted TRnat</i> and <i>Climate Impacted TReng</i>

# %%
dwnp_2020_XWet_nan = np.where(Threat_nan == 1, 0, dwnp_2020_XWet)
dwnp_year_fut_2C_XWet_nan = np.where(Threat_nan == 1, 0, dwnp_year_fut_2C_XWet)
dwnp_year_fut_4C_XWet_nan = np.where(Threat_nan == 1, 0, dwnp_year_fut_4C_XWet)

# > 0.7 for TRnat and TReng = HIGH Capacity (BLUE)
# < 0.3 for TRnat and TReng = LOW Capacity (RED)

print("Create Low-Mod-High arrays..")
print("  Contemporary")
dwnpop_TiORIG2020_low_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 < 0.3, dwnp_2020_XWet_nan, 0))
dwnpop_TiORIG2020_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.3, np.where(Ti_2005 < 0.7, dwnp_2020_XWet_nan, 0), 0))
dwnpop_TiORIG2020_high_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.7, dwnp_2020_XWet_nan, 0))

dwnpop_TiORIGyear_fut_2C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut < 0.3, dwnp_year_fut_2C_XWet_nan, 0))
dwnpop_TiORIGyear_fut_2C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.3, np.where(Ti_year_fut < 0.7, dwnp_year_fut_2C_XWet_nan, 0), 0))
dwnpop_TiORIGyear_fut_2C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_2C_XWet_nan, 0))

dwnpop_TiORIGyear_fut_4C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut < 0.3, dwnp_year_fut_4C_XWet_nan, 0))
dwnpop_TiORIGyear_fut_4C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.3, np.where(Ti_year_fut < 0.7, dwnp_year_fut_4C_XWet_nan, 0), 0))
dwnpop_TiORIGyear_fut_4C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_4C_XWet_nan, 0))

dwnpop_CV2020_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.3, dwnp_2020_XWet_nan, 0))
dwnpop_Ti2020_low_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.3, dwnp_2020_XWet_nan, 0))
dwnpop_TRnat2020_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.7, dwnp_2020_XWet_nan, 0))
dwnpop_TReng2020_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.7, dwnp_2020_XWet_nan, 0))

dwnpop_CV2020_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.3, np.where(TS_Contemp_CV_CDF < 0.7, dwnp_2020_XWet_nan, 0), 0))
dwnpop_Ti2020_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.3, np.where(Ti_ClimVul_2005_CDF < 0.7, dwnp_2020_XWet_nan, 0), 0))
dwnpop_TRnat2020_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.7, np.where(TRnat_ClimVul_2005_CDF >= 0.3, dwnp_2020_XWet_nan, 0), 0))
dwnpop_TReng2020_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.7, np.where(TReng_ClimVul_2005_CDF >= 0.3, dwnp_2020_XWet_nan, 0), 0))

dwnpop_CV2020_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, dwnp_2020_XWet_nan, 0))
dwnpop_Ti2020_high_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, dwnp_2020_XWet_nan, 0))
dwnpop_TRnat2020_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, dwnp_2020_XWet_nan, 0))
dwnpop_TReng2020_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, dwnp_2020_XWet_nan, 0))

print("  2C")
dwnpop_CVyear_fut_2C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF < 0.3, dwnp_year_fut_2C_XWet_nan, 0))
dwnpop_Tiyear_fut_2C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_XWet_nan, 0))
dwnpop_TRnatyear_fut_2C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_XWet_nan, 0))
dwnpop_TRengyear_fut_2C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_XWet_nan, 0))

dwnpop_CVyear_fut_2C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.3, np.where(TS_FutClim_2C_CV_CDF < 0.7, dwnp_year_fut_2C_XWet_nan, 0), 0))
dwnpop_Tiyear_fut_2C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.3, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, dwnp_year_fut_2C_XWet_nan, 0), 0))
dwnpop_TRnatyear_fut_2C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.7, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_2C_XWet_nan, 0), 0))
dwnpop_TRengyear_fut_2C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.7, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_2C_XWet_nan, 0), 0))

dwnpop_CVyear_fut_2C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut_2C_XWet_nan, 0))
dwnpop_Tiyear_fut_2C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_XWet_nan, 0))
dwnpop_TRnatyear_fut_2C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_XWet_nan, 0))
dwnpop_TRengyear_fut_2C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_XWet_nan, 0))

print("  4C")
dwnpop_CVyear_fut_4C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF < 0.3, dwnp_year_fut_4C_XWet_nan, 0))
dwnpop_Tiyear_fut_4C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_XWet_nan, 0))
dwnpop_TRnatyear_fut_4C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_XWet_nan, 0))
dwnpop_TRengyear_fut_4C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_XWet_nan, 0))

dwnpop_CVyear_fut_4C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.3, np.where(TS_FutClim_4C_CV_CDF < 0.7, dwnp_year_fut_4C_XWet_nan, 0), 0))
dwnpop_Tiyear_fut_4C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.3, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, dwnp_year_fut_4C_XWet_nan, 0), 0))
dwnpop_TRnatyear_fut_4C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.7, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_4C_XWet_nan, 0), 0))
dwnpop_TRengyear_fut_4C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.7, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_4C_XWet_nan, 0), 0))

dwnpop_CVyear_fut_4C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut_4C_XWet_nan, 0))
dwnpop_Tiyear_fut_4C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_XWet_nan, 0))
dwnpop_TRnatyear_fut_4C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_XWet_nan, 0))
dwnpop_TRengyear_fut_4C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_XWet_nan, 0))

print("Create Change Classes..")

print("  2C")

dwnpop_CV_StaysLowModThreat_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_CV_StaysLowModThreat_2C, 0)
dwnpop_CV_StaysHiThreat_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_CV_StaysHiThreat_2C, 0)
dwnpop_CV_fromLowModThreat2Hi_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_CV_fromLowModThreat2Hi_2C, 0)
dwnpop_CV_fromHiThreat2LowMod_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_CV_fromHiThreat2LowMod_2C, 0)

dwnpop_TiCV_StaysLowModThreat_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TiCV_StaysLowModThreat_2C, 0)
dwnpop_TiCV_StaysHiThreat_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TiCV_StaysHiThreat_2C, 0)
dwnpop_TiCV_fromLowModThreat2Hi_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TiCV_fromLowModThreat2Hi_2C, 0)
dwnpop_TiCV_fromHiThreat2LowMod_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TiCV_fromHiThreat2LowMod_2C, 0)

dwnpop_TRnat_StaysLowCapacity_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TRnat_StaysLowCapacity_2C, 0)
dwnpop_TRnat_StaysModHiCapacity_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TRnat_StaysModHiCapacity_2C, 0)
dwnpop_TRnat_fromLowCapacity2ModHi_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TRnat_fromLowCapacity2ModHi_2C, 0)
dwnpop_TRnat_fromModHiCapacity2Low_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TRnat_fromModHiCapacity2Low_2C, 0)

dwnpop_TReng_StaysLowCapacity_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TReng_StaysLowCapacity_2C, 0)
dwnpop_TReng_StaysModHiCapacity_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TReng_StaysModHiCapacity_2C, 0)
dwnpop_TReng_fromLowCapacity2ModHi_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TReng_fromLowCapacity2ModHi_2C, 0)
dwnpop_TReng_fromModHiCapacity2Low_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TReng_fromModHiCapacity2Low_2C, 0)

print("  4C")

dwnpop_CV_StaysLowModThreat_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_CV_StaysLowModThreat_4C, 0)
dwnpop_CV_StaysHiThreat_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_CV_StaysHiThreat_4C, 0)
dwnpop_CV_fromLowModThreat2Hi_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_CV_fromLowModThreat2Hi_4C, 0)
dwnpop_CV_fromHiThreat2LowMod_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_CV_fromHiThreat2LowMod_4C, 0)

dwnpop_TiCV_StaysLowModThreat_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TiCV_StaysLowModThreat_4C, 0)
dwnpop_TiCV_StaysHiThreat_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TiCV_StaysHiThreat_4C, 0)
dwnpop_TiCV_fromLowModThreat2Hi_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TiCV_fromLowModThreat2Hi_4C, 0)
dwnpop_TiCV_fromHiThreat2LowMod_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TiCV_fromHiThreat2LowMod_4C, 0)

dwnpop_TRnat_StaysLowCapacity_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TRnat_StaysLowCapacity_4C, 0)
dwnpop_TRnat_StaysModHiCapacity_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TRnat_StaysModHiCapacity_4C, 0)
dwnpop_TRnat_fromLowCapacity2ModHi_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TRnat_fromLowCapacity2ModHi_4C, 0)
dwnpop_TRnat_fromModHiCapacity2Low_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TRnat_fromModHiCapacity2Low_4C, 0)

dwnpop_TReng_StaysLowCapacity_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TReng_StaysLowCapacity_4C, 0)
dwnpop_TReng_StaysModHiCapacity_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TReng_StaysModHiCapacity_4C, 0)
dwnpop_TReng_fromLowCapacity2ModHi_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TReng_fromLowCapacity2ModHi_4C, 0)
dwnpop_TReng_fromModHiCapacity2Low_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TReng_fromModHiCapacity2Low_4C, 0)

# %% [markdown]
# # Global and Continental Population Aggregates and Sums

# %% [markdown]
# ## Global and Continental Population Sums by Climate Vulnerability (<i>ClimVar<sub>contemp</sub> , ClimVar<sub>future</sub>></i>), <i>Climate Impacted Ti</i>, <i>Climate Impacted TRnat</i> and <i>Climate Impacted TReng</i>

# %%
print("Global sums ..")

dwnpop_CV2020_high_global = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, dwnp_2020, 0))
dwnpop_Ti2020_high_global = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, dwnp_2020_nan, 0))
dwnpop_TRnat2020_low_global = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, dwnp_2020_nan, 0))
dwnpop_TReng2020_low_global = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, dwnp_2020_nan, 0))

dwnpop_CVyear_fut_2C_high_global = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut, 0))
dwnpop_Tiyear_fut_2C_high_global = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_nan, 0))
dwnpop_TRnatyear_fut_2C_low_global = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_nan, 0))
dwnpop_TRengyear_fut_2C_low_global = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_nan, 0))

dwnpop_CVyear_fut_4C_high_global = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut, 0))
dwnpop_Tiyear_fut_4C_high_global = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_nan, 0))
dwnpop_TRnatyear_fut_4C_low_global = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_nan, 0))
dwnpop_TRengyear_fut_4C_low_global = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_nan, 0))

pop_2020_sum = np.sum(pop2020) / 1000000000
pop_year_fut_sum = np.sum(scaled_pop_year_fut) / 1000000000

CV_High_2020 = np.sum(dwnpop_CV2020_high_global) / 1000000000
Ti_High_2020 = np.sum(dwnpop_Ti2020_high_global) / 1000000000
TRnat_Low_2020 = np.sum(dwnpop_TRnat2020_low_global) / 1000000000
TReng_Low_2020 = np.sum(dwnpop_TReng2020_low_global) / 1000000000

CV_High_year_fut_2C = np.sum(dwnpop_CVyear_fut_2C_high_global) / 1000000000
Ti_High_year_fut_2C = np.sum(dwnpop_Tiyear_fut_2C_high_global) / 1000000000
TRnat_Low_year_fut_2C = np.sum(dwnpop_TRnatyear_fut_2C_low_global) / 1000000000
TReng_Low_year_fut_2C = np.sum(dwnpop_TRengyear_fut_2C_low_global) / 1000000000

CV_High_year_fut_4C = np.sum(dwnpop_CVyear_fut_4C_high_global) / 1000000000
Ti_High_year_fut_4C = np.sum(dwnpop_Tiyear_fut_4C_high_global) / 1000000000
TRnat_Low_year_fut_4C = np.sum(dwnpop_TRnatyear_fut_4C_low_global) / 1000000000
TReng_Low_year_fut_4C = np.sum(dwnpop_TRengyear_fut_4C_low_global) / 1000000000

df_global_Contemp = pd.DataFrame({'Year': ['2020'],
                   'Population (billions)': [pop_2020_sum],
                   'Downstream Population Served by Areas under High Climate Variability (billions)': [CV_High_2020], 
                   'Downstream Population Served by Areas under High Water Security Threat (billions)': [Ti_High_2020],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Natural Capital (billions)': [TRnat_Low_2020],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Engineering (billions)': [TReng_Low_2020]})

df_global_2C = pd.DataFrame({'Year': [str(year_fut) + ' +2C'],
                   'Population (billions)': [pop_year_fut_sum],
                   'Downstream Population Served by Areas under High Climate Variability (billions)': [CV_High_year_fut_2C], 
                   'Downstream Population Served by Areas under High Water Security Threat (billions)': [Ti_High_year_fut_2C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Natural Capital (billions)': [TRnat_Low_year_fut_2C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Engineering (billions)': [TReng_Low_year_fut_2C]})

df_global_4C = pd.DataFrame({'Year': [str(year_fut) + ' +4C'],
                   'Population (billions)': [pop_year_fut_sum],
                   'Downstream Population Served by Areas under High Climate Variability (billions)': [CV_High_year_fut_4C], 
                   'Downstream Population Served by Areas under High Water Security Threat (billions)': [Ti_High_year_fut_4C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Natural Capital (billions)': [TRnat_Low_year_fut_4C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Engineering (billions)': [TReng_Low_year_fut_4C]})

df_global_Contemp_global = pd.DataFrame({'Year': ['2020'],
                   'Population (billions)': [pop_2020_sum],
                   'Fraction Land Area Under Extreme Dry/Wet': ' ',
                   'Fraction Population Under Extreme Dry/Wet': ' ',
                   'Downstream Population Served by Areas under High Climate Variability (billions)': [CV_High_2020], 
                   'Downstream Population Served by Areas under High Water Security Threat (billions)': [Ti_High_2020],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Natural Capital (billions)': [TRnat_Low_2020],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Engineering (billions)': [TReng_Low_2020]})

df_global_2C_global = pd.DataFrame({'Year': [str(year_fut) + ' +2C'],
                   'Population (billions)': [pop_year_fut_sum],
                   'Fraction Land Area Under Extreme Dry/Wet': ' ',
                   'Fraction Population Under Extreme Dry/Wet': ' ',
                   'Downstream Population Served by Areas under High Climate Variability (billions)': [CV_High_year_fut_2C], 
                   'Downstream Population Served by Areas under High Water Security Threat (billions)': [Ti_High_year_fut_2C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Natural Capital (billions)': [TRnat_Low_year_fut_2C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Engineering (billions)': [TReng_Low_year_fut_2C]})

df_global_4C_global = pd.DataFrame({'Year': [str(year_fut) + ' +4C'],
                   'Population (billions)': [pop_year_fut_sum],
                   'Fraction Land Area Under Extreme Dry/Wet': ' ',
                   'Fraction Population Under Extreme Dry/Wet': ' ',
                   'Downstream Population Served by Areas under High Climate Variability (billions)': [CV_High_year_fut_4C], 
                   'Downstream Population Served by Areas under High Water Security Threat (billions)': [Ti_High_year_fut_4C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Natural Capital (billions)': [TRnat_Low_year_fut_4C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Engineering (billions)': [TReng_Low_year_fut_4C]})


unqID,idx,IDsums = np.unique(gadm_cont,return_counts=True,return_inverse=True)

locp_2020_array = np.bincount(idx,pop2020.ravel()) / 1000000
locp_year_fut_array = np.bincount(idx,scaled_pop_year_fut.ravel()) / 1000000

dwnp_2020_array = np.bincount(idx,dwnp_2020.ravel()) / 1000000
dwnp_year_fut_array = np.bincount(idx,dwnp_year_fut.ravel()) / 1000000

dwnpop_CV2020_high_array = np.bincount(idx,dwnpop_CV2020_high_global.ravel()) / 1000000
dwnpop_Ti2020_high_array = np.bincount(idx,dwnpop_Ti2020_high_global.ravel()) / 1000000
dwnpop_TRnat2020_low_array = np.bincount(idx,dwnpop_TRnat2020_low_global.ravel()) / 1000000
dwnpop_TReng2020_low_array = np.bincount(idx,dwnpop_TReng2020_low_global.ravel()) / 1000000

dwnpop_CVyear_fut_2C_high_array = np.bincount(idx,dwnpop_CVyear_fut_2C_high_global.ravel()) / 1000000
dwnpop_Tiyear_fut_2C_high_array = np.bincount(idx,dwnpop_Tiyear_fut_2C_high_global.ravel()) / 1000000
dwnpop_TRnatyear_fut_2C_low_array = np.bincount(idx,dwnpop_TRnatyear_fut_2C_low_global.ravel()) / 1000000
dwnpop_TRengyear_fut_2C_low_array = np.bincount(idx,dwnpop_TRengyear_fut_2C_low_global.ravel()) / 1000000

dwnpop_CVyear_fut_4C_high_array = np.bincount(idx,dwnpop_CVyear_fut_4C_high_global.ravel()) / 1000000
dwnpop_Tiyear_fut_4C_high_array = np.bincount(idx,dwnpop_Tiyear_fut_4C_high_global.ravel()) / 1000000
dwnpop_TRnatyear_fut_4C_low_array = np.bincount(idx,dwnpop_TRnatyear_fut_4C_low_global.ravel()) / 1000000
dwnpop_TRengyear_fut_4C_low_array = np.bincount(idx,dwnpop_TRengyear_fut_4C_low_global.ravel()) / 1000000

Cont_table_Contemp = pd.DataFrame({'Continent': unqID, 'Local Population 2020 (millions)' : locp_2020_array, 
                                   'Downstream Population 2020 (millions)' : dwnp_2020_array, 
                                   'Population Downstream of Areas Under High Climate Variability 2020 (millions)' : dwnpop_CV2020_high_array, 
                                   'Population Downstream of Areas Under High Water Security Threat 2020 (millions)' : dwnpop_Ti2020_high_array, 
                                   'Population Downstream of Areas Under Highly Impaired Natural Threat Reduction 2020 (millions)' : dwnpop_TRnat2020_low_array, 
                                   'Population Downstream of Areas Under Highly Impaired Engineered Threat Reduction 2020 (millions)' : dwnpop_TReng2020_low_array}, 
                                  columns=['Continent', 'Local Population 2020 (millions)',
                                           'Downstream Population 2020 (millions)', 
                                           'Population Downstream of Areas Under High Climate Variability 2020 (millions)', 
                                           'Population Downstream of Areas Under High Water Security Threat 2020 (millions)', 
                                           'Population Downstream of Areas Under Highly Impaired Natural Threat Reduction 2020 (millions)', 
                                           'Population Downstream of Areas Under Highly Impaired Engineered Threat Reduction 2020 (millions)'])
Cont_table_Contemp.insert(1, "Continent Name", ['Other', 'Africa', 'North America', 'East and Southeast Asia', 'Western Europe', 'Australia and Oceania', 'Central and South America', 'Western and South Asia', 'Eastern Europe'], True)

Cont_table_2C = pd.DataFrame({'Continent': unqID, 'Local Population ' + str(year_fut) + ' (millions)' : locp_year_fut_array, 
                              'Downstream Population year_fut (millions)': dwnp_year_fut_array, 
                              'Population Downstream of Areas Under High Climate Variability ' + str(year_fut) + ' (millions)' : dwnpop_CVyear_fut_2C_high_array, 
                              'Population Downstream of Areas Under High Water Security Threat '+ str(year_fut) + ' (millions)' : dwnpop_Tiyear_fut_2C_high_array, 
                              'Population Downstream of Areas Under Highly Impaired Natural Threat Reduction ' + str(year_fut) + ' (millions)' : dwnpop_TRnatyear_fut_2C_low_array, 
                              'Population Downstream of Areas Under Highly Impaired Engineered Threat Reduction '  + str(year_fut) +  ' (millions)' : dwnpop_TRengyear_fut_2C_low_array}, 
                             columns=['Continent', 'Local Population ' + str(year_fut) + ' (millions)',
                                      'Downstream Population ' + str(year_fut) + ' (millions)', 
                                      'Population Downstream of Areas Under High Climate Variability ' + str(year_fut) + ' (millions)', 
                                      'Population Downstream of Areas Under High Water Security Threat ' + str(year_fut) + ' (millions)', 
                                      'Population Downstream of Areas Under Highly Impaired Natural Threat Reduction ' + str(year_fut) + ' (millions)', 
                                      'Population Downstream of Areas Under Highly Impaired Engineered Threat Reduction ' + str(year_fut) + ' (millions)'])
Cont_table_2C.insert(1, "Continent Name", ['Other', 'Africa', 'North America', 'East and Southeast Asia', 'Western Europe', 'Australia and Oceania', 'Central and South America', 'Western and South Asia', 'Eastern Europe'], True)

Cont_table_4C = pd.DataFrame({'Continent': unqID, 'Local Population ' + str(year_fut) + ' (millions)' : locp_year_fut_array, 
                              'Downstream Population ' + str(year_fut) + ' (millions)': dwnp_year_fut_array, 
                              'Population Downstream of Areas Under High Climate Variability ' + str(year_fut) + ' (millions)' : dwnpop_CVyear_fut_4C_high_array, 
                              'Population Downstream of Areas Under High Water Security Threat ' + str(year_fut) + ' (millions)' : dwnpop_Tiyear_fut_4C_high_array, 
                              'Population Downstream of Areas Under Highly Impaired Natural Threat Reduction ' + str(year_fut) + ' (millions)' : dwnpop_TRnatyear_fut_4C_low_array, 
                              'Population Downstream of Areas Under Highly Impaired Engineered Threat Reduction ' + str(year_fut) + ' (millions)' : dwnpop_TRengyear_fut_4C_low_array}, 
                             columns=['Continent', 'Local Population ' + str(year_fut) + ' (millions)',
                                      'Downstream Population ' + str(year_fut) + ' (millions)', 
                                      'Population Downstream of Areas Under High Climate Variability ' + str(year_fut) + ' (millions)', 
                                      'Population Downstream of Areas Under High Water Security Threat ' + str(year_fut) + ' (millions)', 
                                      'Population Downstream of Areas Under Highly Impaired Natural Threat Reduction ' + str(year_fut) + ' (millions)', 
                                      'Population Downstream of Areas Under Highly Impaired Engineered Threat Reduction ' + str(year_fut) + ' (millions)'])
Cont_table_4C.insert(1, "Continent Name", ['Other', 'Africa', 'North America', 'East and Southeast Asia', 'Western Europe', 'Australia and Oceania', 'Central and South America', 'Western and South Asia', 'Eastern Europe'], True)

# %% [markdown]
# ## Extremely Dry Anomalies: Global and Continental Population Sums by Climate Vulnerability (<i>ClimVar<sub>contemp</sub> , ClimVar<sub>future</sub>></i>), <i>Climate Impacted Ti</i>, <i>Climate Impacted TRnat</i> and <i>Climate Impacted TReng</i>

# %%
print("Global sums - Extreme Dry ..")

area_2020_XDry = np.where(msk_Contemp_XDry > 0, CellArea6m, 0)
area_year_fut_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, CellArea6m, 0)
area_year_fut_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, CellArea6m, 0)

area_2020_frac = np.sum(np.where(msk_Contemp_XDry > 0, CellArea6m, 0)) / np.sum(CellArea6m)
area_year_fut_2C_frac = np.sum(np.where(msk_FutClim_2C_XDry > 0, CellArea6m, 0)) / np.sum(CellArea6m)
area_year_fut_4C_frac = np.sum(np.where(msk_FutClim_4C_XDry > 0, CellArea6m, 0)) / np.sum(CellArea6m)

pop2020_frac = np.sum(np.where(msk_Contemp_XDry > 0, pop2020, 0)) / np.sum(pop2020)
popyear_fut_2C_frac = np.sum(np.where(msk_FutClim_2C_XDry > 0, scaled_pop_year_fut, 0)) / np.sum(scaled_pop_year_fut)
popyear_fut_4C_frac = np.sum(np.where(msk_FutClim_4C_XDry > 0, scaled_pop_year_fut, 0)) / np.sum(scaled_pop_year_fut)

dwnpop2020_frac = np.sum(np.where(msk_Contemp_XDry > 0, dwnp_2020, 0)) / np.sum(dwnp_2020)
dwnpopyear_fut_2C_frac = np.sum(np.where(msk_FutClim_2C_XDry > 0, dwnp_year_fut, 0)) / np.sum(dwnp_year_fut)
dwnpopyear_fut_4C_frac = np.sum(np.where(msk_FutClim_4C_XDry > 0, dwnp_year_fut, 0)) / np.sum(dwnp_year_fut)

locp_2020_XDry = np.where(msk_Contemp_XDry > 0, pop2020, 0)
locp_year_fut_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, scaled_pop_year_fut, 0)
locp_year_fut_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, scaled_pop_year_fut, 0)

locp_2020_XDry_sum = np.sum(locp_2020_XDry) / 1000000000
locp_year_fut_2C_XDry_sum = np.sum(locp_year_fut_2C_XDry) / 1000000000
locp_year_fut_4C_XDry_sum = np.sum(locp_year_fut_4C_XDry) / 1000000000

dwnp_2020_XDry = np.where(msk_Contemp_XDry > 0, dwnp_2020, 0)
dwnp_year_fut_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnp_year_fut, 0)
dwnp_year_fut_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnp_year_fut, 0)

dwnpop_2020_XDry_sum = np.sum(dwnp_2020_XDry) / 1000000000
dwnpop_year_fut_2C_XDry_sum = np.sum(dwnp_year_fut_2C_XDry) / 1000000000
dwnpop_year_fut_4C_XDry_sum = np.sum(dwnp_year_fut_4C_XDry) / 1000000000

dwnpop_CV2020_high_global = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, dwnp_2020_XDry, 0))
dwnpop_Ti2020_high_global = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, dwnp_2020_XDry_nan, 0))
dwnpop_TRnat2020_low_global = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, dwnp_2020_XDry_nan, 0))
dwnpop_TReng2020_low_global = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, dwnp_2020_XDry_nan, 0))

dwnpop_CVyear_fut_2C_high_global = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut_2C_XDry, 0))
dwnpop_Tiyear_fut_2C_high_global = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_XDry_nan, 0))
dwnpop_TRnatyear_fut_2C_low_global = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_XDry_nan, 0))
dwnpop_TRengyear_fut_2C_low_global = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_XDry_nan, 0))

dwnpop_CVyear_fut_4C_high_global = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut_4C_XDry, 0))
dwnpop_Tiyear_fut_4C_high_global = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_XDry_nan, 0))
dwnpop_TRnatyear_fut_4C_low_global = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_XDry_nan, 0))
dwnpop_TRengyear_fut_4C_low_global = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_XDry_nan, 0))


CV_High_2020 = np.sum(dwnpop_CV2020_high_global) / 1000000000
Ti_High_2020 = np.sum(dwnpop_Ti2020_high_global) / 1000000000
TRnat_Low_2020 = np.sum(dwnpop_TRnat2020_low_global) / 1000000000
TReng_Low_2020 = np.sum(dwnpop_TReng2020_low_global) / 1000000000

CV_High_year_fut_2C = np.sum(dwnpop_CVyear_fut_2C_high_global) / 1000000000
Ti_High_year_fut_2C = np.sum(dwnpop_Tiyear_fut_2C_high_global) / 1000000000
TRnat_Low_year_fut_2C = np.sum(dwnpop_TRnatyear_fut_2C_low_global) / 1000000000
TReng_Low_year_fut_2C = np.sum(dwnpop_TRengyear_fut_2C_low_global) / 1000000000

CV_High_year_fut_4C = np.sum(dwnpop_CVyear_fut_4C_high_global) / 1000000000
Ti_High_year_fut_4C = np.sum(dwnpop_Tiyear_fut_4C_high_global) / 1000000000
TRnat_Low_year_fut_4C = np.sum(dwnpop_TRnatyear_fut_4C_low_global) / 1000000000
TReng_Low_year_fut_4C = np.sum(dwnpop_TRengyear_fut_4C_low_global) / 1000000000

df_global_Contemp_XDry = pd.DataFrame({'Year': ['2020'],
                   'Population (billions)': [locp_2020_XDry_sum],
                   'Fraction Land Area Under Extreme Dry/Wet': [area_2020_frac],
                   'Fraction Population Under Extreme Dry/Wet': [pop2020_frac],
                   'Downstream Population Served by Areas under High Climate Variability (billions)': [CV_High_2020], 
                   'Downstream Population Served by Areas under High Water Security Threat (billions)': [Ti_High_2020],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Natural Capital (billions)': [TRnat_Low_2020],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Engineering (billions)': [TReng_Low_2020]})

df_global_2C_XDry = pd.DataFrame({'Year': [str(year_fut) + ' +2C'],
                   'Population (billions)': [locp_year_fut_2C_XDry_sum],
                   'Fraction Land Area Under Extreme Dry/Wet': [area_year_fut_2C_frac],
                   'Fraction Population Under Extreme Dry/Wet': [popyear_fut_2C_frac],
                   'Downstream Population Served by Areas under High Climate Variability (billions)': [CV_High_year_fut_2C], 
                   'Downstream Population Served by Areas under High Water Security Threat (billions)': [Ti_High_year_fut_2C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Natural Capital (billions)': [TRnat_Low_year_fut_2C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Engineering (billions)': [TReng_Low_year_fut_2C]})

df_global_4C_XDry = pd.DataFrame({'Year': [str(year_fut) + ' +4C'],
                   'Population (billions)': [locp_year_fut_4C_XDry_sum],
                   'Fraction Land Area Under Extreme Dry/Wet': [area_year_fut_4C_frac],
                   'Fraction Population Under Extreme Dry/Wet': [popyear_fut_4C_frac],
                   'Downstream Population Served by Areas under High Climate Variability (billions)': [CV_High_year_fut_4C], 
                   'Downstream Population Served by Areas under High Water Security Threat (billions)': [Ti_High_year_fut_4C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Natural Capital (billions)': [TRnat_Low_year_fut_4C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Engineering (billions)': [TReng_Low_year_fut_4C]})

unqID,idx,IDsums = np.unique(gadm_cont,return_counts=True,return_inverse=True)

## Updated
area_total = np.bincount(idx,CellArea6m.ravel())
locp_2020_total = np.bincount(idx,pop2020.ravel())
locp_year_fut_total = np.bincount(idx,scaled_pop_year_fut.ravel())
dwnp_2020_total = np.bincount(idx,dwnp_2020.ravel())
dwnp_year_fut_total = np.bincount(idx,dwnp_year_fut.ravel())

area_2020_frac_array = np.bincount(idx,area_2020_XDry.ravel()) / area_total
area_year_fut_2C_frac_array = np.bincount(idx,area_year_fut_2C_XDry.ravel()) / area_total
area_year_fut_4C_frac_array = np.bincount(idx,area_year_fut_4C_XDry.ravel()) / area_total

locp_2020_frac_XDry_array = np.bincount(idx,locp_2020_XDry.ravel()) / locp_2020_total
locp_year_fut_2C_frac_XDry_array = np.bincount(idx,locp_year_fut_2C_XDry.ravel()) / locp_year_fut_total
locp_year_fut_4C_frac_XDry_array = np.bincount(idx,locp_year_fut_4C_XDry.ravel()) / locp_year_fut_total

dwnp_2020_frac_XDry_array = np.bincount(idx,dwnp_2020_XDry.ravel()) / dwnp_2020_total
dwnp_year_fut_2C_frac_XDry_array = np.bincount(idx,dwnp_year_fut_2C_XDry.ravel()) / dwnp_year_fut_total
dwnp_year_fut_4C_frac_XDry_array = np.bincount(idx,dwnp_year_fut_4C_XDry.ravel()) / dwnp_year_fut_total
## Updated

locp_2020_XDry_array = np.bincount(idx,locp_2020_XDry.ravel()) / 1000000
locp_year_fut_2C_XDry_array = np.bincount(idx,locp_year_fut_2C_XDry.ravel()) / 1000000
locp_year_fut_4C_XDry_array = np.bincount(idx,locp_year_fut_4C_XDry.ravel()) / 1000000

dwnp_2020_XDry_array = np.bincount(idx,dwnp_2020_XDry.ravel()) / 1000000
dwnp_year_fut_2C_XDry_array = np.bincount(idx,dwnp_year_fut_2C_XDry.ravel()) / 1000000
dwnp_year_fut_4C_XDry_array = np.bincount(idx,dwnp_year_fut_4C_XDry.ravel()) / 1000000

dwnpop_CV2020_high_array = np.bincount(idx,dwnpop_CV2020_high_global.ravel()) / 1000000
dwnpop_Ti2020_high_array = np.bincount(idx,dwnpop_Ti2020_high_global.ravel()) / 1000000
dwnpop_TRnat2020_low_array = np.bincount(idx,dwnpop_TRnat2020_low_global.ravel()) / 1000000
dwnpop_TReng2020_low_array = np.bincount(idx,dwnpop_TReng2020_low_global.ravel()) / 1000000

dwnpop_CVyear_fut_2C_high_array = np.bincount(idx,dwnpop_CVyear_fut_2C_high_global.ravel()) / 1000000
dwnpop_Tiyear_fut_2C_high_array = np.bincount(idx,dwnpop_Tiyear_fut_2C_high_global.ravel()) / 1000000
dwnpop_TRnatyear_fut_2C_low_array = np.bincount(idx,dwnpop_TRnatyear_fut_2C_low_global.ravel()) / 1000000
dwnpop_TRengyear_fut_2C_low_array = np.bincount(idx,dwnpop_TRengyear_fut_2C_low_global.ravel()) / 1000000

dwnpop_CVyear_fut_4C_high_array = np.bincount(idx,dwnpop_CVyear_fut_4C_high_global.ravel()) / 1000000
dwnpop_Tiyear_fut_4C_high_array = np.bincount(idx,dwnpop_Tiyear_fut_4C_high_global.ravel()) / 1000000
dwnpop_TRnatyear_fut_4C_low_array = np.bincount(idx,dwnpop_TRnatyear_fut_4C_low_global.ravel()) / 1000000
dwnpop_TRengyear_fut_4C_low_array = np.bincount(idx,dwnpop_TRengyear_fut_4C_low_global.ravel()) / 1000000

Cont_table_Contemp = pd.DataFrame({'Continent': unqID, 'Local Population 2020 (millions)' : locp_2020_XDry_array, 
                                   'Downstream Population 2020 (millions)' : dwnp_2020_XDry_array, 
                                   'Under High Climate Variability 2020 (millions)' : dwnpop_CV2020_high_array, 
                                   'Under High Water Security Threat 2020 (millions)' : dwnpop_Ti2020_high_array, 
                                   'Under Highly Impaired Natural Threat Reduction 2020 (millions)' : dwnpop_TRnat2020_low_array,
                                   'Under Highly Impaired Engineered Threat Reduction 2020 (millions)' : dwnpop_TReng2020_low_array}, 
                                  columns=['Continent', 'Local Population 2020 (millions)', 
                                           'Downstream Population 2020 (millions)', 
                                           'Under High Climate Variability 2020 (millions)', 
                                           'Under High Water Security Threat 2020 (millions)', 
                                           'Under Highly Impaired Natural Threat Reduction 2020 (millions)', 
                                           'Under Highly Impaired Engineered Threat Reduction 2020 (millions)'])
Cont_table_Contemp.insert(1, "Continent Name", ['Other', 'Africa', 'North America', 'East and Southeast Asia', 'Western Europe', 'Australia and Oceania', 'Central and South America', 'Western and South Asia', 'Eastern Europe'], True)


Cont_table_2C = pd.DataFrame({'Continent': unqID, 'Local Population ' + str(year_fut) + ' (millions)' : locp_year_fut_2C_XDry_array, 
                              'Downstream Population ' + str(year_fut) + ' (millions)': dwnp_year_fut_2C_XDry_array, 
                              'Under High Climate Variability ' + str(year_fut) + ' (millions)' : dwnpop_CVyear_fut_2C_high_array, 
                              'Under High Water Security Threat ' + str(year_fut) + ' (millions)' : dwnpop_Tiyear_fut_2C_high_array, 
                              'Under Highly Impaired Natural Threat Reduction ' + str(year_fut) + ' (millions)' : dwnpop_TRnatyear_fut_2C_low_array, 
                              'Under Highly Impaired Engineered Threat Reduction ' + str(year_fut) + ' (millions)' : dwnpop_TRengyear_fut_2C_low_array}, 
                             columns=['Continent', 'Local Population ' + str(year_fut) + ' (millions)',
                                      'Downstream Population ' + str(year_fut) + ' (millions)', 
                                      'Under High Climate Variability ' + str(year_fut) + ' (millions)', 
                                      'Under High Water Security Threat ' + str(year_fut) + ' (millions)', 
                                      'Under Highly Impaired Natural Threat Reduction ' + str(year_fut) + ' (millions)', 
                                      'Under Highly Impaired Engineered Threat Reduction ' + str(year_fut) + ' (millions)'])
Cont_table_2C.insert(1, "Continent Name", ['Other', 'Africa', 'North America', 'East and Southeast Asia', 'Western Europe', 'Australia and Oceania', 'Central and South America', 'Western and South Asia', 'Eastern Europe'], True)

Cont_table_4C = pd.DataFrame({'Continent': unqID, 'Local Population ' + str(year_fut) + ' (millions)' : locp_year_fut_4C_XDry_array, 
                              'Downstream Population ' + str(year_fut) + ' (millions)': dwnp_year_fut_4C_XDry_array, 
                              'Under High Climate Variability ' + str(year_fut) + ' (millions)' : dwnpop_CVyear_fut_4C_high_array, 
                              'Under High Water Security Threat ' + str(year_fut) + ' (millions)' : dwnpop_Tiyear_fut_4C_high_array, 
                              'Under Highly Impaired Natural Threat Reduction ' + str(year_fut) + ' (millions)' : dwnpop_TRnatyear_fut_4C_low_array, 
                              'Under Highly Impaired Engineered Threat Reduction ' + str(year_fut) + ' (millions)' : dwnpop_TRengyear_fut_4C_low_array}, 
                             columns=['Continent', 'Local Population ' + str(year_fut) + ' (millions)',
                                      'Downstream Population ' + str(year_fut) + ' (millions)', 
                                      'Under High Climate Variability ' + str(year_fut) + ' (millions)', 
                                      'Under High Water Security Threat ' + str(year_fut) + ' (millions)', 
                                      'Under Highly Impaired Natural Threat Reduction ' + str(year_fut) + ' (millions)', 
                                      'Under Highly Impaired Engineered Threat Reduction ' + str(year_fut) + ' (millions)'])
Cont_table_4C.insert(1, "Continent Name", ['Other', 'Africa', 'North America', 'East and Southeast Asia', 'Western Europe', 'Australia and Oceania', 'Central and South America', 'Western and South Asia', 'Eastern Europe'], True)

# %% [markdown]
# ## Extremely Wet Anomalies: Global and Continental Population Sums by Climate Vulnerability (<i>ClimVar<sub>contemp</sub> , ClimVar<sub>future</sub>></i>), <i>Climate Impacted Ti</i>, <i>Climate Impacted TRnat</i> and <i>Climate Impacted TReng</i>

# %%
print("Global sums - Extreme Wet ..")

area_2020_frac = np.sum(np.where(msk_Contemp_XWet > 0, CellArea6m, 0)) / np.sum(CellArea6m)
area_year_fut_2C_frac = np.sum(np.where(msk_FutClim_2C_XWet > 0, CellArea6m, 0)) / np.sum(CellArea6m)
area_year_fut_4C_frac = np.sum(np.where(msk_FutClim_4C_XWet > 0, CellArea6m, 0)) / np.sum(CellArea6m)

pop2020_frac = np.sum(np.where(msk_Contemp_XWet > 0, pop2020, 0)) / np.sum(pop2020)
popyear_fut_2C_frac = np.sum(np.where(msk_FutClim_2C_XWet > 0, scaled_pop_year_fut, 0)) / np.sum(scaled_pop_year_fut)
popyear_fut_4C_frac = np.sum(np.where(msk_FutClim_4C_XWet > 0, scaled_pop_year_fut, 0)) / np.sum(scaled_pop_year_fut)

dwnpop2020_frac = np.sum(np.where(msk_Contemp_XWet > 0, dwnp_2020, 0)) / np.sum(dwnp_2020)
dwnpopyear_fut_2C_frac = np.sum(np.where(msk_FutClim_2C_XWet > 0, dwnp_year_fut, 0)) / np.sum(dwnp_year_fut)
dwnpopyear_fut_4C_frac = np.sum(np.where(msk_FutClim_4C_XWet > 0, dwnp_year_fut, 0)) / np.sum(dwnp_year_fut)

area_2020_XWet = np.where(msk_Contemp_XWet > 0, CellArea6m, 0)
area_year_fut_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, CellArea6m, 0)
area_year_fut_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, CellArea6m, 0)

locp_2020_XWet = np.where(msk_Contemp_XWet > 0, pop2020, 0)
locp_year_fut_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, scaled_pop_year_fut, 0)
locp_year_fut_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, scaled_pop_year_fut, 0)

dwnp_2020_XWet = np.where(msk_Contemp_XWet > 0, dwnp_2020, 0)
dwnp_year_fut_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnp_year_fut, 0)
dwnp_year_fut_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnp_year_fut, 0)

dwnpop_2020_XWet_sum = np.sum(dwnp_2020_XWet) / 1000000000
dwnpop_year_fut_2C_XWet_sum = np.sum(dwnp_year_fut_2C_XWet) / 1000000000
dwnpop_year_fut_4C_XWet_sum = np.sum(dwnp_year_fut_4C_XWet) / 1000000000

dwnpop_CV2020_high_global = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, dwnp_2020_XWet, 0))
dwnpop_Ti2020_high_global = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, dwnp_2020_XWet_nan, 0))
dwnpop_TRnat2020_low_global = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, dwnp_2020_XWet_nan, 0))
dwnpop_TReng2020_low_global = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, dwnp_2020_XWet_nan, 0))

dwnpop_CVyear_fut_2C_high_global = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut_2C_XWet, 0))
dwnpop_Tiyear_fut_2C_high_global = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_XWet_nan, 0))
dwnpop_TRnatyear_fut_2C_low_global = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_XWet_nan, 0))
dwnpop_TRengyear_fut_2C_low_global = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_XWet_nan, 0))

dwnpop_CVyear_fut_4C_high_global = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut_4C_XWet, 0))
dwnpop_Tiyear_fut_4C_high_global = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_XWet_nan, 0))
dwnpop_TRnatyear_fut_4C_low_global = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_XWet_nan, 0))
dwnpop_TRengyear_fut_4C_low_global = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_XWet_nan, 0))

CV_High_2020 = np.sum(dwnpop_CV2020_high_global) / 1000000000
Ti_High_2020 = np.sum(dwnpop_Ti2020_high_global) / 1000000000
TRnat_Low_2020 = np.sum(dwnpop_TRnat2020_low_global) / 1000000000
TReng_Low_2020 = np.sum(dwnpop_TReng2020_low_global) / 1000000000

CV_High_year_fut_2C = np.sum(dwnpop_CVyear_fut_2C_high_global) / 1000000000
Ti_High_year_fut_2C = np.sum(dwnpop_Tiyear_fut_2C_high_global) / 1000000000
TRnat_Low_year_fut_2C = np.sum(dwnpop_TRnatyear_fut_2C_low_global) / 1000000000
TReng_Low_year_fut_2C = np.sum(dwnpop_TRengyear_fut_2C_low_global) / 1000000000

CV_High_year_fut_4C = np.sum(dwnpop_CVyear_fut_4C_high_global) / 1000000000
Ti_High_year_fut_4C = np.sum(dwnpop_Tiyear_fut_4C_high_global) / 1000000000
TRnat_Low_year_fut_4C = np.sum(dwnpop_TRnatyear_fut_4C_low_global) / 1000000000
TReng_Low_year_fut_4C = np.sum(dwnpop_TRengyear_fut_4C_low_global) / 1000000000

df_global_Contemp_XWet = pd.DataFrame({'Year': ['2020'],
                   'Population (billions)': [dwnpop_2020_XWet_sum],
                   'Fraction Land Area Under Extreme Wet/Wet': [area_2020_frac],
                   'Fraction Population Under Extreme Wet/Wet': [pop2020_frac],
                   'Downstream Population Served by Areas under High Climate Variability (billions)': [CV_High_2020], 
                   'Downstream Population Served by Areas under High Water Security Threat (billions)': [Ti_High_2020],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Natural Capital (billions)': [TRnat_Low_2020],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Engineering (billions)': [TReng_Low_2020]})

df_global_2C_XWet = pd.DataFrame({'Year': [str(year_fut) + ' +2C'],
                   'Population (billions)': [dwnpop_year_fut_2C_XWet_sum],
                   'Fraction Land Area Under Extreme Wet/Wet': [area_year_fut_2C_frac],
                   'Fraction Population Under Extreme Wet/Wet': [popyear_fut_2C_frac],
                   'Downstream Population Served by Areas under High Climate Variability (billions)': [CV_High_year_fut_2C], 
                   'Downstream Population Served by Areas under High Water Security Threat (billions)': [Ti_High_year_fut_2C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Natural Capital (billions)': [TRnat_Low_year_fut_2C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Engineering (billions)': [TReng_Low_year_fut_2C]})

df_global_4C_XWet = pd.DataFrame({'Year': [str(year_fut) + ' +4C'],
                   'Population (billions)': [dwnpop_year_fut_4C_XWet_sum],
                   'Fraction Land Area Under Extreme Wet/Wet': [area_year_fut_4C_frac],
                   'Fraction Population Under Extreme Wet/Wet': [popyear_fut_4C_frac],
                   'Downstream Population Served by Areas under High Climate Variability (billions)': [CV_High_year_fut_4C], 
                   'Downstream Population Served by Areas under High Water Security Threat (billions)': [Ti_High_year_fut_4C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Natural Capital (billions)': [TRnat_Low_year_fut_4C],
                   'Downstream Population Served by Areas under Low Capacity for Threat Reduction by Engineering (billions)': [TReng_Low_year_fut_4C]})

unqID,idx,IDsums = np.unique(gadm_cont,return_counts=True,return_inverse=True)

## Updated
area_total = np.bincount(idx,CellArea6m.ravel())
locp_2020_total = np.bincount(idx,pop2020.ravel())
locp_year_fut_total = np.bincount(idx,scaled_pop_year_fut.ravel())
dwnp_2020_total = np.bincount(idx,dwnp_2020.ravel())
dwnp_year_fut_total = np.bincount(idx,dwnp_year_fut.ravel())

area_2020_frac_array = np.bincount(idx,area_2020_XWet.ravel()) / area_total
area_year_fut_2C_frac_array = np.bincount(idx,area_2020_XWet.ravel()) / area_total
area_year_fut_4C_frac_array = np.bincount(idx,area_2020_XWet.ravel()) / area_total

locp_2020_frac_XWet_array = np.bincount(idx,locp_2020_XWet.ravel()) / locp_2020_total
locp_year_fut_2C_frac_XWet_array = np.bincount(idx,locp_year_fut_2C_XWet.ravel()) / locp_year_fut_total
locp_year_fut_4C_frac_XWet_array = np.bincount(idx,locp_year_fut_4C_XWet.ravel()) / locp_year_fut_total

dwnp_2020_frac_XWet_array = np.bincount(idx,dwnp_2020_XWet.ravel()) / dwnp_2020_total
dwnp_year_fut_2C_frac_XWet_array = np.bincount(idx,dwnp_year_fut_2C_XWet.ravel()) / dwnp_year_fut_total
dwnp_year_fut_4C_frac_XWet_array = np.bincount(idx,dwnp_year_fut_4C_XWet.ravel()) / dwnp_year_fut_total
## Updated

locp_2020_XWet_array = np.bincount(idx,locp_2020_XWet.ravel()) / 1000000
locp_year_fut_2C_XWet_array = np.bincount(idx,locp_year_fut_2C_XWet.ravel()) / 1000000
locp_year_fut_4C_XWet_array = np.bincount(idx,locp_year_fut_4C_XWet.ravel()) / 1000000

dwnp_2020_XWet_array = np.bincount(idx,dwnp_2020_XWet.ravel()) / 1000000
dwnp_year_fut_2C_XWet_array = np.bincount(idx,dwnp_year_fut_2C_XWet.ravel()) / 1000000
dwnp_year_fut_4C_XWet_array = np.bincount(idx,dwnp_year_fut_4C_XWet.ravel()) / 1000000

dwnpop_CV2020_high_array = np.bincount(idx,dwnpop_CV2020_high_global.ravel()) / 1000000
dwnpop_Ti2020_high_array = np.bincount(idx,dwnpop_Ti2020_high_global.ravel()) / 1000000
dwnpop_TRnat2020_low_array = np.bincount(idx,dwnpop_TRnat2020_low_global.ravel()) / 1000000
dwnpop_TReng2020_low_array = np.bincount(idx,dwnpop_TReng2020_low_global.ravel()) / 1000000

dwnpop_CVyear_fut_2C_high_array = np.bincount(idx,dwnpop_CVyear_fut_2C_high_global.ravel()) / 1000000
dwnpop_Tiyear_fut_2C_high_array = np.bincount(idx,dwnpop_Tiyear_fut_2C_high_global.ravel()) / 1000000
dwnpop_TRnatyear_fut_2C_low_array = np.bincount(idx,dwnpop_TRnatyear_fut_2C_low_global.ravel()) / 1000000
dwnpop_TRengyear_fut_2C_low_array = np.bincount(idx,dwnpop_TRengyear_fut_2C_low_global.ravel()) / 1000000

dwnpop_CVyear_fut_4C_high_array = np.bincount(idx,dwnpop_CVyear_fut_4C_high_global.ravel()) / 1000000
dwnpop_Tiyear_fut_4C_high_array = np.bincount(idx,dwnpop_Tiyear_fut_4C_high_global.ravel()) / 1000000
dwnpop_TRnatyear_fut_4C_low_array = np.bincount(idx,dwnpop_TRnatyear_fut_4C_low_global.ravel()) / 1000000
dwnpop_TRengyear_fut_4C_low_array = np.bincount(idx,dwnpop_TRengyear_fut_4C_low_global.ravel()) / 1000000

Cont_table_Contemp_XWet = pd.DataFrame({'Continent': unqID, 'Local Population 2020 (millions)' : locp_2020_XWet_array, 
                                   'Downstream Population 2020 (millions)' : dwnp_2020_XWet_array, 
                                   'Under High Climate Variability 2020 (millions)' : dwnpop_CV2020_high_array, 
                                   'Under High Water Security Threat 2020 (millions)' : dwnpop_Ti2020_high_array, 
                                   'Under Highly Impaired Natural Threat Reduction 2020 (millions)' : dwnpop_TRnat2020_low_array,
                                   'Under Highly Impaired Engineered Threat Reduction 2020 (millions)' : dwnpop_TReng2020_low_array}, 
                                  columns=['Continent', 'Local Population 2020 (millions)', 
                                           'Downstream Population 2020 (millions)', 
                                           'Under High Climate Variability 2020 (millions)', 
                                           'Under High Water Security Threat 2020 (millions)', 
                                           'Under Highly Impaired Natural Threat Reduction 2020 (millions)', 
                                           'Under Highly Impaired Engineered Threat Reduction 2020 (millions)'])
Cont_table_Contemp_XWet.insert(1, "Continent Name", ['Other', 'Africa', 'North America', 'East and Southeast Asia', 'Western Europe', 'Australia and Oceania', 'Central and South America', 'Western and South Asia', 'Eastern Europe'], True)


Cont_table_2C_XWet = pd.DataFrame({'Continent': unqID, 'Local Population ' + str(year_fut) + ' (millions)' : locp_year_fut_2C_XWet_array, 
                              'Downstream Population ' + str(year_fut) + ' (millions)': dwnp_year_fut_2C_XWet_array, 
                              'Under High Climate Variability ' + str(year_fut) + ' (millions)' : dwnpop_CVyear_fut_2C_high_array, 
                              'Under High Water Security Threat ' + str(year_fut) + ' (millions)' : dwnpop_Tiyear_fut_2C_high_array, 
                              'Under Highly Impaired Natural Threat Reduction ' + str(year_fut) + ' (millions)' : dwnpop_TRnatyear_fut_2C_low_array, 
                              'Under Highly Impaired Engineered Threat Reduction ' + str(year_fut) + ' (millions)' : dwnpop_TRengyear_fut_2C_low_array}, 
                             columns=['Continent', 'Local Population ' + str(year_fut) + ' (millions)',
                                      'Downstream Population ' + str(year_fut) + ' (millions)', 
                                      'Under High Climate Variability ' + str(year_fut) + ' (millions)', 
                                      'Under High Water Security Threat ' + str(year_fut) + ' (millions)', 
                                      'Under Highly Impaired Natural Threat Reduction ' + str(year_fut) + ' (millions)', 
                                      'Under Highly Impaired Engineered Threat Reduction ' + str(year_fut) + ' (millions)'])
Cont_table_2C_XWet.insert(1, "Continent Name", ['Other', 'Africa', 'North America', 'East and Southeast Asia', 'Western Europe', 'Australia and Oceania', 'Central and South America', 'Western and South Asia', 'Eastern Europe'], True)

Cont_table_4C_XWet = pd.DataFrame({'Continent': unqID, 'Local Population ' + str(year_fut) + ' (millions)' : locp_year_fut_4C_XWet_array, 
                              'Downstream Population ' + str(year_fut) + ' (millions)': dwnp_year_fut_4C_XWet_array, 
                              'Under High Climate Variability ' + str(year_fut) + ' (millions)' : dwnpop_CVyear_fut_4C_high_array, 
                              'Under High Water Security Threat ' + str(year_fut) + ' (millions)' : dwnpop_Tiyear_fut_4C_high_array, 
                              'Under Highly Impaired Natural Threat Reduction ' + str(year_fut) + ' (millions)' : dwnpop_TRnatyear_fut_4C_low_array, 
                              'Under Highly Impaired Engineered Threat Reduction ' + str(year_fut) + ' (millions)' : dwnpop_TRengyear_fut_4C_low_array}, 
                             columns=['Continent', 'Local Population ' + str(year_fut) + ' (millions)',
                                      'Downstream Population ' + str(year_fut) + ' (millions)', 
                                      'Under High Climate Variability ' + str(year_fut) + ' (millions)', 
                                      'Under High Water Security Threat ' + str(year_fut) + ' (millions)', 
                                      'Under Highly Impaired Natural Threat Reduction ' + str(year_fut) + ' (millions)', 
                                      'Under Highly Impaired Engineered Threat Reduction ' + str(year_fut) + ' (millions)'])
Cont_table_4C_XWet.insert(1, "Continent Name", ['Other', 'Africa', 'North America', 'East and Southeast Asia', 'Western Europe', 'Australia and Oceania', 'Central and South America', 'Western and South Asia', 'Eastern Europe'], True)

# %% [markdown]
# ## Make Composite Global Stats table - Contemp, 2C, 4C, XDry, XWet

# %%
global_txt_row = pd.DataFrame({'Name': ['Global Sums'], 'B1': [''], 'B2': [''], 'B3': [''], 'B4': [''], 'B5': [''], 'B6': [''], 'B7': ['']})
dry_txt_row = pd.DataFrame({'Name': ['Areas with Extreme Dry Anomalies'], 'B1': [''], 'B2': [''], 'B3': [''], 'B4': [''], 'B5': [''], 'B6': [''], 'B7': ['']})
wet_txt_row = pd.DataFrame({'Name': ['Areas with Extreme Wet Anomalies'], 'B1': [''], 'B2': [''], 'B3': [''], 'B4': [''], 'B5': [''], 'B6': [''], 'B7': ['']})

filenmXL = out_dir + 'Model_Global_AggrVariables_data_' + str(year_fut) + '.xlsx'
with pd.ExcelWriter(filenmXL) as writer:
    global_txt_row.to_excel(writer, index=False, sheet_name='Global', header=['Year', 'Population (billions)', 'Percent Land Area Under Extreme Dry/Wet', 'Percent Population Under Extreme Dry/Wet', 'Population Downstream of Areas Under High Climate Variability (billions)', 'Population Downstream of Areas Under High Water Security Threat (billions)','Population Downstream of Areas Under Highly Impaired Natural Threat Reduction (billions)', 'Population Downstream of Areas Under Highly Impaired Engineered Threat Reduction (billions)'])
    df_global_Contemp_global.to_excel(writer, startrow = 2,index = False, sheet_name='Global', header = False)
    df_global_2C_global.to_excel(writer, startrow = 3,index = False, sheet_name='Global', header = False)
    df_global_4C_global.to_excel(writer, startrow = 4,index = False, sheet_name='Global', header = False)
    dry_txt_row.to_excel(writer, startrow = 5,index = False, sheet_name='Global', header = False)
    df_global_Contemp_XDry.to_excel(writer, startrow = 6,index = False, sheet_name='Global', header = False)
    df_global_2C_XDry.to_excel(writer, startrow = 7,index = False, sheet_name='Global', header = False)
    df_global_4C_XDry.to_excel(writer, startrow = 8,index = False, sheet_name='Global', header = False)
    wet_txt_row.to_excel(writer, startrow = 9,index = False, sheet_name='Global', header = False)
    df_global_Contemp_XWet.to_excel(writer, startrow = 10,index = False, sheet_name='Global', header = False)
    df_global_2C_XWet.to_excel(writer, startrow = 11,index = False, sheet_name='Global', header = False)
    df_global_4C_XWet.to_excel(writer, startrow = 12,index = False, sheet_name='Global', header = False)

# %% [markdown]
# # Sub-National Administrative Unit Aggregations - two choices for adminstrative units applied
# - Bin grid cell level data into sub-national units by array zones using bincount
# - Combine binned data into a pandas dataframe
# - Write to MSExcel file

# %%
for x in range(1, 3):
#    np.seterr(divide='ignore')
    if x == 1:
        adm = "GDL"
        fin = '/asrc/ecr/pamela/model/python/GDL_ObjectID_6m.tif'
        print(f'{adm} aggr..')
    if x == 2:
        adm = "IR"
        fin = out_dir + 'IR_regions_Model.tif'
        print(f'{adm} aggr..')

    ds = gdal.Open(str(fin))
    model_adm = np.array(ds.GetRasterBand(1).ReadAsArray())
    model_adm[np.isnan(model_adm)] = 0

    #
    # DO SUB-NATIONAL AGGREGATION OF GRID CELL DATA AND COMBINE IN DATAFRAME
    #

    print('Summing Variables by Earlier Model Sub-national\n')
    # CREATE ARRAY ZONES BASED ON FID FROM model_adm Model SUB-NATIONAL GRID
    unqID,idx,IDsums = np.unique(model_adm,return_counts=True,return_inverse=True)

    # CREATE SUMS OVER ARRAY ZONES
    pop2020_array = np.bincount(idx,np.where(np.isnan(pop2020), 0, pop2020).ravel())
    popyear_fut_array = np.bincount(idx,np.where(np.isnan(scaled_pop_year_fut), 0, scaled_pop_year_fut).ravel())
    dwnpop2020_array = np.bincount(idx,np.where(np.isnan(dwnp_2020), 0, dwnp_2020).ravel())
    dwnpopyear_fut_array = np.bincount(idx,np.where(np.isnan(dwnp_year_fut), 0, dwnp_year_fut).ravel())
    area_array = np.bincount(idx,CellArea6m.ravel())
    popden2020_array = pop2020_array / area_array
    popdenyear_fut_array = popyear_fut_array / area_array
    
    print("  Calculating means over admins..")
    # Contemp Indicator averages, arithmetic mean and pop weighted
    with np.errstate(all='ignore'):       

        keep = np.where(np.isnan(TS_Contemp_CV_CDF), 0, TS_Contemp_CV_CDF)
        cnt = np.bincount(idx,np.where(flow_mask == 1.0, 0.0, np.where(keep > 0, 1, 0)).ravel())
        ClimVarCont_mean = np.where(cnt == 0, 0, np.bincount(idx,keep.ravel()) / cnt)
        ClimVarCont_wgt = np.where(pop2020_array == 0, 0, np.bincount(idx,(keep * pop2020).ravel()) / pop2020_array)
        
        keep = np.where(np.isnan(Ti_ClimVul_2005_CDF), 0, Ti_ClimVul_2005_CDF)
        cnt = np.bincount(idx,np.where(flow_mask == 1.0, 0.0, np.where(keep > 0, 1, 0)).ravel())
        ClimTiCont_mean = np.where(cnt == 0, 0, np.bincount(idx,keep.ravel()) / cnt)
        ClimTiCont_wgt = np.where(pop2020_array == 0, 0, np.bincount(idx,(keep * pop2020).ravel()) / pop2020_array)
        
        keep = np.where(np.isnan(TRnat_ClimVul_2005_CDF), 0, TRnat_ClimVul_2005_CDF)
        cnt = np.bincount(idx,np.where(flow_mask == 1.0, 0.0, np.where(keep > 0, 1, 0)).ravel())
        ClimTRnatCont_mean = np.where(cnt == 0, 0, np.bincount(idx,keep.ravel()) / cnt)
        ClimTRnatCont_wgt = np.where(pop2020_array == 0, 0, np.bincount(idx,(keep * pop2020).ravel()) / pop2020_array)
        
        keep = np.where(np.isnan(TReng_ClimVul_2005_CDF), 0, TReng_ClimVul_2005_CDF)
        cnt = np.bincount(idx,np.where(flow_mask == 1.0, 0.0, np.where(keep > 0, 1, 0)).ravel())
        ClimTRengCont_mean = np.where(cnt == 0, 0, np.bincount(idx,keep.ravel()) / cnt)
        ClimTRengCont_wgt = np.where(pop2020_array == 0, 0, np.bincount(idx,(keep * pop2020).ravel()) / pop2020_array)
        
    # 2C Indicator averages, arithmetic mean and pop weighted
    with np.errstate(all='ignore'):
        
        keep = np.where(np.isnan(TS_FutClim_2C_CV_CDF), 0, TS_FutClim_2C_CV_CDF)
        cnt = np.bincount(idx,np.where(flow_mask == 1.0, 0.0, np.where(keep > 0, 1, 0)).ravel())
        ClimVarFut_2C_mean = np.where(cnt == 0, 0, np.bincount(idx,keep.ravel()) / cnt)
        ClimVarFut_2C_wgt = np.where(pop2020_array == 0, 0, np.bincount(idx,(keep * pop2020).ravel()) / pop2020_array)
        
        keep = np.where(np.isnan(Ti_ClimVul_year_fut_2C_CDF), 0, Ti_ClimVul_year_fut_2C_CDF)
        cnt = np.bincount(idx,np.where(flow_mask == 1.0, 0.0, np.where(keep > 0, 1, 0)).ravel())
        ClimTiFut_2C_mean = np.where(cnt == 0, 0, np.bincount(idx,keep.ravel()) / cnt)
        ClimTiFut_2C_wgt = np.where(pop2020_array == 0, 0, np.bincount(idx,(keep * pop2020).ravel()) / pop2020_array)
        
        keep = np.where(np.isnan(TRnat_ClimVul_year_fut_2C_CDF), 0, TRnat_ClimVul_year_fut_2C_CDF)
        cnt = np.bincount(idx,np.where(flow_mask == 1.0, 0.0, np.where(keep > 0, 1, 0)).ravel())
        ClimTRnatFut_2C_mean = np.where(cnt == 0, 0, np.bincount(idx,keep.ravel()) / cnt)
        ClimTRnatFut_2C_wgt = np.where(pop2020_array == 0, 0, np.bincount(idx,(keep * pop2020).ravel()) / pop2020_array)
        
        keep = np.where(np.isnan(TReng_ClimVul_year_fut_2C_CDF), 0, TReng_ClimVul_year_fut_2C_CDF)
        cnt = np.bincount(idx,np.where(flow_mask == 1.0, 0.0, np.where(keep > 0, 1, 0)).ravel())
        ClimTRengFut_2C_mean = np.where(cnt == 0, 0, np.bincount(idx,keep.ravel()) / cnt)
        ClimTRengFut_2C_wgt = np.where(pop2020_array == 0, 0, np.bincount(idx,(keep * pop2020).ravel()) / pop2020_array)
        
    # 4C Indicator averages, arithmetic mean and pop weighted
    with np.errstate(all='ignore'):
    
        keep = np.where(np.isnan(TS_FutClim_4C_CV_CDF), 0, TS_FutClim_4C_CV_CDF)
        cnt = np.bincount(idx,np.where(flow_mask == 1.0, 0.0, np.where(keep > 0, 1, 0)).ravel())
        ClimVarFut_4C_mean = np.where(cnt == 0, 0, np.bincount(idx,keep.ravel()) / cnt)
        ClimVarFut_4C_wgt = np.where(pop2020_array == 0, 0, np.bincount(idx,(keep * pop2020).ravel()) / pop2020_array)
        
        keep = np.where(np.isnan(Ti_ClimVul_year_fut_4C_CDF), 0, Ti_ClimVul_year_fut_4C_CDF)
        cnt = np.bincount(idx,np.where(flow_mask == 1.0, 0.0, np.where(keep > 0, 1, 0)).ravel())
        ClimTiFut_4C_mean = np.where(cnt == 0, 0, np.bincount(idx,keep.ravel()) / cnt)
        ClimTiFut_4C_wgt = np.where(pop2020_array == 0, 0, np.bincount(idx,(keep * pop2020).ravel()) / pop2020_array)
        
        keep = np.where(np.isnan(TRnat_ClimVul_year_fut_4C_CDF), 0, TRnat_ClimVul_year_fut_4C_CDF)
        cnt = np.bincount(idx,np.where(flow_mask == 1.0, 0.0, np.where(keep > 0, 1, 0)).ravel())
        ClimTRnatFut_4C_mean = np.where(cnt == 0, 0, np.bincount(idx,keep.ravel()) / cnt)
        ClimTRnatFut_4C_wgt = np.where(pop2020_array == 0, 0, np.bincount(idx,(keep * pop2020).ravel()) / pop2020_array)
        
        keep = np.where(np.isnan(TReng_ClimVul_year_fut_4C_CDF), 0, TReng_ClimVul_year_fut_4C_CDF)
        cnt = np.bincount(idx,np.where(flow_mask == 1.0, 0.0, np.where(keep > 0, 1, 0)).ravel())
        ClimTRengFut_4C_mean = np.where(cnt == 0, 0, np.bincount(idx,keep.ravel()) / cnt)
        ClimTRengFut_4C_wgt = np.where(pop2020_array == 0, 0, np.bincount(idx,(keep * pop2020).ravel()) / pop2020_array)

    print("  Summing downstream pops for low-mod-high over admins..")
    # Contemp sum downpop by indicators

    dwnpopHIGH_ClimVarCont_array = np.bincount(idx,dwnpop_CV2020_high.ravel())
    dwnpopHIGH_ClimTiCont_array = np.bincount(idx,dwnpop_Ti2020_high.ravel())
    dwnpopHIGH_ClimTRnatCont_array = np.bincount(idx,dwnpop_TRnat2020_high.ravel())
    dwnpopHIGH_ClimTRengCont_array = np.bincount(idx,dwnpop_TReng2020_high.ravel())

    dwnpopMOD_ClimVarCont_array = np.bincount(idx,dwnpop_CV2020_mod.ravel())
    dwnpopMOD_ClimTiCont_array = np.bincount(idx,dwnpop_Ti2020_mod.ravel())
    dwnpopMOD_ClimTRnatCont_array = np.bincount(idx,dwnpop_TRnat2020_mod.ravel())
    dwnpopMOD_ClimTRengCont_array = np.bincount(idx,dwnpop_TReng2020_mod.ravel())
    
    dwnpopLOW_ClimVarCont_array = np.bincount(idx,dwnpop_CV2020_low.ravel())
    dwnpopLOW_ClimTiCont_array = np.bincount(idx,dwnpop_Ti2020_low.ravel())
    dwnpopLOW_ClimTRnatCont_array = np.bincount(idx,dwnpop_TRnat2020_low.ravel())
    dwnpopLOW_ClimTRengCont_array = np.bincount(idx,dwnpop_TReng2020_low.ravel())    

    # 2C sum downpop by indicators
    dwnpopHIGH_ClimVarFut_2C_array = np.bincount(idx,dwnpop_CVyear_fut_2C_high.ravel())
    dwnpopHIGH_ClimTiFut_2C_array = np.bincount(idx,dwnpop_Tiyear_fut_2C_high.ravel())
    dwnpopHIGH_ClimTRnatFut_2C_array = np.bincount(idx,dwnpop_TRnatyear_fut_2C_high.ravel())
    dwnpopHIGH_ClimTRengFut_2C_array = np.bincount(idx,dwnpop_TRengyear_fut_2C_high.ravel())

    dwnpopMOD_ClimVarFut_2C_array = np.bincount(idx,dwnpop_CVyear_fut_2C_mod.ravel())
    dwnpopMOD_ClimTiFut_2C_array = np.bincount(idx,dwnpop_Tiyear_fut_2C_mod.ravel())
    dwnpopMOD_ClimTRnatFut_2C_array = np.bincount(idx,dwnpop_TRnatyear_fut_2C_mod.ravel())
    dwnpopMOD_ClimTRengFut_2C_array = np.bincount(idx,dwnpop_TRengyear_fut_2C_mod.ravel())

    dwnpopLOW_ClimVarFut_2C_array = np.bincount(idx,dwnpop_CVyear_fut_2C_low.ravel())
    dwnpopLOW_ClimTiFut_2C_array = np.bincount(idx,dwnpop_Tiyear_fut_2C_low.ravel())
    dwnpopLOW_ClimTRnatFut_2C_array = np.bincount(idx,dwnpop_TRnatyear_fut_2C_low.ravel())
    dwnpopLOW_ClimTRengFut_2C_array = np.bincount(idx,dwnpop_TRengyear_fut_2C_low.ravel())
    
    # 4C sum downpop by indicators
    dwnpopHIGH_ClimVarFut_4C_array = np.bincount(idx,dwnpop_CVyear_fut_4C_high.ravel())
    dwnpopHIGH_ClimTiFut_4C_array = np.bincount(idx,dwnpop_Tiyear_fut_4C_high.ravel())
    dwnpopHIGH_ClimTRnatFut_4C_array = np.bincount(idx,dwnpop_TRnatyear_fut_4C_high.ravel())
    dwnpopHIGH_ClimTRengFut_4C_array = np.bincount(idx,dwnpop_TRengyear_fut_4C_high.ravel())

    dwnpopMOD_ClimVarFut_4C_array = np.bincount(idx,dwnpop_CVyear_fut_4C_mod.ravel())
    dwnpopMOD_ClimTiFut_4C_array = np.bincount(idx,dwnpop_Tiyear_fut_4C_mod.ravel())
    dwnpopMOD_ClimTRnatFut_4C_array = np.bincount(idx,dwnpop_TRnatyear_fut_4C_mod.ravel())
    dwnpopMOD_ClimTRengFut_4C_array = np.bincount(idx,dwnpop_TRengyear_fut_4C_mod.ravel())

    dwnpopLOW_ClimVarFut_4C_array = np.bincount(idx,dwnpop_CVyear_fut_4C_low.ravel())
    dwnpopLOW_ClimTiFut_4C_array = np.bincount(idx,dwnpop_Tiyear_fut_4C_low.ravel())
    dwnpopLOW_ClimTRnatFut_4C_array = np.bincount(idx,dwnpop_TRnatyear_fut_4C_low.ravel())
    dwnpopLOW_ClimTRengFut_4C_array = np.bincount(idx,dwnpop_TRengyear_fut_4C_low.ravel())

    print("  Summing downstream pops for change classes over admins..")
    # Stays HIGH Threat or LOW Capacity (REDS)
    dwnpop_CV_StaysHiThreat_2C_array = np.bincount(idx,dwnpop_CV_StaysHiThreat_2C.ravel())
    dwnpop_TiCV_StaysHiThreat_2C_array = np.bincount(idx,dwnpop_TiCV_StaysHiThreat_2C.ravel())
    dwnpop_TRnat_StaysLowCapacity_2C_array = np.bincount(idx,dwnpop_TRnat_StaysLowCapacity_2C.ravel())
    dwnpop_TReng_StaysLowCapacity_2C_array = np.bincount(idx,dwnpop_TReng_StaysLowCapacity_2C.ravel())

    # Stays LOW Threat or HIGH Capacity (GRAYS)
    dwnpop_CV_StaysLowModThreat_2C_array = np.bincount(idx,dwnpop_CV_StaysLowModThreat_2C.ravel())
    dwnpop_TiCV_StaysLowModThreat_2C_array = np.bincount(idx,dwnpop_TiCV_StaysLowModThreat_2C.ravel())
    dwnpop_TRnat_StaysModHiCapacity_2C_array = np.bincount(idx,dwnpop_TRnat_StaysModHiCapacity_2C.ravel())
    dwnpop_TReng_StaysModHiCapacity_2C_array = np.bincount(idx,dwnpop_TReng_StaysModHiCapacity_2C.ravel())

    # Goes From LOW threat to HIGH threat or HIGH capacity to LOW capcity, gets worse (ORANGE)
    dwnpop_CV_fromLowModThreat2Hi_2C_array = np.bincount(idx,dwnpop_CV_fromLowModThreat2Hi_2C.ravel())
    dwnpop_TiCV_fromLowModThreat2Hi_2C_array = np.bincount(idx,dwnpop_TiCV_fromLowModThreat2Hi_2C.ravel())
    dwnpop_TRnat_fromModHiCapacity2Low_2C_array = np.bincount(idx,dwnpop_TRnat_fromModHiCapacity2Low_2C.ravel())
    dwnpop_TReng_fromModHiCapacity2Low_2C_array = np.bincount(idx,dwnpop_TReng_fromModHiCapacity2Low_2C.ravel())

    # Goes From HIGH threat to LOW threat or LOW capacity to HIGH capcity, gets better (BLUE)
    dwnpop_CV_fromHiThreat2LowMod_2C_array = np.bincount(idx,dwnpop_CV_fromHiThreat2LowMod_2C.ravel())
    dwnpop_TiCV_fromHiThreat2LowMod_2C_array = np.bincount(idx,dwnpop_TiCV_fromHiThreat2LowMod_2C.ravel())
    dwnpop_TRnat_fromLowCapacity2ModHi_2C_array = np.bincount(idx,dwnpop_TRnat_fromLowCapacity2ModHi_2C.ravel())
    dwnpop_TReng_fromLowCapacity2ModHi_2C_array = np.bincount(idx,dwnpop_TReng_fromLowCapacity2ModHi_2C.ravel())

    # Stays HIGH Threat or LOW Capacity (REDS)
    dwnpop_CV_StaysHiThreat_4C_array = np.bincount(idx,dwnpop_CV_StaysHiThreat_4C.ravel())
    dwnpop_TiCV_StaysHiThreat_4C_array = np.bincount(idx,dwnpop_TiCV_StaysHiThreat_4C.ravel())
    dwnpop_TRnat_StaysLowCapacity_4C_array = np.bincount(idx,dwnpop_TRnat_StaysLowCapacity_4C.ravel())
    dwnpop_TReng_StaysLowCapacity_4C_array = np.bincount(idx,dwnpop_TReng_StaysLowCapacity_4C.ravel())

    # Stays LOW Threat or HIGH Capacity (GRAYS)
    dwnpop_CV_StaysLowModThreat_4C_array = np.bincount(idx,dwnpop_CV_StaysLowModThreat_4C.ravel())
    dwnpop_TiCV_StaysLowModThreat_4C_array = np.bincount(idx,dwnpop_TiCV_StaysLowModThreat_4C.ravel())
    dwnpop_TRnat_StaysModHiCapacity_4C_array = np.bincount(idx,dwnpop_TRnat_StaysModHiCapacity_4C.ravel())
    dwnpop_TReng_StaysModHiCapacity_4C_array = np.bincount(idx,dwnpop_TReng_StaysModHiCapacity_4C.ravel())

    # Goes From LOW threat to HIGH threat or HIGH capacity to LOW capcity, gets worse (ORANGE)
    dwnpop_CV_fromLowModThreat2Hi_4C_array = np.bincount(idx,dwnpop_CV_fromLowModThreat2Hi_4C.ravel())
    dwnpop_TiCV_fromLowModThreat2Hi_4C_array = np.bincount(idx,dwnpop_TiCV_fromLowModThreat2Hi_4C.ravel())
    dwnpop_TRnat_fromModHiCapacity2Low_4C_array = np.bincount(idx,dwnpop_TRnat_fromModHiCapacity2Low_4C.ravel())
    dwnpop_TReng_fromModHiCapacity2Low_4C_array = np.bincount(idx,dwnpop_TReng_fromModHiCapacity2Low_4C.ravel())

    # Goes From HIGH threat to LOW threat or LOW capacity to HIGH capcity, gets better (BLUE)
    dwnpop_CV_fromHiThreat2LowMod_4C_array = np.bincount(idx,dwnpop_CV_fromHiThreat2LowMod_4C.ravel())
    dwnpop_TiCV_fromHiThreat2LowMod_4C_array = np.bincount(idx,dwnpop_TiCV_fromHiThreat2LowMod_4C.ravel())
    dwnpop_TRnat_fromLowCapacity2ModHi_4C_array = np.bincount(idx,dwnpop_TRnat_fromLowCapacity2ModHi_4C.ravel())
    dwnpop_TReng_fromLowCapacity2ModHi_4C_array = np.bincount(idx,dwnpop_TReng_fromLowCapacity2ModHi_4C.ravel())

    # CREATE BIG SUB-NATIONAL TABLE AND APPLY SUB-NATIONAL FINAL CALCS
    print("Create Contemporary table")    

    model_adm_table_attr = pd.DataFrame({'ObjectID': unqID, 'SubNational Area (km2)': area_array, 
                                        'Population Density people/km2 (2020)': popden2020_array, 
                                        'Downstream Population (2020)': dwnpop2020_array}, 
                                       columns=['ObjectID', 'SubNational Area (km2)', 
                                                'Population Density people/km2 (2020)', 
                                                'Downstream Population (2020)'])
    model_adm_table_attr = model_adm_table_attr[model_adm_table_attr.ObjectID != -9999]

    model_adm_table_mean = pd.DataFrame({'ObjectID': unqID, 
                                        'Mean Climate Impacted Ti': ClimTiCont_mean, 
                                        'Mean Climate Impacted TRnat': ClimTRnatCont_mean, 
                                        'Mean Climate Impacted TReng': ClimTRengCont_mean},  
                                       columns=['ObjectID', 
                                                'Mean Climate Impacted Ti', 
                                                'Mean Climate Impacted TRnat', 
                                                'Mean Climate Impacted TReng'])
    model_adm_table_mean = model_adm_table_mean[model_adm_table_mean.ObjectID != -9999]

    model_adm_table_wgt = pd.DataFrame({'ObjectID': unqID, 
                                       'Climate Impacted Ti, pop wgt': ClimTiCont_wgt, 
                                       'Climate Impacted TRnat, pop wgt': ClimTRnatCont_wgt, 
                                       'Climate Impacted TReng, pop wgt': ClimTRengCont_wgt}, 
                                      columns=['ObjectID', 
                                               'Climate Impacted Ti, pop wgt', 
                                               'Climate Impacted TRnat, pop wgt', 
                                               'Climate Impacted TReng, pop wgt'])
    model_adm_table_wgt = model_adm_table_wgt[model_adm_table_wgt.ObjectID != -9999]

    model_adm_table_HML_ThreatsCapacity = pd.DataFrame({'ObjectID': unqID, 
                                               'Dwnpop High Climate Impacted Ti': dwnpopHIGH_ClimTiCont_array, 
                                               'Dwnpop Mod Climate Impacted Ti': dwnpopMOD_ClimTiCont_array, 
                                               'Dwnpop Low Climate Impacted Ti': dwnpopLOW_ClimTiCont_array,
                                                'Dwnpop High Climate Impacted TRnat': dwnpopHIGH_ClimTRnatCont_array, 
                                                'Dwnpop Mod Climate Impacted TRnat': dwnpopMOD_ClimTRnatCont_array, 
                                                'Dwnpop Low Climate Impacted TRnat': dwnpopLOW_ClimTRnatCont_array, 
                                                'Dwnpop High Climate Impacted TReng': dwnpopHIGH_ClimTRengCont_array, 
                                                'Dwnpop Mod Climate Impacted TReng': dwnpopMOD_ClimTRengCont_array, 
                                                'Dwnpop Low Climate Impacted TReng': dwnpopLOW_ClimTRengCont_array}, 
                                              columns=['ObjectID', 
                                                       'Dwnpop High Climate Impacted Ti', 
                                                       'Dwnpop Mod Climate Impacted Ti', 
                                                       'Dwnpop Low Climate Impacted Ti',
                                                        'Dwnpop High Climate Impacted TRnat', 
                                                        'Dwnpop Mod Climate Impacted TRnat', 
                                                        'Dwnpop Low Climate Impacted TRnat', 
                                                        'Dwnpop High Climate Impacted TReng', 
                                                        'Dwnpop Mod Climate Impacted TReng', 
                                                        'Dwnpop Low Climate Impacted TReng'])
    model_adm_table_HML_ThreatsCapacity = model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity.ObjectID != -9999]
    
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 0].index, inplace = True)
    model_adm_table_mean.drop(model_adm_table_mean[model_adm_table_mean['ObjectID'] == 0].index, inplace = True)
    model_adm_table_wgt.drop(model_adm_table_wgt[model_adm_table_wgt['ObjectID'] == 0].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 0].index, inplace = True)
    
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_mean.drop(model_adm_table_mean[model_adm_table_mean['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_wgt.drop(model_adm_table_wgt[model_adm_table_wgt['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 21909].index, inplace = True)
    
    filenmXL = out_dir + 'Model_' + str(adm) + '_AggrVariables_Contemp.xlsx'
    with pd.ExcelWriter(filenmXL) as writer:
            model_adm_table_attr.to_excel(writer, index=False, sheet_name='model_adm SubNational Attributes')    
            model_adm_table_mean.to_excel(writer, index=False, sheet_name='Indicator Avg')
            model_adm_table_wgt.to_excel(writer, index=False, sheet_name='Indicator PopWgt')
            model_adm_table_HML_ThreatsCapacity.to_excel(writer, index=False, sheet_name='HiModLo Classes')
            

    print("Create 2C table")

    model_adm_table_attr = pd.DataFrame({'ObjectID': unqID, 'SubNational Area (km2)': area_array,  
                                        'Population Density people/km2 (' + str(year_fut) + ')': popdenyear_fut_array, 
                                        'Downstream Population (' + str(year_fut) + ')': dwnpopyear_fut_array}, 
                                       columns=['ObjectID', 'SubNational Area (km2)', 
                                                'Population Density people/km2 (' + str(year_fut) + ')', 
                                                'Downstream Population (' + str(year_fut) + ')'])
    model_adm_table_attr = model_adm_table_attr[model_adm_table_attr.ObjectID != -9999]

    model_adm_table_mean = pd.DataFrame({'ObjectID': unqID, 
                                        'Mean Climate Impacted Ti': ClimTiFut_2C_mean, 
                                        'Mean Climate Impacted TRnat': ClimTRnatFut_2C_mean, 
                                        'Mean Climate Impacted TReng': ClimTRengFut_2C_mean}, 
                                       columns=['ObjectID', 
                                                'Mean Climate Impacted Ti', 
                                                'Mean Climate Impacted TRnat', 
                                                'Mean Climate Impacted TReng'])
    model_adm_table_mean = model_adm_table_mean[model_adm_table_mean.ObjectID != -9999]

    model_adm_table_wgt = pd.DataFrame({'ObjectID': unqID, 
                                       'Climate Impacted Ti, pop wgt': ClimTiFut_2C_wgt, 
                                       'Climate Impacted TRnat, pop wgt': ClimTRnatFut_2C_wgt, 
                                       'Climate Impacted TReng, pop wgt': ClimTRengFut_2C_wgt}, 
                                      columns=['ObjectID', 
                                               'Climate Impacted Ti, pop wgt', 
                                               'Climate Impacted TRnat, pop wgt', 
                                               'Climate Impacted TReng, pop wgt'])
    model_adm_table_wgt = model_adm_table_wgt[model_adm_table_wgt.ObjectID != -9999]

    model_adm_table_HML_ThreatsCapacity = pd.DataFrame({'ObjectID': unqID, 
                                               'Dwnpop High Climate Impacted Ti': dwnpopHIGH_ClimTiFut_2C_array, 
                                               'Dwnpop Mod Climate Impacted Ti': dwnpopMOD_ClimTiFut_2C_array, 
                                               'Dwnpop Low Climate Impacted Ti': dwnpopLOW_ClimTiFut_2C_array,
                                                'Dwnpop High Climate Impacted TRnat': dwnpopHIGH_ClimTRnatFut_2C_array, 
                                                'Dwnpop Mod Climate Impacted TRnat': dwnpopMOD_ClimTRnatFut_2C_array, 
                                                'Dwnpop Low Climate Impacted TRnat': dwnpopLOW_ClimTRnatFut_2C_array, 
                                                'Dwnpop High Climate Impacted TReng': dwnpopHIGH_ClimTRengFut_2C_array, 
                                                'Dwnpop Mod Climate Impacted TReng': dwnpopMOD_ClimTRengFut_2C_array, 
                                                'Dwnpop Low Climate Impacted TReng': dwnpopLOW_ClimTRengFut_2C_array}, 
                                              columns=['ObjectID', 
                                                       'Dwnpop High Climate Impacted Ti', 
                                                       'Dwnpop Mod Climate Impacted Ti', 
                                                       'Dwnpop Low Climate Impacted Ti',
                                                        'Dwnpop High Climate Impacted TRnat', 
                                                        'Dwnpop Mod Climate Impacted TRnat', 
                                                        'Dwnpop Low Climate Impacted TRnat', 
                                                        'Dwnpop High Climate Impacted TReng', 
                                                        'Dwnpop Mod Climate Impacted TReng', 
                                                        'Dwnpop Low Climate Impacted TReng'])
    model_adm_table_HML_ThreatsCapacity = model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity.ObjectID != -9999]


    model_adm_table_TrajClimTi = pd.DataFrame({'ObjectID': unqID, 
                                               'DwnPop Persistent High Threats Climate Impacted Ti': dwnpop_TiCV_StaysHiThreat_2C_array, 
                                               'DwnPop Expected Accelerated Threats Climate Impacted Ti': dwnpop_TiCV_fromLowModThreat2Hi_2C_array, 
                                               'DwnPop Expected Decreased Threats Climate Impacted Ti': dwnpop_TiCV_fromHiThreat2LowMod_2C_array, 
                                               'DwnPop Sustained Lower Threats Climate Impacted Ti': dwnpop_TiCV_StaysLowModThreat_2C_array}, 
                                              columns=['ObjectID', 
                                                       'DwnPop Persistent High Threats Climate Impacted Ti', 
                                                       'DwnPop Expected Accelerated Threats Climate Impacted Ti', 
                                                       'DwnPop Expected Decreased Threats Climate Impacted Ti', 
                                                       'DwnPop Sustained Lower Threats Climate Impacted Ti'])
    model_adm_table_TrajClimTi = model_adm_table_TrajClimTi[model_adm_table_TrajClimTi.ObjectID != -9999]

    model_adm_table_TrajTRnat = pd.DataFrame({'ObjectID': unqID, 
                                                'DwnPop Persistent Low Threat Reduction Capacity TRnat': dwnpop_TRnat_StaysLowCapacity_2C_array, 
                                                'DwnPop Expected Diminished Threat Reduction Capacity TRnat': dwnpop_TRnat_fromModHiCapacity2Low_2C_array, 
                                                'DwnPop Expected Increased Threat Reduction Capacity TRnat': dwnpop_TRnat_fromLowCapacity2ModHi_2C_array, 
                                                'DwnPop Sustained Higher Threat Reduction Capacity TRnat': dwnpop_TRnat_StaysModHiCapacity_2C_array}, 
                                               columns=['ObjectID', 
                                                        'DwnPop Persistent Low Threat Reduction Capacity TRnat', 
                                                        'DwnPop Expected Diminished Threat Reduction Capacity TRnat', 
                                                        'DwnPop Expected Increased Threat Reduction Capacity TRnat', 
                                                        'DwnPop Sustained Higher Threat Reduction Capacity TRnat'])
    model_adm_table_TrajTRnat = model_adm_table_TrajTRnat[model_adm_table_TrajTRnat.ObjectID != -9999]

    
    model_adm_table_TrajTReng = pd.DataFrame({'ObjectID': unqID, 
                                                'DwnPop Persistent Low Threat Reduction Capacity TReng': dwnpop_TReng_StaysLowCapacity_2C_array, 
                                                'DwnPop Expected Diminished Threat Reduction Capacity TReng': dwnpop_TReng_fromModHiCapacity2Low_2C_array, 
                                                'DwnPop Expected Increased Threat Reduction Capacity TReng': dwnpop_TReng_fromLowCapacity2ModHi_2C_array, 
                                                'DwnPop Sustained Higher Threat Reduction Capacity TReng': dwnpop_TReng_StaysModHiCapacity_2C_array}, 
                                               columns=['ObjectID', 
                                                        'DwnPop Persistent Low Threat Reduction Capacity TReng', 
                                                        'DwnPop Expected Diminished Threat Reduction Capacity TReng', 
                                                        'DwnPop Expected Increased Threat Reduction Capacity TReng', 
                                                        'DwnPop Sustained Higher Threat Reduction Capacity TReng'])
    model_adm_table_TrajTReng = model_adm_table_TrajTReng[model_adm_table_TrajTReng.ObjectID != -9999]

    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 0].index, inplace = True)
    model_adm_table_mean.drop(model_adm_table_mean[model_adm_table_mean['ObjectID'] == 0].index, inplace = True)
    model_adm_table_wgt.drop(model_adm_table_wgt[model_adm_table_wgt['ObjectID'] == 0].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajClimTi.drop(model_adm_table_TrajClimTi[model_adm_table_TrajClimTi['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajTRnat.drop(model_adm_table_TrajTRnat[model_adm_table_TrajTRnat['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajTReng.drop(model_adm_table_TrajTReng[model_adm_table_TrajTReng['ObjectID'] == 0].index, inplace = True)
        
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_mean.drop(model_adm_table_mean[model_adm_table_mean['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_wgt.drop(model_adm_table_wgt[model_adm_table_wgt['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajClimTi.drop(model_adm_table_TrajClimTi[model_adm_table_TrajClimTi['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajTRnat.drop(model_adm_table_TrajTRnat[model_adm_table_TrajTRnat['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajTReng.drop(model_adm_table_TrajTReng[model_adm_table_TrajTReng['ObjectID'] == 21909].index, inplace = True)


    filenmXL = out_dir + 'Model_' + str(adm) + '_AggrVariables_' + str(year_fut) + '_2C.xlsx'
    with pd.ExcelWriter(filenmXL) as writer:
            model_adm_table_attr.to_excel(writer, index=False, sheet_name='model_adm SubNational Attributes')    
            model_adm_table_mean.to_excel(writer, index=False, sheet_name='Indicator Avg')
            model_adm_table_wgt.to_excel(writer, index=False, sheet_name='Indicator PopWgt')
            model_adm_table_HML_ThreatsCapacity.to_excel(writer, index=False, sheet_name='HiModLo Classes')
            model_adm_table_TrajClimTi.to_excel(writer, index=False, sheet_name='Ti Threat Trajectories')
            model_adm_table_TrajTRnat.to_excel(writer, index=False, sheet_name='TRnat Trajectories')
            model_adm_table_TrajTReng.to_excel(writer, index=False, sheet_name='TReng Trajectories')

    print("Create 4C table")
    model_adm_table_attr = pd.DataFrame({'ObjectID': unqID, 'SubNational Area (km2)': area_array,  
                                        'Population Density people/km2 (' + str(year_fut) + ')': popdenyear_fut_array, 
                                        'Downstream Population (' + str(year_fut) + ')': dwnpopyear_fut_array}, 
                                       columns=['ObjectID', 'SubNational Area (km2)', 
                                                'Population Density people/km2 (' + str(year_fut) + ')', 
                                                'Downstream Population (' + str(year_fut) + ')'])
    model_adm_table_attr = model_adm_table_attr[model_adm_table_attr.ObjectID != -9999]

    model_adm_table_mean = pd.DataFrame({'ObjectID': unqID, 
                                        'Mean Climate Impacted Ti': ClimTiFut_4C_mean, 
                                        'Mean Climate Impacted TRnat': ClimTRnatFut_4C_mean, 
                                        'Mean Climate Impacted TReng': ClimTRengFut_4C_mean}, 
                                       columns=['ObjectID', 
                                                'Mean Climate Impacted Ti', 
                                                'Mean Climate Impacted TRnat', 
                                                'Mean Climate Impacted TReng'])
    model_adm_table_mean = model_adm_table_mean[model_adm_table_mean.ObjectID != -9999]

    model_adm_table_wgt = pd.DataFrame({'ObjectID': unqID, 
                                       'Climate Impacted Ti, pop wgt': ClimTiFut_4C_wgt, 
                                       'Climate Impacted TRnat, pop wgt': ClimTRnatFut_4C_wgt, 
                                       'Climate Impacted TReng, pop wgt': ClimTRengFut_4C_wgt}, 
                                      columns=['ObjectID', 
                                               'Climate Impacted Ti, pop wgt', 
                                               'Climate Impacted TRnat, pop wgt', 
                                               'Climate Impacted TReng, pop wgt'])
    model_adm_table_wgt = model_adm_table_wgt[model_adm_table_wgt.ObjectID != -9999]

    model_adm_table_HML_ThreatsCapacity = pd.DataFrame({'ObjectID': unqID, 
                                               'Dwnpop High Climate Impacted Ti': dwnpopHIGH_ClimTiFut_4C_array, 
                                               'Dwnpop Mod Climate Impacted Ti': dwnpopMOD_ClimTiFut_4C_array, 
                                               'Dwnpop Low Climate Impacted Ti': dwnpopLOW_ClimTiFut_4C_array,
                                                'Dwnpop High Climate Impacted TRnat': dwnpopHIGH_ClimTRnatFut_4C_array, 
                                                'Dwnpop Mod Climate Impacted TRnat': dwnpopMOD_ClimTRnatFut_4C_array, 
                                                'Dwnpop Low Climate Impacted TRnat': dwnpopLOW_ClimTRnatFut_4C_array, 
                                                'Dwnpop High Climate Impacted TReng': dwnpopHIGH_ClimTRengFut_4C_array, 
                                                'Dwnpop Mod Climate Impacted TReng': dwnpopMOD_ClimTRengFut_4C_array, 
                                                'Dwnpop Low Climate Impacted TReng': dwnpopLOW_ClimTRengFut_4C_array}, 
                                              columns=['ObjectID', 
                                                       'Dwnpop High Climate Impacted Ti', 
                                                       'Dwnpop Mod Climate Impacted Ti', 
                                                       'Dwnpop Low Climate Impacted Ti',
                                                        'Dwnpop High Climate Impacted TRnat', 
                                                        'Dwnpop Mod Climate Impacted TRnat', 
                                                        'Dwnpop Low Climate Impacted TRnat', 
                                                        'Dwnpop High Climate Impacted TReng', 
                                                        'Dwnpop Mod Climate Impacted TReng', 
                                                        'Dwnpop Low Climate Impacted TReng'])
    model_adm_table_HML_ThreatsCapacity = model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity.ObjectID != -9999]

    model_adm_table_TrajClimTi = pd.DataFrame({'ObjectID': unqID, 
                                               'DwnPop Persistent High Threats Climate Impacted Ti': dwnpop_TiCV_StaysHiThreat_4C_array, 
                                               'DwnPop Expected Accelerated Threats Climate Impacted Ti': dwnpop_TiCV_fromLowModThreat2Hi_4C_array, 
                                               'DwnPop Expected Decreased Threats Climate Impacted Ti': dwnpop_TiCV_fromHiThreat2LowMod_4C_array, 
                                               'DwnPop Sustained Lower Threats Climate Impacted Ti': dwnpop_TiCV_StaysLowModThreat_4C_array}, 
                                              columns=['ObjectID', 
                                                       'DwnPop Persistent High Threats Climate Impacted Ti', 
                                                       'DwnPop Expected Accelerated Threats Climate Impacted Ti', 
                                                       'DwnPop Expected Decreased Threats Climate Impacted Ti', 
                                                       'DwnPop Sustained Lower Threats Climate Impacted Ti'])
    model_adm_table_TrajClimTi = model_adm_table_TrajClimTi[model_adm_table_TrajClimTi.ObjectID != -9999]

    model_adm_table_TrajTRnat = pd.DataFrame({'ObjectID': unqID, 
                                                'DwnPop Persistent Low Threat Reduction Capacity TRnat': dwnpop_TRnat_StaysLowCapacity_4C_array, 
                                                'DwnPop Expected Diminished Threat Reduction Capacity TRnat': dwnpop_TRnat_fromModHiCapacity2Low_4C_array, 
                                                'DwnPop Expected Increased Threat Reduction Capacity TRnat': dwnpop_TRnat_fromLowCapacity2ModHi_4C_array, 
                                                'DwnPop Sustained Higher Threat Reduction Capacity TRnat': dwnpop_TRnat_StaysModHiCapacity_4C_array}, 
                                               columns=['ObjectID', 
                                                        'DwnPop Persistent Low Threat Reduction Capacity TRnat', 
                                                        'DwnPop Expected Diminished Threat Reduction Capacity TRnat', 
                                                        'DwnPop Expected Increased Threat Reduction Capacity TRnat', 
                                                        'DwnPop Sustained Higher Threat Reduction Capacity TRnat'])
    model_adm_table_TrajTRnat = model_adm_table_TrajTRnat[model_adm_table_TrajTRnat.ObjectID != -9999]

    
    model_adm_table_TrajTReng = pd.DataFrame({'ObjectID': unqID, 
                                                'DwnPop Persistent Low Threat Reduction Capacity TReng': dwnpop_TReng_StaysLowCapacity_4C_array, 
                                                'DwnPop Expected Diminished Threat Reduction Capacity TReng': dwnpop_TReng_fromModHiCapacity2Low_4C_array, 
                                                'DwnPop Expected Increased Threat Reduction Capacity TReng': dwnpop_TReng_fromLowCapacity2ModHi_4C_array, 
                                                'DwnPop Sustained Higher Threat Reduction Capacity TReng': dwnpop_TReng_StaysModHiCapacity_4C_array}, 
                                               columns=['ObjectID', 
                                                        'DwnPop Persistent Low Threat Reduction Capacity TReng', 
                                                        'DwnPop Expected Diminished Threat Reduction Capacity TReng', 
                                                        'DwnPop Expected Increased Threat Reduction Capacity TReng', 
                                                        'DwnPop Sustained Higher Threat Reduction Capacity TReng'])
    model_adm_table_TrajTReng = model_adm_table_TrajTReng[model_adm_table_TrajTReng.ObjectID != -9999]

    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 0].index, inplace = True)
    model_adm_table_mean.drop(model_adm_table_mean[model_adm_table_mean['ObjectID'] == 0].index, inplace = True)
    model_adm_table_wgt.drop(model_adm_table_wgt[model_adm_table_wgt['ObjectID'] == 0].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajClimTi.drop(model_adm_table_TrajClimTi[model_adm_table_TrajClimTi['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajTRnat.drop(model_adm_table_TrajTRnat[model_adm_table_TrajTRnat['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajTReng.drop(model_adm_table_TrajTReng[model_adm_table_TrajTReng['ObjectID'] == 0].index, inplace = True)
        
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_mean.drop(model_adm_table_mean[model_adm_table_mean['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_wgt.drop(model_adm_table_wgt[model_adm_table_wgt['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajClimTi.drop(model_adm_table_TrajClimTi[model_adm_table_TrajClimTi['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajTRnat.drop(model_adm_table_TrajTRnat[model_adm_table_TrajTRnat['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajTReng.drop(model_adm_table_TrajTReng[model_adm_table_TrajTReng['ObjectID'] == 21909].index, inplace = True)


    filenmXL = out_dir + 'Model_' + str(adm) + '_AggrVariables_' + str(year_fut) + '_4C.xlsx'
    with pd.ExcelWriter(filenmXL) as writer:
            model_adm_table_attr.to_excel(writer, index=False, sheet_name='model_adm SubNational Attributes')    
            model_adm_table_mean.to_excel(writer, index=False, sheet_name='Indicator Avg')
            model_adm_table_wgt.to_excel(writer, index=False, sheet_name='Indicator PopWgt')
            model_adm_table_HML_ThreatsCapacity.to_excel(writer, index=False, sheet_name='HiModLo Classes')
            model_adm_table_TrajClimTi.to_excel(writer, index=False, sheet_name='Ti Threat Trajectories')
            model_adm_table_TrajTRnat.to_excel(writer, index=False, sheet_name='TRnat Trajectories')
            model_adm_table_TrajTReng.to_excel(writer, index=False, sheet_name='TReng Trajectories')

# %% [markdown]
# ## EXTREMELY DRY: Administrative Unit Aggregations - GDL, IR at 6-min resolution
# - Bin grid cell level data into sub-national units by array zones using bincount
# - Combine binned data into a pandas dataframe
# - Write to MSExcell file

# %%
dwnp_2020_XDry = np.where(msk_Contemp_XDry > 0, dwnp_2020, 0)
dwnp_year_fut_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnp_year_fut, 0)
dwnp_year_fut_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnp_year_fut, 0)

tot_pop_2020_XDry = np.where(msk_Contemp_XDry > 0, pop2020, 0)
tot_pop_year_fut_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, scaled_pop_year_fut, 0)
tot_pop_year_fut_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, scaled_pop_year_fut, 0)

for x in range(1, 3):
    if x == 1:
        adm = "GDL"
        fin = '/asrc/ecr/pamela/model/python/GDL_ObjectID_6m.tif'
        print(f'{adm} aggr..')
    if x == 2:
        adm = "IR"
        fin = out_dir + 'IR_regions_Model.tif'
        print(f'{adm} aggr..')

    ds = gdal.Open(str(fin))
    model_adm = np.array(ds.GetRasterBand(1).ReadAsArray())
    model_adm[np.isnan(model_adm)] = 0

    #
    # DO SUB-NATIONAL AGGREGATION OF GRID CELL DATA AND COMBINE IN DATAFRAME
    #

    print('Summing Variables by Model Sub-national\n')
    # CREATE ARRAY ZONES BASED ON FID FROM model_adm Model SUB-NATIONAL GRID
    unqID,idx,IDsums = np.unique(model_adm,return_counts=True,return_inverse=True)

    # CREATE SUMS OVER ARRAY ZONES
    pop2020_array = np.bincount(idx,np.where(np.isnan(pop2020), 0, pop2020).ravel())
    popyear_fut_array = np.bincount(idx,np.where(np.isnan(scaled_pop_year_fut), 0, scaled_pop_year_fut).ravel())

    pop2020_array_XDry = np.bincount(idx,np.where(np.isnan(tot_pop_2020_XDry), 0, tot_pop_2020_XDry).ravel())
    popyear_fut_2C_array_XDry = np.bincount(idx,np.where(np.isnan(tot_pop_year_fut_2C_XDry), 0, tot_pop_year_fut_2C_XDry).ravel())
    popyear_fut_4C_array_XDry = np.bincount(idx,np.where(np.isnan(tot_pop_year_fut_4C_XDry), 0, tot_pop_year_fut_4C_XDry).ravel())
    
    dwnpop2020_array = np.bincount(idx,np.where(np.isnan(dwnp_2020), 0, dwnp_2020).ravel())
    dwnpopyear_fut_array = np.bincount(idx,np.where(np.isnan(dwnp_year_fut), 0, dwnp_year_fut).ravel())
    
    dwnpop2020_array_XDry = np.bincount(idx,np.where(np.isnan(dwnp_2020_XDry), 0, dwnp_2020_XDry).ravel())
    dwnpopyear_fut_2C_array_XDry = np.bincount(idx,np.where(np.isnan(dwnp_year_fut_2C_XDry), 0, dwnp_year_fut_2C_XDry).ravel())
    dwnpopyear_fut_4C_array_XDry = np.bincount(idx,np.where(np.isnan(dwnp_year_fut_4C_XDry), 0, dwnp_year_fut_4C_XDry).ravel())

    area_array = np.bincount(idx,CellArea6m.ravel())

    area_array_2020_XDry = np.bincount(idx,np.where(msk_Contemp_XDry > 0, CellArea6m, 0).ravel())
    area_array_year_fut_2C_XDry = np.bincount(idx,np.where(msk_FutClim_2C_XDry > 0, CellArea6m, 0).ravel())
    area_array_year_fut_4C_XDry = np.bincount(idx,np.where(msk_FutClim_4C_XDry > 0, CellArea6m, 0).ravel())

    with np.errstate(all='ignore'):
        area_2020_frac_array = area_array_2020_XDry / area_array
        area_year_fut_frac_2C_array = area_array_year_fut_2C_XDry / area_array
        area_year_fut_frac_4C_array = area_array_year_fut_4C_XDry / area_array

        pop2020_frac_array = pop2020_array_XDry / pop2020_array
        popyear_fut_frac_2C_array = popyear_fut_2C_array_XDry / popyear_fut_array
        popyear_fut_frac_4C_array = popyear_fut_4C_array_XDry / popyear_fut_array

        dwnpop2020_frac_array = dwnpop2020_array_XDry / dwnpop2020_array
        dwnpopyear_fut_frac_2C_array = dwnpopyear_fut_2C_array_XDry / dwnpopyear_fut_array
        dwnpopyear_fut_frac_4C_array = dwnpopyear_fut_4C_array_XDry / dwnpopyear_fut_array

        popden2020_array = pop2020_array_XDry / area_array
        popdenyear_fut_2C_array = popyear_fut_2C_array_XDry / area_array
        popdenyear_fut_4C_array = popyear_fut_4C_array_XDry / area_array

        dwnpopden2020_array = dwnpop2020_array_XDry / area_array
        dwnpopdenyear_fut_2C_array = dwnpopyear_fut_2C_array_XDry / area_array
        dwnpopdenyear_fut_4C_array = dwnpopyear_fut_4C_array_XDry / area_array
    

    print(" Summing downstream pops for low-mod-high over admins..")
    print("   Contemp sum downpop by indicators")
    dwnpopHIGH_ClimVarCont_array = np.bincount(idx,dwnpop_CV2020_high_XDry.ravel())
    dwnpopHIGH_ClimTiCont_array = np.bincount(idx,dwnpop_Ti2020_high_XDry.ravel())
    dwnpopHIGH_ClimTRnatCont_array = np.bincount(idx,dwnpop_TRnat2020_high_XDry.ravel())
    dwnpopHIGH_ClimTRengCont_array = np.bincount(idx,dwnpop_TReng2020_high_XDry.ravel())
    
    dwnpopMOD_ClimVarCont_array = np.bincount(idx,dwnpop_CV2020_mod_XDry.ravel())
    dwnpopMOD_ClimTiCont_array = np.bincount(idx,dwnpop_Ti2020_mod_XDry.ravel())
    dwnpopMOD_ClimTRnatCont_array = np.bincount(idx,dwnpop_TRnat2020_mod_XDry.ravel())
    dwnpopMOD_ClimTRengCont_array = np.bincount(idx,dwnpop_TReng2020_mod_XDry.ravel())
    
    dwnpopLOW_ClimVarCont_array = np.bincount(idx,dwnpop_CV2020_low_XDry.ravel())
    dwnpopLOW_ClimTiCont_array = np.bincount(idx,dwnpop_Ti2020_low_XDry.ravel())
    dwnpopLOW_ClimTRnatCont_array = np.bincount(idx,dwnpop_TRnat2020_low_XDry.ravel())
    dwnpopLOW_ClimTRengCont_array = np.bincount(idx,dwnpop_TReng2020_low_XDry.ravel())    

    print("   2C sum downpop by indicators")
    dwnpopHIGH_ClimVarFut_2C_array = np.bincount(idx,dwnpop_CVyear_fut_2C_high_XDry.ravel())
    dwnpopHIGH_ClimTiFut_2C_array = np.bincount(idx,dwnpop_Tiyear_fut_2C_high_XDry.ravel())
    dwnpopHIGH_ClimTRnatFut_2C_array = np.bincount(idx,dwnpop_TRnatyear_fut_2C_high_XDry.ravel())
    dwnpopHIGH_ClimTRengFut_2C_array = np.bincount(idx,dwnpop_TRengyear_fut_2C_high_XDry.ravel())

    dwnpopMOD_ClimVarFut_2C_array = np.bincount(idx,dwnpop_CVyear_fut_2C_mod_XDry.ravel())
    dwnpopMOD_ClimTiFut_2C_array = np.bincount(idx,dwnpop_Tiyear_fut_2C_mod_XDry.ravel())
    dwnpopMOD_ClimTRnatFut_2C_array = np.bincount(idx,dwnpop_TRnatyear_fut_2C_mod_XDry.ravel())
    dwnpopMOD_ClimTRengFut_2C_array = np.bincount(idx,dwnpop_TRengyear_fut_2C_mod_XDry.ravel())

    dwnpopLOW_ClimVarFut_2C_array = np.bincount(idx,dwnpop_CVyear_fut_2C_low_XDry.ravel())
    dwnpopLOW_ClimTiFut_2C_array = np.bincount(idx,dwnpop_Tiyear_fut_2C_low_XDry.ravel())
    dwnpopLOW_ClimTRnatFut_2C_array = np.bincount(idx,dwnpop_TRnatyear_fut_2C_low_XDry.ravel())
    dwnpopLOW_ClimTRengFut_2C_array = np.bincount(idx,dwnpop_TRengyear_fut_2C_low_XDry.ravel())
    
    print("   4C sum downpop by indicators")
    dwnpopHIGH_ClimVarFut_4C_array = np.bincount(idx,dwnpop_CVyear_fut_4C_high_XDry.ravel())
    dwnpopHIGH_ClimTiFut_4C_array = np.bincount(idx,dwnpop_Tiyear_fut_4C_high_XDry.ravel())
    dwnpopHIGH_ClimTRnatFut_4C_array = np.bincount(idx,dwnpop_TRnatyear_fut_4C_high_XDry.ravel())
    dwnpopHIGH_ClimTRengFut_4C_array = np.bincount(idx,dwnpop_TRengyear_fut_4C_high_XDry.ravel())

    dwnpopMOD_ClimVarFut_4C_array = np.bincount(idx,dwnpop_CVyear_fut_4C_mod_XDry.ravel())
    dwnpopMOD_ClimTiFut_4C_array = np.bincount(idx,dwnpop_Tiyear_fut_4C_mod_XDry.ravel())
    dwnpopMOD_ClimTRnatFut_4C_array = np.bincount(idx,dwnpop_TRnatyear_fut_4C_mod_XDry.ravel())
    dwnpopMOD_ClimTRengFut_4C_array = np.bincount(idx,dwnpop_TRengyear_fut_4C_mod_XDry.ravel())

    dwnpopLOW_ClimVarFut_4C_array = np.bincount(idx,dwnpop_CVyear_fut_4C_low_XDry.ravel())
    dwnpopLOW_ClimTiFut_4C_array = np.bincount(idx,dwnpop_Tiyear_fut_4C_low_XDry.ravel())
    dwnpopLOW_ClimTRnatFut_4C_array = np.bincount(idx,dwnpop_TRnatyear_fut_4C_low_XDry.ravel())
    dwnpopLOW_ClimTRengFut_4C_array = np.bincount(idx,dwnpop_TRengyear_fut_4C_low_XDry.ravel())

    print("  Summing downstream pops for change classes over admins..")
    print("    2C")
    # Stays HIGH Threat or LOW Capacity (REDS)
    dwnpop_CV_StaysHiThreat_2C_array = np.bincount(idx,dwnpop_CV_StaysHiThreat_2C_XDry.ravel())
    dwnpop_TiCV_StaysHiThreat_2C_array = np.bincount(idx,dwnpop_TiCV_StaysHiThreat_2C_XDry.ravel())
    dwnpop_TRnat_StaysLowCapacity_2C_array = np.bincount(idx,dwnpop_TRnat_StaysLowCapacity_2C_XDry.ravel())
    dwnpop_TReng_StaysLowCapacity_2C_array = np.bincount(idx,dwnpop_TReng_StaysLowCapacity_2C_XDry.ravel())

    # Stays LOW Threat or HIGH Capacity (GRAYS)
    dwnpop_CV_StaysLowModThreat_2C_array = np.bincount(idx,dwnpop_CV_StaysLowModThreat_2C_XDry.ravel())
    dwnpop_TiCV_StaysLowModThreat_2C_array = np.bincount(idx,dwnpop_TiCV_StaysLowModThreat_2C_XDry.ravel())
    dwnpop_TRnat_StaysModHiCapacity_2C_array = np.bincount(idx,dwnpop_TRnat_StaysModHiCapacity_2C_XDry.ravel())
    dwnpop_TReng_StaysModHiCapacity_2C_array = np.bincount(idx,dwnpop_TReng_StaysModHiCapacity_2C_XDry.ravel())

    # Goes From LOW threat to HIGH threat or HIGH capacity to LOW capcity, gets worse (ORANGE)
    dwnpop_CV_fromLowModThreat2Hi_2C_array = np.bincount(idx,dwnpop_CV_fromLowModThreat2Hi_2C_XDry.ravel())
    dwnpop_TiCV_fromLowModThreat2Hi_2C_array = np.bincount(idx,dwnpop_TiCV_fromLowModThreat2Hi_2C_XDry.ravel())
    dwnpop_TRnat_fromModHiCapacity2Low_2C_array = np.bincount(idx,dwnpop_TRnat_fromModHiCapacity2Low_2C_XDry.ravel())
    dwnpop_TReng_fromModHiCapacity2Low_2C_array = np.bincount(idx,dwnpop_TReng_fromModHiCapacity2Low_2C_XDry.ravel())

    # Goes From HIGH threat to LOW threat or LOW capacity to HIGH capcity, gets better (BLUE)
    dwnpop_CV_fromHiThreat2LowMod_2C_array = np.bincount(idx,dwnpop_CV_fromHiThreat2LowMod_2C_XDry.ravel())
    dwnpop_TiCV_fromHiThreat2LowMod_2C_array = np.bincount(idx,dwnpop_TiCV_fromHiThreat2LowMod_2C_XDry.ravel())
    dwnpop_TRnat_fromLowCapacity2ModHi_2C_array = np.bincount(idx,dwnpop_TRnat_fromLowCapacity2ModHi_2C_XDry.ravel())
    dwnpop_TReng_fromLowCapacity2ModHi_2C_array = np.bincount(idx,dwnpop_TReng_fromLowCapacity2ModHi_2C_XDry.ravel())

    print("    4C")
    # Stays HIGH Threat or LOW Capacity (REDS)
    dwnpop_CV_StaysHiThreat_4C_array = np.bincount(idx,dwnpop_CV_StaysHiThreat_4C_XDry.ravel())
    dwnpop_TiCV_StaysHiThreat_4C_array = np.bincount(idx,dwnpop_TiCV_StaysHiThreat_4C_XDry.ravel())
    dwnpop_TRnat_StaysLowCapacity_4C_array = np.bincount(idx,dwnpop_TRnat_StaysLowCapacity_4C_XDry.ravel())
    dwnpop_TReng_StaysLowCapacity_4C_array = np.bincount(idx,dwnpop_TReng_StaysLowCapacity_4C_XDry.ravel())

    # Stays LOW Threat or HIGH Capacity (GRAYS)
    dwnpop_CV_StaysLowModThreat_4C_array = np.bincount(idx,dwnpop_CV_StaysLowModThreat_4C_XDry.ravel())
    dwnpop_TiCV_StaysLowModThreat_4C_array = np.bincount(idx,dwnpop_TiCV_StaysLowModThreat_4C_XDry.ravel())
    dwnpop_TRnat_StaysModHiCapacity_4C_array = np.bincount(idx,dwnpop_TRnat_StaysModHiCapacity_4C_XDry.ravel())
    dwnpop_TReng_StaysModHiCapacity_4C_array = np.bincount(idx,dwnpop_TReng_StaysModHiCapacity_4C_XDry.ravel())

    # Goes From LOW threat to HIGH threat or HIGH capacity to LOW capcity, gets worse (ORANGE)
    dwnpop_CV_fromLowModThreat2Hi_4C_array = np.bincount(idx,dwnpop_CV_fromLowModThreat2Hi_4C_XDry.ravel())
    dwnpop_TiCV_fromLowModThreat2Hi_4C_array = np.bincount(idx,dwnpop_TiCV_fromLowModThreat2Hi_4C_XDry.ravel())
    dwnpop_TRnat_fromModHiCapacity2Low_4C_array = np.bincount(idx,dwnpop_TRnat_fromModHiCapacity2Low_4C_XDry.ravel())
    dwnpop_TReng_fromModHiCapacity2Low_4C_array = np.bincount(idx,dwnpop_TReng_fromModHiCapacity2Low_4C_XDry.ravel())

    # Goes From HIGH threat to LOW threat or LOW capacity to HIGH capcity, gets better (BLUE)
    dwnpop_CV_fromHiThreat2LowMod_4C_array = np.bincount(idx,dwnpop_CV_fromHiThreat2LowMod_4C_XDry.ravel())
    dwnpop_TiCV_fromHiThreat2LowMod_4C_array = np.bincount(idx,dwnpop_TiCV_fromHiThreat2LowMod_4C_XDry.ravel())
    dwnpop_TRnat_fromLowCapacity2ModHi_4C_array = np.bincount(idx,dwnpop_TRnat_fromLowCapacity2ModHi_4C_XDry.ravel())
    dwnpop_TReng_fromLowCapacity2ModHi_4C_array = np.bincount(idx,dwnpop_TReng_fromLowCapacity2ModHi_4C_XDry.ravel())

    # CREATE BIG SUB-NATIONAL TABLE AND APPLY SUB-NATIONAL FINAL CALCS
    print("Create 2C table")
    with np.errstate(all='ignore'):
        area_2020_frac_array = area_array_2020_XDry / area_array
        area_year_fut_frac_2C_array = area_array_year_fut_2C_XDry / area_array
        area_year_fut_frac_4C_array = area_array_year_fut_4C_XDry / area_array

        # Population Fractions
        pop2020_frac_array = pop2020_array_XDry / pop2020_array
        popyear_fut_frac_2C_array = popyear_fut_2C_array_XDry / popyear_fut_array
        popyear_fut_frac_4C_array = popyear_fut_4C_array_XDry / popyear_fut_array

        dwnpop2020_frac_array = dwnpop2020_array_XDry / dwnpop2020_array
        dwnpopyear_fut_frac_2C_array = dwnpopyear_fut_2C_array_XDry / dwnpopyear_fut_array
        dwnpopyear_fut_frac_4C_array = dwnpopyear_fut_4C_array_XDry / dwnpopyear_fut_array
        
        dwnpopHIGH_frac_ClimTiCont_array = dwnpopHIGH_ClimTiCont_array / dwnpop2020_array
        dwnpopLOW_frac_ClimTRnatCont_array = dwnpopLOW_ClimTRnatCont_array / dwnpop2020_array
        dwnpopLOW_frac_ClimTRengCont_array = dwnpopLOW_ClimTRengCont_array / dwnpop2020_array
        
        dwnpopHIGH_frac_ClimTiFut_2C_array = dwnpopHIGH_ClimTiFut_2C_array / dwnpopyear_fut_array
        dwnpopLOW_frac_ClimTRnatFut_2C_array = dwnpopLOW_ClimTRnatFut_2C_array / dwnpopyear_fut_array
        dwnpopLOW_frac_ClimTRengFut_2C_array = dwnpopLOW_ClimTRengFut_2C_array / dwnpopyear_fut_array
        
        dwnpopHIGH_frac_ClimTiFut_4C_array = dwnpopHIGH_ClimTiFut_4C_array / dwnpopyear_fut_array
        dwnpopLOW_frac_ClimTRnatFut_4C_array = dwnpopLOW_ClimTRnatFut_4C_array / dwnpopyear_fut_array
        dwnpopLOW_frac_ClimTRengFut_4C_array = dwnpopLOW_ClimTRengFut_4C_array / dwnpopyear_fut_array
        
        # Population Densities
        popden2020_array = pop2020_array_XDry / area_array
        popdenyear_fut_2C_array = popyear_fut_2C_array_XDry / area_array
        popdenyear_fut_4C_array = popyear_fut_4C_array_XDry / area_array

        dwnpopden2020_array = dwnpop2020_array_XDry / area_array
        dwnpopdenyear_fut_2C_array = dwnpopyear_fut_2C_array_XDry / area_array
        dwnpopdenyear_fut_4C_array = dwnpopyear_fut_4C_array_XDry / area_array   
        
        dwnpopHIGH_den_ClimTiCont_array = dwnpopHIGH_ClimTiCont_array / area_array
        dwnpopLOW_den_ClimTRnatCont_array = dwnpopLOW_ClimTRnatCont_array / area_array
        dwnpopLOW_den_ClimTRengCont_array = dwnpopLOW_ClimTRengCont_array / area_array
        
        dwnpopHIGH_den_ClimTiFut_2C_array = dwnpopHIGH_ClimTiFut_2C_array / area_array
        dwnpopLOW_den_ClimTRnatFut_2C_array = dwnpopLOW_ClimTRnatFut_2C_array / area_array
        dwnpopLOW_den_ClimTRengFut_2C_array = dwnpopLOW_ClimTRengFut_2C_array / area_array
        
        dwnpopHIGH_den_ClimTiFut_4C_array = dwnpopHIGH_ClimTiFut_4C_array / area_array
        dwnpopLOW_den_ClimTRnatFut_4C_array = dwnpopLOW_ClimTRnatFut_4C_array / area_array
        dwnpopLOW_den_ClimTRengFut_4C_array = dwnpopLOW_ClimTRengFut_4C_array / area_array
    
    # CREATE BIG SUB-NATIONAL TABLE AND APPLY SUB-NATIONAL FINAL CALCS
    
    print(" Create Contemporary table")    
    model_adm_table_attr = pd.DataFrame({'ObjectID': unqID, 'SubNational Area (km2)': area_array, 
                                        'Fraction Land Area XDry (2020)': area_2020_frac_array, 
                                        'Fraction Population XDry (2020)': pop2020_frac_array, 
                                        'Fraction Downstream Population XDry (2020)': dwnpop2020_frac_array,
                                        'Fraction Dwnpop High Climate Impacted Ti': dwnpopHIGH_frac_ClimTiCont_array,
                                        'Fraction Dwnpop Low Climate Impacted TRnat': dwnpopLOW_frac_ClimTRnatCont_array,
                                        'Fraction Dwnpop Low Climate Impacted TReng': dwnpopLOW_frac_ClimTRengCont_array,
                                        'Population Density XDry (2020)': popden2020_array, 
                                        'Downstream Population Density XDry (2020)': dwnpopden2020_array,
                                        'Dwnpop Density High Climate Impacted Ti': dwnpopHIGH_den_ClimTiCont_array,
                                        'Dwnpop Density Low Climate Impacted TRnat': dwnpopLOW_den_ClimTRnatCont_array,
                                        'Dwnpop Density Low Climate Impacted TReng': dwnpopLOW_den_ClimTRengCont_array},
                                       columns=['ObjectID', 'SubNational Area (km2)', 
                                                'Fraction Land Area XDry (2020)',                                          
                                                'Fraction Population XDry (2020)', 
                                                'Fraction Downstream Population XDry (2020)',
                                                'Fraction Dwnpop High Climate Impacted Ti',
                                                'Fraction Dwnpop Low Climate Impacted TRnat',
                                                'Fraction Dwnpop Low Climate Impacted TReng',
                                                'Population Density XDry (2020)', 
                                                'Downstream Population Density XDry (2020)',
                                                'Dwnpop Density High Climate Impacted Ti',
                                                'Dwnpop Density Low Climate Impacted TRnat',
                                                'Dwnpop Density Low Climate Impacted TReng'])
    model_adm_table_attr = model_adm_table_attr[model_adm_table_attr.ObjectID != -9999]

    model_adm_table_HML_ThreatsCapacity = pd.DataFrame({'ObjectID': unqID, 
                                               'Dwnpop High Climate Impacted Ti': dwnpopHIGH_ClimTiCont_array, 
                                               'Dwnpop Mod Climate Impacted Ti': dwnpopMOD_ClimTiCont_array, 
                                               'Dwnpop Low Climate Impacted Ti': dwnpopLOW_ClimTiCont_array,
                                                'Dwnpop High Climate Impacted TRnat': dwnpopHIGH_ClimTRnatCont_array, 
                                                'Dwnpop Mod Climate Impacted TRnat': dwnpopMOD_ClimTRnatCont_array, 
                                                'Dwnpop Low Climate Impacted TRnat': dwnpopLOW_ClimTRnatCont_array, 
                                                'Dwnpop High Climate Impacted TReng': dwnpopHIGH_ClimTRengCont_array, 
                                                'Dwnpop Mod Climate Impacted TReng': dwnpopMOD_ClimTRengCont_array, 
                                                'Dwnpop Low Climate Impacted TReng': dwnpopLOW_ClimTRengCont_array},
                                              columns=['ObjectID', 
                                                       'Dwnpop High Climate Impacted Ti', 
                                                       'Dwnpop Mod Climate Impacted Ti', 
                                                       'Dwnpop Low Climate Impacted Ti',
                                                       'Dwnpop High Climate Impacted TRnat', 
                                                        'Dwnpop Mod Climate Impacted TRnat', 
                                                        'Dwnpop Low Climate Impacted TRnat', 
                                                        'Dwnpop High Climate Impacted TReng', 
                                                        'Dwnpop Mod Climate Impacted TReng', 
                                                        'Dwnpop Low Climate Impacted TReng'])
    model_adm_table_HML_ThreatsCapacity = model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity.ObjectID != -9999]
    
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 0].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 0].index, inplace = True)
        
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 21909].index, inplace = True)

    filenmXL = out_dir + 'Model_' + str(adm) + '_AggrVariables_Contemp_XDry.xlsx'
    with pd.ExcelWriter(filenmXL) as writer:
            model_adm_table_attr.to_excel(writer, index=False, sheet_name='model_adm SubNational Attributes')    
            model_adm_table_HML_ThreatsCapacity.to_excel(writer, index=False, sheet_name='HiModLo Classes')
            
            
    print(" Create 2C table")
    model_adm_table_attr = pd.DataFrame({'ObjectID': unqID, 'SubNational Area (km2)': area_array,  
                                        'Fraction Land Area XDry 2C (' + str(year_fut) + ')': area_year_fut_frac_2C_array,
                                        'Fraction Population XDry 2C (' + str(year_fut) + ')': popyear_fut_frac_2C_array, 
                                        'Fraction Downstream Population XDry 2C (' + str(year_fut) + ')': dwnpopyear_fut_frac_2C_array,
                                        'Fraction Dwnpop High Climate Impacted Ti': dwnpopHIGH_frac_ClimTiFut_2C_array,
                                        'Fraction Dwnpop Low Climate Impacted TRnat': dwnpopLOW_frac_ClimTRnatFut_2C_array,
                                        'Fraction Dwnpop Low Climate Impacted TReng': dwnpopLOW_frac_ClimTRengFut_2C_array,                                        
                                        'Population Density XDry (' + str(year_fut) + ')': popdenyear_fut_2C_array, 
                                        'Downstream Population Density XDry (' + str(year_fut) + ')': dwnpopdenyear_fut_2C_array,
                                        'Dwnpop Density High Climate Impacted Ti': dwnpopHIGH_den_ClimTiFut_2C_array,
                                        'Dwnpop Density Low Climate Impacted TRnat': dwnpopLOW_den_ClimTRnatFut_2C_array,
                                        'Dwnpop Density Low Climate Impacted TReng': dwnpopLOW_den_ClimTRengFut_2C_array},
                                       columns=['ObjectID', 'SubNational Area (km2)', 
                                                'Fraction Land Area XDry 2C (' + str(year_fut) + ')',
                                                'Fraction Population XDry 2C (' + str(year_fut) + ')', 
                                                'Fraction Downstream Population XDry 2C (' + str(year_fut) + ')',
                                                'Fraction Dwnpop High Climate Impacted Ti',
                                                'Fraction Dwnpop Low Climate Impacted TRnat',
                                                'Fraction Dwnpop Low Climate Impacted TReng',
                                                'Population Density XDry (' + str(year_fut) + ')', 
                                                'Downstream Population Density XDry (' + str(year_fut) + ')',
                                                'Dwnpop Density High Climate Impacted Ti',
                                                'Dwnpop Density Low Climate Impacted TRnat',
                                                'Dwnpop Density Low Climate Impacted TReng'])
    model_adm_table_attr = model_adm_table_attr[model_adm_table_attr.ObjectID != -9999]
    
    model_adm_table_HML_ThreatsCapacity = pd.DataFrame({'ObjectID': unqID, 
                                               'Dwnpop High Climate Impacted Ti': dwnpopHIGH_ClimTiFut_2C_array, 
                                               'Dwnpop Mod Climate Impacted Ti': dwnpopMOD_ClimTiFut_2C_array, 
                                               'Dwnpop Low Climate Impacted Ti': dwnpopLOW_ClimTiFut_2C_array,
                                               'Dwnpop High Climate Impacted TRnat': dwnpopHIGH_ClimTRnatFut_2C_array, 
                                               'Dwnpop Mod Climate Impacted TRnat': dwnpopMOD_ClimTRnatFut_2C_array, 
                                               'Dwnpop Low Climate Impacted TRnat': dwnpopLOW_ClimTRnatFut_2C_array, 
                                               'Dwnpop High Climate Impacted TReng': dwnpopHIGH_ClimTRengFut_2C_array, 
                                               'Dwnpop Mod Climate Impacted TReng': dwnpopMOD_ClimTRengFut_2C_array, 
                                               'Dwnpop Low Climate Impacted TReng': dwnpopLOW_ClimTRengFut_2C_array}, 
                                              columns=['ObjectID', 
                                                       'Dwnpop High Climate Impacted Ti', 
                                                       'Dwnpop Mod Climate Impacted Ti', 
                                                       'Dwnpop Low Climate Impacted Ti',
                                                       'Dwnpop High Climate Impacted TRnat', 
                                                       'Dwnpop Mod Climate Impacted TRnat', 
                                                       'Dwnpop Low Climate Impacted TRnat', 
                                                       'Dwnpop High Climate Impacted TReng', 
                                                       'Dwnpop Mod Climate Impacted TReng', 
                                                       'Dwnpop Low Climate Impacted TReng'])
    model_adm_table_HML_ThreatsCapacity = model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity.ObjectID != -9999]
    
    model_adm_table_TrajClimTi = pd.DataFrame({'ObjectID': unqID, 
                                               'DwnPop Persistent High Threats Climate Impacted Ti': dwnpop_TiCV_StaysHiThreat_2C_array, 
                                               'DwnPop Expected Accelerated Threats Climate Impacted Ti': dwnpop_TiCV_fromLowModThreat2Hi_2C_array, 
                                               'DwnPop Expected Decreased Threats Climate Impacted Ti': dwnpop_TiCV_fromHiThreat2LowMod_2C_array, 
                                               'DwnPop Sustained Lower Threats Climate Impacted Ti': dwnpop_TiCV_StaysLowModThreat_2C_array}, 
                                              columns=['ObjectID', 
                                                       'DwnPop Persistent High Threats Climate Impacted Ti', 
                                                       'DwnPop Expected Accelerated Threats Climate Impacted Ti', 
                                                       'DwnPop Expected Decreased Threats Climate Impacted Ti', 
                                                       'DwnPop Sustained Lower Threats Climate Impacted Ti'])
    model_adm_table_TrajClimTi = model_adm_table_TrajClimTi[model_adm_table_TrajClimTi.ObjectID != -9999]

    
    model_adm_table_TrajTRnat = pd.DataFrame({'ObjectID': unqID, 
                                                'DwnPop Persistent Low Threat Reduction Capacity TRnat': dwnpop_TRnat_StaysLowCapacity_2C_array, 
                                                'DwnPop Expected Diminished Threat Reduction Capacity TRnat': dwnpop_TRnat_fromModHiCapacity2Low_2C_array, 
                                                'DwnPop Expected Increased Threat Reduction Capacity TRnat': dwnpop_TRnat_fromLowCapacity2ModHi_2C_array, 
                                                'DwnPop Sustained Higher Threat Reduction Capacity TRnat': dwnpop_TRnat_StaysModHiCapacity_2C_array}, 
                                              columns=['ObjectID', 
                                                        'DwnPop Persistent Low Threat Reduction Capacity TRnat', 
                                                        'DwnPop Expected Diminished Threat Reduction Capacity TRnat', 
                                                        'DwnPop Expected Increased Threat Reduction Capacity TRnat', 
                                                        'DwnPop Sustained Higher Threat Reduction Capacity TRnat'])
    model_adm_table_TrajTRnat = model_adm_table_TrajTRnat[model_adm_table_TrajTRnat.ObjectID != -9999]
    
    model_adm_table_TrajTReng = pd.DataFrame({'ObjectID': unqID, 
                                                'DwnPop Persistent Low Threat Reduction Capacity TReng': dwnpop_TReng_StaysLowCapacity_2C_array, 
                                                'DwnPop Expected Diminished Threat Reduction Capacity TReng': dwnpop_TReng_fromModHiCapacity2Low_2C_array, 
                                                'DwnPop Expected Increased Threat Reduction Capacity TReng': dwnpop_TReng_fromLowCapacity2ModHi_2C_array, 
                                                'DwnPop Sustained Higher Threat Reduction Capacity TReng': dwnpop_TReng_StaysModHiCapacity_2C_array}, 
                                              columns=['ObjectID', 
                                                        'DwnPop Persistent Low Threat Reduction Capacity TReng', 
                                                        'DwnPop Expected Diminished Threat Reduction Capacity TReng', 
                                                        'DwnPop Expected Increased Threat Reduction Capacity TReng', 
                                                        'DwnPop Sustained Higher Threat Reduction Capacity TReng'])
    model_adm_table_TrajTReng = model_adm_table_TrajTReng[model_adm_table_TrajTReng.ObjectID != -9999]

    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 0].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajClimTi.drop(model_adm_table_TrajClimTi[model_adm_table_TrajClimTi['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajTRnat.drop(model_adm_table_TrajTRnat[model_adm_table_TrajTRnat['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajTReng.drop(model_adm_table_TrajTReng[model_adm_table_TrajTReng['ObjectID'] == 0].index, inplace = True)
        
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajClimTi.drop(model_adm_table_TrajClimTi[model_adm_table_TrajClimTi['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajTRnat.drop(model_adm_table_TrajTRnat[model_adm_table_TrajTRnat['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajTReng.drop(model_adm_table_TrajTReng[model_adm_table_TrajTReng['ObjectID'] == 21909].index, inplace = True)


    filenmXL = out_dir + 'Model_' + str(adm) + '_AggrVariables_' + str(year_fut) + '_2C_XDry.xlsx'
    with pd.ExcelWriter(filenmXL) as writer:
            model_adm_table_attr.to_excel(writer, index=False, sheet_name='model_adm SubNational Attributes')    
            model_adm_table_HML_ThreatsCapacity.to_excel(writer, index=False, sheet_name='HiModLo Classes')
            model_adm_table_TrajClimTi.to_excel(writer, index=False, sheet_name='Ti Threat Trajectories')
            model_adm_table_TrajTRnat.to_excel(writer, index=False, sheet_name='TRnat Trajectories')
            model_adm_table_TrajTReng.to_excel(writer, index=False, sheet_name='TReng Trajectories')


    print(" Create 4C table")
        
    model_adm_table_attr = pd.DataFrame({'ObjectID': unqID, 'SubNational Area (km2)': area_array,  
                                        'Fraction Land Area XDry 4C (' + str(year_fut) + ')': area_year_fut_frac_4C_array,
                                        'Fraction Population XDry 4C (' + str(year_fut) + ')': popyear_fut_frac_4C_array, 
                                        'Fraction Downstream Population XDry 4C (' + str(year_fut) + ')': dwnpopyear_fut_frac_4C_array,
                                        'Fraction Dwnpop High Climate Impacted Ti': dwnpopHIGH_frac_ClimTiFut_4C_array,
                                        'Fraction Dwnpop Low Climate Impacted TRnat': dwnpopLOW_frac_ClimTRnatFut_4C_array,
                                        'Fraction Dwnpop Low Climate Impacted TReng': dwnpopLOW_frac_ClimTRengFut_4C_array,                                        
                                        'Population Density XDry (' + str(year_fut) + ')': popdenyear_fut_4C_array, 
                                        'Downstream Population Density XDry (' + str(year_fut) + ')': dwnpopdenyear_fut_4C_array,
                                        'Dwnpop Density High Climate Impacted Ti': dwnpopHIGH_den_ClimTiFut_4C_array,
                                        'Dwnpop Density Low Climate Impacted TRnat': dwnpopLOW_den_ClimTRnatFut_4C_array,
                                        'Dwnpop Density Low Climate Impacted TReng': dwnpopLOW_den_ClimTRengFut_4C_array},
                                       columns=['ObjectID', 'SubNational Area (km2)', 
                                                'Fraction Land Area XDry 4C (' + str(year_fut) + ')',
                                                'Fraction Population XDry 4C (' + str(year_fut) + ')', 
                                                'Fraction Downstream Population XDry 4C (' + str(year_fut) + ')',
                                                'Fraction Dwnpop High Climate Impacted Ti',
                                                'Fraction Dwnpop Low Climate Impacted TRnat',
                                                'Fraction Dwnpop Low Climate Impacted TReng',
                                                'Population Density XDry (' + str(year_fut) + ')', 
                                                'Downstream Population Density XDry (' + str(year_fut) + ')',
                                                'Dwnpop Density High Climate Impacted Ti',
                                                'Dwnpop Density Low Climate Impacted TRnat',
                                                'Dwnpop Density Low Climate Impacted TReng'])
    model_adm_table_attr = model_adm_table_attr[model_adm_table_attr.ObjectID != -9999]

    model_adm_table_HML_ThreatsCapacity = pd.DataFrame({'ObjectID': unqID, 
                                               'Dwnpop High Climate Impacted Ti': dwnpopHIGH_ClimTiFut_4C_array, 
                                               'Dwnpop Mod Climate Impacted Ti': dwnpopMOD_ClimTiFut_4C_array, 
                                               'Dwnpop Low Climate Impacted Ti': dwnpopLOW_ClimTiFut_4C_array,
                                               'Dwnpop High Climate Impacted TRnat': dwnpopHIGH_ClimTRnatFut_4C_array, 
                                               'Dwnpop Mod Climate Impacted TRnat': dwnpopMOD_ClimTRnatFut_4C_array, 
                                               'Dwnpop Low Climate Impacted TRnat': dwnpopLOW_ClimTRnatFut_4C_array, 
                                               'Dwnpop High Climate Impacted TReng': dwnpopHIGH_ClimTRengFut_4C_array, 
                                               'Dwnpop Mod Climate Impacted TReng': dwnpopMOD_ClimTRengFut_4C_array, 
                                               'Dwnpop Low Climate Impacted TReng': dwnpopLOW_ClimTRengFut_4C_array}, 
                                              columns=['ObjectID', 
                                                       'Dwnpop High Climate Impacted Ti', 
                                                       'Dwnpop Mod Climate Impacted Ti', 
                                                       'Dwnpop Low Climate Impacted Ti',
                                                       'Dwnpop High Climate Impacted TRnat', 
                                                       'Dwnpop Mod Climate Impacted TRnat', 
                                                       'Dwnpop Low Climate Impacted TRnat', 
                                                       'Dwnpop High Climate Impacted TReng', 
                                                       'Dwnpop Mod Climate Impacted TReng', 
                                                       'Dwnpop Low Climate Impacted TReng'])
    model_adm_table_HML_ThreatsCapacity = model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity.ObjectID != -9999]


    model_adm_table_TrajClimTi = pd.DataFrame({'ObjectID': unqID, 
                                               'DwnPop Persistent High Threats Climate Impacted Ti': dwnpop_TiCV_StaysHiThreat_4C_array, 
                                               'DwnPop Expected Accelerated Threats Climate Impacted Ti': dwnpop_TiCV_fromLowModThreat2Hi_4C_array, 
                                               'DwnPop Expected Decreased Threats Climate Impacted Ti': dwnpop_TiCV_fromHiThreat2LowMod_4C_array, 
                                               'DwnPop Sustained Lower Threats Climate Impacted Ti': dwnpop_TiCV_StaysLowModThreat_4C_array}, 
                                              columns=['ObjectID', 
                                                       'DwnPop Persistent High Threats Climate Impacted Ti', 
                                                       'DwnPop Expected Accelerated Threats Climate Impacted Ti', 
                                                       'DwnPop Expected Decreased Threats Climate Impacted Ti', 
                                                       'DwnPop Sustained Lower Threats Climate Impacted Ti'])
    model_adm_table_TrajClimTi = model_adm_table_TrajClimTi[model_adm_table_TrajClimTi.ObjectID != -9999]

    
    model_adm_table_TrajTRnat = pd.DataFrame({'ObjectID': unqID, 
                                                'DwnPop Persistent Low Threat Reduction Capacity TRnat': dwnpop_TRnat_StaysLowCapacity_4C_array, 
                                                'DwnPop Expected Diminished Threat Reduction Capacity TRnat': dwnpop_TRnat_fromModHiCapacity2Low_4C_array, 
                                                'DwnPop Expected Increased Threat Reduction Capacity TRnat': dwnpop_TRnat_fromLowCapacity2ModHi_4C_array, 
                                                'DwnPop Sustained Higher Threat Reduction Capacity TRnat': dwnpop_TRnat_StaysModHiCapacity_4C_array}, 
                                              columns=['ObjectID', 
                                                        'DwnPop Persistent Low Threat Reduction Capacity TRnat', 
                                                        'DwnPop Expected Diminished Threat Reduction Capacity TRnat', 
                                                        'DwnPop Expected Increased Threat Reduction Capacity TRnat', 
                                                        'DwnPop Sustained Higher Threat Reduction Capacity TRnat'])
    model_adm_table_TrajTRnat = model_adm_table_TrajTRnat[model_adm_table_TrajTRnat.ObjectID != -9999]
    
    model_adm_table_TrajTReng = pd.DataFrame({'ObjectID': unqID, 
                                                'DwnPop Persistent Low Threat Reduction Capacity TReng': dwnpop_TReng_StaysLowCapacity_4C_array, 
                                                'DwnPop Expected Diminished Threat Reduction Capacity TReng': dwnpop_TReng_fromModHiCapacity2Low_4C_array, 
                                                'DwnPop Expected Increased Threat Reduction Capacity TReng': dwnpop_TReng_fromLowCapacity2ModHi_4C_array, 
                                                'DwnPop Sustained Higher Threat Reduction Capacity TReng': dwnpop_TReng_StaysModHiCapacity_4C_array}, 
                                              columns=['ObjectID', 
                                                        'DwnPop Persistent Low Threat Reduction Capacity TReng', 
                                                        'DwnPop Expected Diminished Threat Reduction Capacity TReng', 
                                                        'DwnPop Expected Increased Threat Reduction Capacity TReng', 
                                                        'DwnPop Sustained Higher Threat Reduction Capacity TReng'])
    model_adm_table_TrajTReng = model_adm_table_TrajTReng[model_adm_table_TrajTReng.ObjectID != -9999]
    
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 0].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajClimTi.drop(model_adm_table_TrajClimTi[model_adm_table_TrajClimTi['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajTRnat.drop(model_adm_table_TrajTRnat[model_adm_table_TrajTRnat['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajTReng.drop(model_adm_table_TrajTReng[model_adm_table_TrajTReng['ObjectID'] == 0].index, inplace = True)
        
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajClimTi.drop(model_adm_table_TrajClimTi[model_adm_table_TrajClimTi['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajTRnat.drop(model_adm_table_TrajTRnat[model_adm_table_TrajTRnat['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajTReng.drop(model_adm_table_TrajTReng[model_adm_table_TrajTReng['ObjectID'] == 21909].index, inplace = True)

    filenmXL = out_dir + 'Model_' + str(adm) + '_AggrVariables_' + str(year_fut) + '_4C_XDry.xlsx'
    with pd.ExcelWriter(filenmXL) as writer:
            model_adm_table_attr.to_excel(writer, index=False, sheet_name='model_adm SubNational Attributes')    
            model_adm_table_HML_ThreatsCapacity.to_excel(writer, index=False, sheet_name='HiModLo Classes')
            model_adm_table_TrajClimTi.to_excel(writer, index=False, sheet_name='Ti Threat Trajectories')
            model_adm_table_TrajTRnat.to_excel(writer, index=False, sheet_name='TRnat Trajectories')
            model_adm_table_TrajTReng.to_excel(writer, index=False, sheet_name='TReng Trajectories')

# %% [markdown]
# ## EXTREMELY WET: Administrative Unit Aggregations - GDL, IR at 6-min resolution
# - Bin grid cell level data into sub-national units by array zones using bincount
# - Combine binned data into a pandas dataframe
# - Write to MSExcell file

# %%
dwnp_2020_XWet = np.where(msk_Contemp_XWet > 0, dwnp_2020, 0)
dwnp_year_fut_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnp_year_fut, 0)
dwnp_year_fut_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnp_year_fut, 0)

tot_pop_2020_XWet = np.where(msk_Contemp_XWet > 0, pop2020, 0)
tot_pop_year_fut_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, scaled_pop_year_fut, 0)
tot_pop_year_fut_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, scaled_pop_year_fut, 0)

for x in range(1, 3):
    if x == 1:
        adm = "GDL"
        fin = '/asrc/ecr/pamela/model/python/GDL_ObjectID_6m.tif'
        print(f'{adm} aggr..')
    if x == 2:
        adm = "IR"
        fin = out_dir + 'IR_regions_Model.tif'
        print(f'{adm} aggr..')

    ds = gdal.Open(str(fin))
    model_adm = np.array(ds.GetRasterBand(1).ReadAsArray())
    model_adm[np.isnan(model_adm)] = 0

    #
    # DO SUB-NATIONAL AGGREGATION OF GRID CELL DATA AND COMBINE IN DATAFRAME
    #

    print('Summing Variables by Model Sub-national\n')
    # CREATE ARRAY ZONES BASED ON FID FROM model_adm Model SUB-NATIONAL GRID
    unqID,idx,IDsums = np.unique(model_adm,return_counts=True,return_inverse=True)

    # CREATE SUMS OVER ARRAY ZONES
    pop2020_array = np.bincount(idx,np.where(np.isnan(pop2020), 0, pop2020).ravel())
    popyear_fut_array = np.bincount(idx,np.where(np.isnan(scaled_pop_year_fut), 0, scaled_pop_year_fut).ravel())

    pop2020_array_XWet = np.bincount(idx,np.where(np.isnan(tot_pop_2020_XWet), 0, tot_pop_2020_XWet).ravel())
    popyear_fut_2C_array_XWet = np.bincount(idx,np.where(np.isnan(tot_pop_year_fut_2C_XWet), 0, tot_pop_year_fut_2C_XWet).ravel())
    popyear_fut_4C_array_XWet = np.bincount(idx,np.where(np.isnan(tot_pop_year_fut_4C_XWet), 0, tot_pop_year_fut_4C_XWet).ravel())
    
    dwnpop2020_array = np.bincount(idx,np.where(np.isnan(dwnp_2020), 0, dwnp_2020).ravel())
    dwnpopyear_fut_array = np.bincount(idx,np.where(np.isnan(dwnp_year_fut), 0, dwnp_year_fut).ravel())
    
    dwnpop2020_array_XWet = np.bincount(idx,np.where(np.isnan(dwnp_2020_XWet), 0, dwnp_2020_XWet).ravel())
    dwnpopyear_fut_2C_array_XWet = np.bincount(idx,np.where(np.isnan(dwnp_year_fut_2C_XWet), 0, dwnp_year_fut_2C_XWet).ravel())
    dwnpopyear_fut_4C_array_XWet = np.bincount(idx,np.where(np.isnan(dwnp_year_fut_4C_XWet), 0, dwnp_year_fut_4C_XWet).ravel())

    area_array = np.bincount(idx,CellArea6m.ravel())

    area_array_2020_XWet = np.bincount(idx,np.where(msk_Contemp_XWet > 0, CellArea6m, 0).ravel())
    area_array_year_fut_2C_XWet = np.bincount(idx,np.where(msk_FutClim_2C_XWet > 0, CellArea6m, 0).ravel())
    area_array_year_fut_4C_XWet = np.bincount(idx,np.where(msk_FutClim_4C_XWet > 0, CellArea6m, 0).ravel())

    with np.errstate(all='ignore'):
        area_2020_frac_array = area_array_2020_XWet / area_array
        area_year_fut_frac_2C_array = area_array_year_fut_2C_XWet / area_array
        area_year_fut_frac_4C_array = area_array_year_fut_4C_XWet / area_array

        pop2020_frac_array = pop2020_array_XWet / pop2020_array
        popyear_fut_frac_2C_array = popyear_fut_2C_array_XWet / popyear_fut_array
        popyear_fut_frac_4C_array = popyear_fut_4C_array_XWet / popyear_fut_array

        dwnpop2020_frac_array = dwnpop2020_array_XWet / dwnpop2020_array
        dwnpopyear_fut_frac_2C_array = dwnpopyear_fut_2C_array_XWet / dwnpopyear_fut_array
        dwnpopyear_fut_frac_4C_array = dwnpopyear_fut_4C_array_XWet / dwnpopyear_fut_array

        popden2020_array = pop2020_array_XWet / area_array
        popdenyear_fut_2C_array = popyear_fut_2C_array_XWet / area_array
        popdenyear_fut_4C_array = popyear_fut_4C_array_XWet / area_array

        dwnpopden2020_array = dwnpop2020_array_XWet / area_array
        dwnpopdenyear_fut_2C_array = dwnpopyear_fut_2C_array_XWet / area_array
        dwnpopdenyear_fut_4C_array = dwnpopyear_fut_4C_array_XWet / area_array
 
    print(" Summing downstream pops for low-mod-high over admins..")
    print("   Contemp sum downpop by indicators")
    dwnpopHIGH_ClimVarCont_array = np.bincount(idx,dwnpop_CV2020_high_XWet.ravel())
    dwnpopHIGH_ClimTiCont_array = np.bincount(idx,dwnpop_Ti2020_high_XWet.ravel())
    dwnpopHIGH_ClimTRnatCont_array = np.bincount(idx,dwnpop_TRnat2020_high_XWet.ravel())
    dwnpopHIGH_ClimTRengCont_array = np.bincount(idx,dwnpop_TReng2020_high_XWet.ravel())

    dwnpopMOD_ClimVarCont_array = np.bincount(idx,dwnpop_CV2020_mod_XWet.ravel())
    dwnpopMOD_ClimTiCont_array = np.bincount(idx,dwnpop_Ti2020_mod_XWet.ravel())
    dwnpopMOD_ClimTRnatCont_array = np.bincount(idx,dwnpop_TRnat2020_mod_XWet.ravel())
    dwnpopMOD_ClimTRengCont_array = np.bincount(idx,dwnpop_TReng2020_mod_XWet.ravel())
    
    dwnpopLOW_ClimVarCont_array = np.bincount(idx,dwnpop_CV2020_low_XWet.ravel())
    dwnpopLOW_ClimTiCont_array = np.bincount(idx,dwnpop_Ti2020_low_XWet.ravel())
    dwnpopLOW_ClimTRnatCont_array = np.bincount(idx,dwnpop_TRnat2020_low_XWet.ravel())
    dwnpopLOW_ClimTRengCont_array = np.bincount(idx,dwnpop_TReng2020_low_XWet.ravel())    

    print("   2C sum downpop by indicators")
    dwnpopHIGH_ClimVarFut_2C_array = np.bincount(idx,dwnpop_CVyear_fut_2C_high_XWet.ravel())
    dwnpopHIGH_ClimTiFut_2C_array = np.bincount(idx,dwnpop_Tiyear_fut_2C_high_XWet.ravel())
    dwnpopHIGH_ClimTRnatFut_2C_array = np.bincount(idx,dwnpop_TRnatyear_fut_2C_high_XWet.ravel())
    dwnpopHIGH_ClimTRengFut_2C_array = np.bincount(idx,dwnpop_TRengyear_fut_2C_high_XWet.ravel())

    dwnpopMOD_ClimVarFut_2C_array = np.bincount(idx,dwnpop_CVyear_fut_2C_mod_XWet.ravel())
    dwnpopMOD_ClimTiFut_2C_array = np.bincount(idx,dwnpop_Tiyear_fut_2C_mod_XWet.ravel())
    dwnpopMOD_ClimTRnatFut_2C_array = np.bincount(idx,dwnpop_TRnatyear_fut_2C_mod_XWet.ravel())
    dwnpopMOD_ClimTRengFut_2C_array = np.bincount(idx,dwnpop_TRengyear_fut_2C_mod_XWet.ravel())

    dwnpopLOW_ClimVarFut_2C_array = np.bincount(idx,dwnpop_CVyear_fut_2C_low_XWet.ravel())
    dwnpopLOW_ClimTiFut_2C_array = np.bincount(idx,dwnpop_Tiyear_fut_2C_low_XWet.ravel())
    dwnpopLOW_ClimTRnatFut_2C_array = np.bincount(idx,dwnpop_TRnatyear_fut_2C_low_XWet.ravel())
    dwnpopLOW_ClimTRengFut_2C_array = np.bincount(idx,dwnpop_TRengyear_fut_2C_low_XWet.ravel())
    
    print("   4C sum downpop by indicators")
    dwnpopHIGH_ClimVarFut_4C_array = np.bincount(idx,dwnpop_CVyear_fut_4C_high_XWet.ravel())
    dwnpopHIGH_ClimTiFut_4C_array = np.bincount(idx,dwnpop_Tiyear_fut_4C_high_XWet.ravel())
    dwnpopHIGH_ClimTRnatFut_4C_array = np.bincount(idx,dwnpop_TRnatyear_fut_4C_high_XWet.ravel())
    dwnpopHIGH_ClimTRengFut_4C_array = np.bincount(idx,dwnpop_TRengyear_fut_4C_high_XWet.ravel())

    dwnpopMOD_ClimVarFut_4C_array = np.bincount(idx,dwnpop_CVyear_fut_4C_mod_XWet.ravel())
    dwnpopMOD_ClimTiFut_4C_array = np.bincount(idx,dwnpop_Tiyear_fut_4C_mod_XWet.ravel())
    dwnpopMOD_ClimTRnatFut_4C_array = np.bincount(idx,dwnpop_TRnatyear_fut_4C_mod_XWet.ravel())
    dwnpopMOD_ClimTRengFut_4C_array = np.bincount(idx,dwnpop_TRengyear_fut_4C_mod_XWet.ravel())

    dwnpopLOW_ClimVarFut_4C_array = np.bincount(idx,dwnpop_CVyear_fut_4C_low_XWet.ravel())
    dwnpopLOW_ClimTiFut_4C_array = np.bincount(idx,dwnpop_Tiyear_fut_4C_low_XWet.ravel())
    dwnpopLOW_ClimTRnatFut_4C_array = np.bincount(idx,dwnpop_TRnatyear_fut_4C_low_XWet.ravel())
    dwnpopLOW_ClimTRengFut_4C_array = np.bincount(idx,dwnpop_TRengyear_fut_4C_low_XWet.ravel())

    print("  Summing downstream pops for change classes over admins..")
    print("    2C")
    # Stays HIGH Threat or LOW Capacity (REDS)
    dwnpop_CV_StaysHiThreat_2C_array = np.bincount(idx,dwnpop_CV_StaysHiThreat_2C_XWet.ravel())
    dwnpop_TiCV_StaysHiThreat_2C_array = np.bincount(idx,dwnpop_TiCV_StaysHiThreat_2C_XWet.ravel())
    dwnpop_TRnat_StaysLowCapacity_2C_array = np.bincount(idx,dwnpop_TRnat_StaysLowCapacity_2C_XWet.ravel())
    dwnpop_TReng_StaysLowCapacity_2C_array = np.bincount(idx,dwnpop_TReng_StaysLowCapacity_2C_XWet.ravel())

    # Stays LOW Threat or HIGH Capacity (GRAYS)
    dwnpop_CV_StaysLowModThreat_2C_array = np.bincount(idx,dwnpop_CV_StaysLowModThreat_2C_XWet.ravel())
    dwnpop_TiCV_StaysLowModThreat_2C_array = np.bincount(idx,dwnpop_TiCV_StaysLowModThreat_2C_XWet.ravel())
    dwnpop_TRnat_StaysModHiCapacity_2C_array = np.bincount(idx,dwnpop_TRnat_StaysModHiCapacity_2C_XWet.ravel())
    dwnpop_TReng_StaysModHiCapacity_2C_array = np.bincount(idx,dwnpop_TReng_StaysModHiCapacity_2C_XWet.ravel())

    # Goes From LOW threat to HIGH threat or HIGH capacity to LOW capcity, gets worse (ORANGE)
    dwnpop_CV_fromLowModThreat2Hi_2C_array = np.bincount(idx,dwnpop_CV_fromLowModThreat2Hi_2C_XWet.ravel())
    dwnpop_TiCV_fromLowModThreat2Hi_2C_array = np.bincount(idx,dwnpop_TiCV_fromLowModThreat2Hi_2C_XWet.ravel())
    dwnpop_TRnat_fromModHiCapacity2Low_2C_array = np.bincount(idx,dwnpop_TRnat_fromModHiCapacity2Low_2C_XWet.ravel())
    dwnpop_TReng_fromModHiCapacity2Low_2C_array = np.bincount(idx,dwnpop_TReng_fromModHiCapacity2Low_2C_XWet.ravel())

    # Goes From HIGH threat to LOW threat or LOW capacity to HIGH capcity, gets better (BLUE)
    dwnpop_CV_fromHiThreat2LowMod_2C_array = np.bincount(idx,dwnpop_CV_fromHiThreat2LowMod_2C_XWet.ravel())
    dwnpop_TiCV_fromHiThreat2LowMod_2C_array = np.bincount(idx,dwnpop_TiCV_fromHiThreat2LowMod_2C_XWet.ravel())
    dwnpop_TRnat_fromLowCapacity2ModHi_2C_array = np.bincount(idx,dwnpop_TRnat_fromLowCapacity2ModHi_2C_XWet.ravel())
    dwnpop_TReng_fromLowCapacity2ModHi_2C_array = np.bincount(idx,dwnpop_TReng_fromLowCapacity2ModHi_2C_XWet.ravel())

    print("    4C")
    # Stays HIGH Threat or LOW Capacity (REDS)
    dwnpop_CV_StaysHiThreat_4C_array = np.bincount(idx,dwnpop_CV_StaysHiThreat_4C_XWet.ravel())
    dwnpop_TiCV_StaysHiThreat_4C_array = np.bincount(idx,dwnpop_TiCV_StaysHiThreat_4C_XWet.ravel())
    dwnpop_TRnat_StaysLowCapacity_4C_array = np.bincount(idx,dwnpop_TRnat_StaysLowCapacity_4C_XWet.ravel())
    dwnpop_TReng_StaysLowCapacity_4C_array = np.bincount(idx,dwnpop_TReng_StaysLowCapacity_4C_XWet.ravel())

    # Stays LOW Threat or HIGH Capacity (GRAYS)
    dwnpop_CV_StaysLowModThreat_4C_array = np.bincount(idx,dwnpop_CV_StaysLowModThreat_4C_XWet.ravel())
    dwnpop_TiCV_StaysLowModThreat_4C_array = np.bincount(idx,dwnpop_TiCV_StaysLowModThreat_4C_XWet.ravel())
    dwnpop_TRnat_StaysModHiCapacity_4C_array = np.bincount(idx,dwnpop_TRnat_StaysModHiCapacity_4C_XWet.ravel())
    dwnpop_TReng_StaysModHiCapacity_4C_array = np.bincount(idx,dwnpop_TReng_StaysModHiCapacity_4C_XWet.ravel())

    # Goes From LOW threat to HIGH threat or HIGH capacity to LOW capcity, gets worse (ORANGE)
    dwnpop_CV_fromLowModThreat2Hi_4C_array = np.bincount(idx,dwnpop_CV_fromLowModThreat2Hi_4C_XWet.ravel())
    dwnpop_TiCV_fromLowModThreat2Hi_4C_array = np.bincount(idx,dwnpop_TiCV_fromLowModThreat2Hi_4C_XWet.ravel())
    dwnpop_TRnat_fromModHiCapacity2Low_4C_array = np.bincount(idx,dwnpop_TRnat_fromModHiCapacity2Low_4C_XWet.ravel())
    dwnpop_TReng_fromModHiCapacity2Low_4C_array = np.bincount(idx,dwnpop_TReng_fromModHiCapacity2Low_4C_XWet.ravel())

    # Goes From HIGH threat to LOW threat or LOW capacity to HIGH capcity, gets better (BLUE)
    dwnpop_CV_fromHiThreat2LowMod_4C_array = np.bincount(idx,dwnpop_CV_fromHiThreat2LowMod_4C_XWet.ravel())
    dwnpop_TiCV_fromHiThreat2LowMod_4C_array = np.bincount(idx,dwnpop_TiCV_fromHiThreat2LowMod_4C_XWet.ravel())
    dwnpop_TRnat_fromLowCapacity2ModHi_4C_array = np.bincount(idx,dwnpop_TRnat_fromLowCapacity2ModHi_4C_XWet.ravel())
    dwnpop_TReng_fromLowCapacity2ModHi_4C_array = np.bincount(idx,dwnpop_TReng_fromLowCapacity2ModHi_4C_XWet.ravel())

    # CREATE BIG SUB-NATIONAL TABLE AND APPLY SUB-NATIONAL FINAL CALCS
    print("Create 2C table")
    with np.errstate(all='ignore'):
        area_2020_frac_array = area_array_2020_XWet / area_array
        area_year_fut_frac_2C_array = area_array_year_fut_2C_XWet / area_array
        area_year_fut_frac_4C_array = area_array_year_fut_4C_XWet / area_array

        # Population Fractions
        pop2020_frac_array = pop2020_array_XWet / pop2020_array
        popyear_fut_frac_2C_array = popyear_fut_2C_array_XWet / popyear_fut_array
        popyear_fut_frac_4C_array = popyear_fut_4C_array_XWet / popyear_fut_array

        dwnpop2020_frac_array = dwnpop2020_array_XWet / dwnpop2020_array
        dwnpopyear_fut_frac_2C_array = dwnpopyear_fut_2C_array_XWet / dwnpopyear_fut_array
        dwnpopyear_fut_frac_4C_array = dwnpopyear_fut_4C_array_XWet / dwnpopyear_fut_array
        
        dwnpopHIGH_frac_ClimTiCont_array = dwnpopHIGH_ClimTiCont_array / dwnpop2020_array
        dwnpopLOW_frac_ClimTRnatCont_array = dwnpopLOW_ClimTRnatCont_array / dwnpop2020_array
        dwnpopLOW_frac_ClimTRengCont_array = dwnpopLOW_ClimTRengCont_array / dwnpop2020_array
        
        dwnpopHIGH_frac_ClimTiFut_2C_array = dwnpopHIGH_ClimTiFut_2C_array / dwnpopyear_fut_array
        dwnpopLOW_frac_ClimTRnatFut_2C_array = dwnpopLOW_ClimTRnatFut_2C_array / dwnpopyear_fut_array
        dwnpopLOW_frac_ClimTRengFut_2C_array = dwnpopLOW_ClimTRengFut_2C_array / dwnpopyear_fut_array
        
        dwnpopHIGH_frac_ClimTiFut_4C_array = dwnpopHIGH_ClimTiFut_4C_array / dwnpopyear_fut_array
        dwnpopLOW_frac_ClimTRnatFut_4C_array = dwnpopLOW_ClimTRnatFut_4C_array / dwnpopyear_fut_array
        dwnpopLOW_frac_ClimTRengFut_4C_array = dwnpopLOW_ClimTRengFut_4C_array / dwnpopyear_fut_array
        
        # Population Densities
        popden2020_array = pop2020_array_XWet / area_array
        popdenyear_fut_2C_array = popyear_fut_2C_array_XWet / area_array
        popdenyear_fut_4C_array = popyear_fut_4C_array_XWet / area_array

        dwnpopden2020_array = dwnpop2020_array_XWet / area_array
        dwnpopdenyear_fut_2C_array = dwnpopyear_fut_2C_array_XWet / area_array
        dwnpopdenyear_fut_4C_array = dwnpopyear_fut_4C_array_XWet / area_array   
        
        dwnpopHIGH_den_ClimTiCont_array = dwnpopHIGH_ClimTiCont_array / area_array
        dwnpopLOW_den_ClimTRnatCont_array = dwnpopLOW_ClimTRnatCont_array / area_array
        dwnpopLOW_den_ClimTRengCont_array = dwnpopLOW_ClimTRengCont_array / area_array
        
        dwnpopHIGH_den_ClimTiFut_2C_array = dwnpopHIGH_ClimTiFut_2C_array / area_array
        dwnpopLOW_den_ClimTRnatFut_2C_array = dwnpopLOW_ClimTRnatFut_2C_array / area_array
        dwnpopLOW_den_ClimTRengFut_2C_array = dwnpopLOW_ClimTRengFut_2C_array / area_array
        
        dwnpopHIGH_den_ClimTiFut_4C_array = dwnpopHIGH_ClimTiFut_4C_array / area_array
        dwnpopLOW_den_ClimTRnatFut_4C_array = dwnpopLOW_ClimTRnatFut_4C_array / area_array
        dwnpopLOW_den_ClimTRengFut_4C_array = dwnpopLOW_ClimTRengFut_4C_array / area_array
    
    # CREATE BIG SUB-NATIONAL TABLE AND APPLY SUB-NATIONAL FINAL CALCS
    
    print(" Create Contemporary table")    
    model_adm_table_attr = pd.DataFrame({'ObjectID': unqID, 'SubNational Area (km2)': area_array, 
                                        'Fraction Land Area XWet (2020)': area_2020_frac_array, 
                                        'Fraction Population XWet (2020)': pop2020_frac_array, 
                                        'Fraction Downstream Population XWet (2020)': dwnpop2020_frac_array,
                                        'Fraction Dwnpop High Climate Impacted Ti': dwnpopHIGH_frac_ClimTiCont_array,
                                        'Fraction Dwnpop Low Climate Impacted TRnat': dwnpopLOW_frac_ClimTRnatCont_array,
                                        'Fraction Dwnpop Low Climate Impacted TReng': dwnpopLOW_frac_ClimTRengCont_array,
                                        'Population Density XWet (2020)': popden2020_array, 
                                        'Downstream Population Density XWet (2020)': dwnpopden2020_array,
                                        'Dwnpop Density High Climate Impacted Ti': dwnpopHIGH_den_ClimTiCont_array,
                                        'Dwnpop Density Low Climate Impacted TRnat': dwnpopLOW_den_ClimTRnatCont_array,
                                        'Dwnpop Density Low Climate Impacted TReng': dwnpopLOW_den_ClimTRengCont_array},
                                       columns=['ObjectID', 'SubNational Area (km2)', 
                                                'Fraction Land Area XWet (2020)',                                          
                                                'Fraction Population XWet (2020)', 
                                                'Fraction Downstream Population XWet (2020)',
                                                'Fraction Dwnpop High Climate Impacted Ti',
                                                'Fraction Dwnpop Low Climate Impacted TRnat',
                                                'Fraction Dwnpop Low Climate Impacted TReng',
                                                'Population Density XWet (2020)', 
                                                'Downstream Population Density XWet (2020)',
                                                'Dwnpop Density High Climate Impacted Ti',
                                                'Dwnpop Density Low Climate Impacted TRnat',
                                                'Dwnpop Density Low Climate Impacted TReng'])
    model_adm_table_attr = model_adm_table_attr[model_adm_table_attr.ObjectID != -9999]


    model_adm_table_HML_ThreatsCapacity = pd.DataFrame({'ObjectID': unqID, 
                                               'Dwnpop High Climate Impacted Ti': dwnpopHIGH_ClimTiCont_array, 
                                               'Dwnpop Mod Climate Impacted Ti': dwnpopMOD_ClimTiCont_array, 
                                               'Dwnpop Low Climate Impacted Ti': dwnpopLOW_ClimTiCont_array,
                                                'Dwnpop High Climate Impacted TRnat': dwnpopHIGH_ClimTRnatCont_array, 
                                                'Dwnpop Mod Climate Impacted TRnat': dwnpopMOD_ClimTRnatCont_array, 
                                                'Dwnpop Low Climate Impacted TRnat': dwnpopLOW_ClimTRnatCont_array, 
                                                'Dwnpop High Climate Impacted TReng': dwnpopHIGH_ClimTRengCont_array, 
                                                'Dwnpop Mod Climate Impacted TReng': dwnpopMOD_ClimTRengCont_array, 
                                                'Dwnpop Low Climate Impacted TReng': dwnpopLOW_ClimTRengCont_array},
                                              columns=['ObjectID', 
                                                       'Dwnpop High Climate Impacted Ti', 
                                                       'Dwnpop Mod Climate Impacted Ti', 
                                                       'Dwnpop Low Climate Impacted Ti',
                                                       'Dwnpop High Climate Impacted TRnat', 
                                                        'Dwnpop Mod Climate Impacted TRnat', 
                                                        'Dwnpop Low Climate Impacted TRnat', 
                                                        'Dwnpop High Climate Impacted TReng', 
                                                        'Dwnpop Mod Climate Impacted TReng', 
                                                        'Dwnpop Low Climate Impacted TReng'])
    model_adm_table_HML_ThreatsCapacity = model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity.ObjectID != -9999]

    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 0].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 0].index, inplace = True)
        
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 21909].index, inplace = True)

    filenmXL = out_dir + 'Model_' + str(adm) + '_AggrVariables_Contemp_XWet.xlsx'
    with pd.ExcelWriter(filenmXL) as writer:
            model_adm_table_attr.to_excel(writer, index=False, sheet_name='model_adm SubNational Attributes')    
            model_adm_table_HML_ThreatsCapacity.to_excel(writer, index=False, sheet_name='HiModLo Classes')
            
            
    print(" Create 2C table")
    
    model_adm_table_attr = pd.DataFrame({'ObjectID': unqID, 'SubNational Area (km2)': area_array,  
                                        'Fraction Land Area XWet 2C (' + str(year_fut) + ')': area_year_fut_frac_2C_array,
                                        'Fraction Population XWet 2C (' + str(year_fut) + ')': popyear_fut_frac_2C_array, 
                                        'Fraction Downstream Population XWet 2C (' + str(year_fut) + ')': dwnpopyear_fut_frac_2C_array,
                                        'Fraction Dwnpop High Climate Impacted Ti': dwnpopHIGH_frac_ClimTiFut_2C_array,
                                        'Fraction Dwnpop Low Climate Impacted TRnat': dwnpopLOW_frac_ClimTRnatFut_2C_array,
                                        'Fraction Dwnpop Low Climate Impacted TReng': dwnpopLOW_frac_ClimTRengFut_2C_array,                                        
                                        'Population Density XWet (' + str(year_fut) + ')': popdenyear_fut_2C_array, 
                                        'Downstream Population Density XWet (' + str(year_fut) + ')': dwnpopdenyear_fut_2C_array,
                                        'Dwnpop Density High Climate Impacted Ti': dwnpopHIGH_den_ClimTiFut_2C_array,
                                        'Dwnpop Density Low Climate Impacted TRnat': dwnpopLOW_den_ClimTRnatFut_2C_array,
                                        'Dwnpop Density Low Climate Impacted TReng': dwnpopLOW_den_ClimTRengFut_2C_array},
                                       columns=['ObjectID', 'SubNational Area (km2)', 
                                                'Fraction Land Area XWet 2C (' + str(year_fut) + ')',
                                                'Fraction Population XWet 2C (' + str(year_fut) + ')', 
                                                'Fraction Downstream Population XWet 2C (' + str(year_fut) + ')',
                                                'Fraction Dwnpop High Climate Impacted Ti',
                                                'Fraction Dwnpop Low Climate Impacted TRnat',
                                                'Fraction Dwnpop Low Climate Impacted TReng',
                                                'Population Density XWet (' + str(year_fut) + ')', 
                                                'Downstream Population Density XWet (' + str(year_fut) + ')',
                                                'Dwnpop Density High Climate Impacted Ti',
                                                'Dwnpop Density Low Climate Impacted TRnat',
                                                'Dwnpop Density Low Climate Impacted TReng'])
    model_adm_table_attr = model_adm_table_attr[model_adm_table_attr.ObjectID != -9999]

    model_adm_table_HML_ThreatsCapacity = pd.DataFrame({'ObjectID': unqID, 
                                               'Dwnpop High Climate Impacted Ti': dwnpopHIGH_ClimTiFut_2C_array, 
                                               'Dwnpop Mod Climate Impacted Ti': dwnpopMOD_ClimTiFut_2C_array, 
                                               'Dwnpop Low Climate Impacted Ti': dwnpopLOW_ClimTiFut_2C_array,
                                               'Dwnpop High Climate Impacted TRnat': dwnpopHIGH_ClimTRnatFut_2C_array, 
                                               'Dwnpop Mod Climate Impacted TRnat': dwnpopMOD_ClimTRnatFut_2C_array, 
                                               'Dwnpop Low Climate Impacted TRnat': dwnpopLOW_ClimTRnatFut_2C_array, 
                                               'Dwnpop High Climate Impacted TReng': dwnpopHIGH_ClimTRengFut_2C_array, 
                                               'Dwnpop Mod Climate Impacted TReng': dwnpopMOD_ClimTRengFut_2C_array, 
                                               'Dwnpop Low Climate Impacted TReng': dwnpopLOW_ClimTRengFut_2C_array}, 
                                              columns=['ObjectID', 
                                                       'Dwnpop High Climate Impacted Ti', 
                                                       'Dwnpop Mod Climate Impacted Ti', 
                                                       'Dwnpop Low Climate Impacted Ti',
                                                       'Dwnpop High Climate Impacted TRnat', 
                                                       'Dwnpop Mod Climate Impacted TRnat', 
                                                       'Dwnpop Low Climate Impacted TRnat', 
                                                       'Dwnpop High Climate Impacted TReng', 
                                                       'Dwnpop Mod Climate Impacted TReng', 
                                                       'Dwnpop Low Climate Impacted TReng'])
    model_adm_table_HML_ThreatsCapacity = model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity.ObjectID != -9999]
    
    model_adm_table_TrajClimTi = pd.DataFrame({'ObjectID': unqID, 
                                               'DwnPop Persistent High Threats Climate Impacted Ti': dwnpop_TiCV_StaysHiThreat_2C_array, 
                                               'DwnPop Expected Accelerated Threats Climate Impacted Ti': dwnpop_TiCV_fromLowModThreat2Hi_2C_array, 
                                               'DwnPop Expected Decreased Threats Climate Impacted Ti': dwnpop_TiCV_fromHiThreat2LowMod_2C_array, 
                                               'DwnPop Sustained Lower Threats Climate Impacted Ti': dwnpop_TiCV_StaysLowModThreat_2C_array}, 
                                              columns=['ObjectID', 
                                                       'DwnPop Persistent High Threats Climate Impacted Ti', 
                                                       'DwnPop Expected Accelerated Threats Climate Impacted Ti', 
                                                       'DwnPop Expected Decreased Threats Climate Impacted Ti', 
                                                       'DwnPop Sustained Lower Threats Climate Impacted Ti'])
    model_adm_table_TrajClimTi = model_adm_table_TrajClimTi[model_adm_table_TrajClimTi.ObjectID != -9999]

    
    model_adm_table_TrajTRnat = pd.DataFrame({'ObjectID': unqID, 
                                                'DwnPop Persistent Low Threat Reduction Capacity TRnat': dwnpop_TRnat_StaysLowCapacity_2C_array, 
                                                'DwnPop Expected Diminished Threat Reduction Capacity TRnat': dwnpop_TRnat_fromModHiCapacity2Low_2C_array, 
                                                'DwnPop Expected Increased Threat Reduction Capacity TRnat': dwnpop_TRnat_fromLowCapacity2ModHi_2C_array, 
                                                'DwnPop Sustained Higher Threat Reduction Capacity TRnat': dwnpop_TRnat_StaysModHiCapacity_2C_array}, 
                                              columns=['ObjectID', 
                                                        'DwnPop Persistent Low Threat Reduction Capacity TRnat', 
                                                        'DwnPop Expected Diminished Threat Reduction Capacity TRnat', 
                                                        'DwnPop Expected Increased Threat Reduction Capacity TRnat', 
                                                        'DwnPop Sustained Higher Threat Reduction Capacity TRnat'])
    model_adm_table_TrajTRnat = model_adm_table_TrajTRnat[model_adm_table_TrajTRnat.ObjectID != -9999]
    
    model_adm_table_TrajTReng = pd.DataFrame({'ObjectID': unqID, 
                                                'DwnPop Persistent Low Threat Reduction Capacity TReng': dwnpop_TReng_StaysLowCapacity_2C_array, 
                                                'DwnPop Expected Diminished Threat Reduction Capacity TReng': dwnpop_TReng_fromModHiCapacity2Low_2C_array, 
                                                'DwnPop Expected Increased Threat Reduction Capacity TReng': dwnpop_TReng_fromLowCapacity2ModHi_2C_array, 
                                                'DwnPop Sustained Higher Threat Reduction Capacity TReng': dwnpop_TReng_StaysModHiCapacity_2C_array}, 
                                              columns=['ObjectID', 
                                                        'DwnPop Persistent Low Threat Reduction Capacity TReng', 
                                                        'DwnPop Expected Diminished Threat Reduction Capacity TReng', 
                                                        'DwnPop Expected Increased Threat Reduction Capacity TReng', 
                                                        'DwnPop Sustained Higher Threat Reduction Capacity TReng'])
    model_adm_table_TrajTReng = model_adm_table_TrajTReng[model_adm_table_TrajTReng.ObjectID != -9999]

    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 0].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajClimTi.drop(model_adm_table_TrajClimTi[model_adm_table_TrajClimTi['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajTRnat.drop(model_adm_table_TrajTRnat[model_adm_table_TrajTRnat['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajTReng.drop(model_adm_table_TrajTReng[model_adm_table_TrajTReng['ObjectID'] == 0].index, inplace = True)
        
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajClimTi.drop(model_adm_table_TrajClimTi[model_adm_table_TrajClimTi['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajTRnat.drop(model_adm_table_TrajTRnat[model_adm_table_TrajTRnat['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajTReng.drop(model_adm_table_TrajTReng[model_adm_table_TrajTReng['ObjectID'] == 21909].index, inplace = True)


    filenmXL = out_dir + 'Model_' + str(adm) + '_AggrVariables_' + str(year_fut) + '_2C_XWet.xlsx'
    with pd.ExcelWriter(filenmXL) as writer:
            model_adm_table_attr.to_excel(writer, index=False, sheet_name='model_adm SubNational Attributes')    
            model_adm_table_HML_ThreatsCapacity.to_excel(writer, index=False, sheet_name='HiModLo Classes')
            model_adm_table_TrajClimTi.to_excel(writer, index=False, sheet_name='Ti Threat Trajectories')
            model_adm_table_TrajTRnat.to_excel(writer, index=False, sheet_name='TRnat Trajectories')
            model_adm_table_TrajTReng.to_excel(writer, index=False, sheet_name='TReng Trajectories')


    print(" Create 4C table")
        
    model_adm_table_attr = pd.DataFrame({'ObjectID': unqID, 'SubNational Area (km2)': area_array,  
                                        'Fraction Land Area XWet 4C (' + str(year_fut) + ')': area_year_fut_frac_4C_array,
                                        'Fraction Population XWet 4C (' + str(year_fut) + ')': popyear_fut_frac_4C_array, 
                                        'Fraction Downstream Population XWet 4C (' + str(year_fut) + ')': dwnpopyear_fut_frac_4C_array,
                                        'Fraction Dwnpop High Climate Impacted Ti': dwnpopHIGH_frac_ClimTiFut_4C_array,
                                        'Fraction Dwnpop Low Climate Impacted TRnat': dwnpopLOW_frac_ClimTRnatFut_4C_array,
                                        'Fraction Dwnpop Low Climate Impacted TReng': dwnpopLOW_frac_ClimTRengFut_4C_array,                                        
                                        'Population Density XWet (' + str(year_fut) + ')': popdenyear_fut_4C_array, 
                                        'Downstream Population Density XWet (' + str(year_fut) + ')': dwnpopdenyear_fut_4C_array,
                                        'Dwnpop Density High Climate Impacted Ti': dwnpopHIGH_den_ClimTiFut_4C_array,
                                        'Dwnpop Density Low Climate Impacted TRnat': dwnpopLOW_den_ClimTRnatFut_4C_array,
                                        'Dwnpop Density Low Climate Impacted TReng': dwnpopLOW_den_ClimTRengFut_4C_array},
                                       columns=['ObjectID', 'SubNational Area (km2)', 
                                                'Fraction Land Area XWet 4C (' + str(year_fut) + ')',
                                                'Fraction Population XWet 4C (' + str(year_fut) + ')', 
                                                'Fraction Downstream Population XWet 4C (' + str(year_fut) + ')',
                                                'Fraction Dwnpop High Climate Impacted Ti',
                                                'Fraction Dwnpop Low Climate Impacted TRnat',
                                                'Fraction Dwnpop Low Climate Impacted TReng',
                                                'Population Density XWet (' + str(year_fut) + ')', 
                                                'Downstream Population Density XWet (' + str(year_fut) + ')',
                                                'Dwnpop Density High Climate Impacted Ti',
                                                'Dwnpop Density Low Climate Impacted TRnat',
                                                'Dwnpop Density Low Climate Impacted TReng'])
    model_adm_table_attr = model_adm_table_attr[model_adm_table_attr.ObjectID != -9999]

    model_adm_table_HML_ThreatsCapacity = pd.DataFrame({'ObjectID': unqID, 
                                               'Dwnpop High Climate Impacted Ti': dwnpopHIGH_ClimTiFut_4C_array, 
                                               'Dwnpop Mod Climate Impacted Ti': dwnpopMOD_ClimTiFut_4C_array, 
                                               'Dwnpop Low Climate Impacted Ti': dwnpopLOW_ClimTiFut_4C_array,
                                               'Dwnpop High Climate Impacted TRnat': dwnpopHIGH_ClimTRnatFut_4C_array, 
                                               'Dwnpop Mod Climate Impacted TRnat': dwnpopMOD_ClimTRnatFut_4C_array, 
                                               'Dwnpop Low Climate Impacted TRnat': dwnpopLOW_ClimTRnatFut_4C_array, 
                                               'Dwnpop High Climate Impacted TReng': dwnpopHIGH_ClimTRengFut_4C_array, 
                                               'Dwnpop Mod Climate Impacted TReng': dwnpopMOD_ClimTRengFut_4C_array, 
                                               'Dwnpop Low Climate Impacted TReng': dwnpopLOW_ClimTRengFut_4C_array}, 
                                              columns=['ObjectID', 
                                                       'Dwnpop High Climate Impacted Ti', 
                                                       'Dwnpop Mod Climate Impacted Ti', 
                                                       'Dwnpop Low Climate Impacted Ti',
                                                       'Dwnpop High Climate Impacted TRnat', 
                                                       'Dwnpop Mod Climate Impacted TRnat', 
                                                       'Dwnpop Low Climate Impacted TRnat', 
                                                       'Dwnpop High Climate Impacted TReng', 
                                                       'Dwnpop Mod Climate Impacted TReng', 
                                                       'Dwnpop Low Climate Impacted TReng'])
    model_adm_table_HML_ThreatsCapacity = model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity.ObjectID != -9999]


    model_adm_table_TrajClimTi = pd.DataFrame({'ObjectID': unqID, 
                                               'DwnPop Persistent High Threats Climate Impacted Ti': dwnpop_TiCV_StaysHiThreat_4C_array, 
                                               'DwnPop Expected Accelerated Threats Climate Impacted Ti': dwnpop_TiCV_fromLowModThreat2Hi_4C_array, 
                                               'DwnPop Expected Decreased Threats Climate Impacted Ti': dwnpop_TiCV_fromHiThreat2LowMod_4C_array, 
                                               'DwnPop Sustained Lower Threats Climate Impacted Ti': dwnpop_TiCV_StaysLowModThreat_4C_array}, 
                                              columns=['ObjectID', 
                                                       'DwnPop Persistent High Threats Climate Impacted Ti', 
                                                       'DwnPop Expected Accelerated Threats Climate Impacted Ti', 
                                                       'DwnPop Expected Decreased Threats Climate Impacted Ti', 
                                                       'DwnPop Sustained Lower Threats Climate Impacted Ti'])
    model_adm_table_TrajClimTi = model_adm_table_TrajClimTi[model_adm_table_TrajClimTi.ObjectID != -9999]

    model_adm_table_TrajTRnat = pd.DataFrame({'ObjectID': unqID, 
                                                'DwnPop Persistent Low Threat Reduction Capacity TRnat': dwnpop_TRnat_StaysLowCapacity_4C_array, 
                                                'DwnPop Expected Diminished Threat Reduction Capacity TRnat': dwnpop_TRnat_fromModHiCapacity2Low_4C_array, 
                                                'DwnPop Expected Increased Threat Reduction Capacity TRnat': dwnpop_TRnat_fromLowCapacity2ModHi_4C_array, 
                                                'DwnPop Sustained Higher Threat Reduction Capacity TRnat': dwnpop_TRnat_StaysModHiCapacity_4C_array}, 
                                              columns=['ObjectID', 
                                                        'DwnPop Persistent Low Threat Reduction Capacity TRnat', 
                                                        'DwnPop Expected Diminished Threat Reduction Capacity TRnat', 
                                                        'DwnPop Expected Increased Threat Reduction Capacity TRnat', 
                                                        'DwnPop Sustained Higher Threat Reduction Capacity TRnat'])
    model_adm_table_TrajTRnat = model_adm_table_TrajTRnat[model_adm_table_TrajTRnat.ObjectID != -9999]
    
    model_adm_table_TrajTReng = pd.DataFrame({'ObjectID': unqID, 
                                                'DwnPop Persistent Low Threat Reduction Capacity TReng': dwnpop_TReng_StaysLowCapacity_4C_array, 
                                                'DwnPop Expected Diminished Threat Reduction Capacity TReng': dwnpop_TReng_fromModHiCapacity2Low_4C_array, 
                                                'DwnPop Expected Increased Threat Reduction Capacity TReng': dwnpop_TReng_fromLowCapacity2ModHi_4C_array, 
                                                'DwnPop Sustained Higher Threat Reduction Capacity TReng': dwnpop_TReng_StaysModHiCapacity_4C_array}, 
                                              columns=['ObjectID', 
                                                        'DwnPop Persistent Low Threat Reduction Capacity TReng', 
                                                        'DwnPop Expected Diminished Threat Reduction Capacity TReng', 
                                                        'DwnPop Expected Increased Threat Reduction Capacity TReng', 
                                                        'DwnPop Sustained Higher Threat Reduction Capacity TReng'])
    model_adm_table_TrajTReng = model_adm_table_TrajTReng[model_adm_table_TrajTReng.ObjectID != -9999]
 
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 0].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajClimTi.drop(model_adm_table_TrajClimTi[model_adm_table_TrajClimTi['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajTRnat.drop(model_adm_table_TrajTRnat[model_adm_table_TrajTRnat['ObjectID'] == 0].index, inplace = True)
    model_adm_table_TrajTReng.drop(model_adm_table_TrajTReng[model_adm_table_TrajTReng['ObjectID'] == 0].index, inplace = True)
        
    model_adm_table_attr.drop(model_adm_table_attr[model_adm_table_attr['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_HML_ThreatsCapacity.drop(model_adm_table_HML_ThreatsCapacity[model_adm_table_HML_ThreatsCapacity['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajClimTi.drop(model_adm_table_TrajClimTi[model_adm_table_TrajClimTi['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajTRnat.drop(model_adm_table_TrajTRnat[model_adm_table_TrajTRnat['ObjectID'] == 21909].index, inplace = True)
    model_adm_table_TrajTReng.drop(model_adm_table_TrajTReng[model_adm_table_TrajTReng['ObjectID'] == 21909].index, inplace = True)


    filenmXL = out_dir + 'Model_' + str(adm) + '_AggrVariables_' + str(year_fut) + '_4C_XWet.xlsx'
    with pd.ExcelWriter(filenmXL) as writer:
            model_adm_table_attr.to_excel(writer, index=False, sheet_name='model_adm SubNational Attributes')    
            model_adm_table_HML_ThreatsCapacity.to_excel(writer, index=False, sheet_name='HiModLo Classes')
            model_adm_table_TrajClimTi.to_excel(writer, index=False, sheet_name='Ti Threat Trajectories')
            model_adm_table_TrajTRnat.to_excel(writer, index=False, sheet_name='TRnat Trajectories')
            model_adm_table_TrajTReng.to_excel(writer, index=False, sheet_name='TReng Trajectories')

# %% [markdown]
# # Output Rasters for Map Production
#
# Includes derivation of climate impacted arrays for total downstream populations developed above based on downstream population density. The arrays normalizing downstream population by area can be used for creating map graphics.

# %%
print("Areas with Extreme Wet/Dry Anomalies - Binary")

outname = out_dir + 'ExtremeDry_Contemp.tif'
save2File(msk_Contemp_XDry_Binary[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'ExtremeDry_' + str(year_fut) + '_2C.tif'
save2File(msk_FutClim_2C_XDry_Binary[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'ExtremeDry_' + str(year_fut) + '_4C.tif'
save2File(msk_FutClim_4C_XDry_Binary[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'ExtremeWet_Contemp.tif'
save2File(msk_Contemp_XWet_Binary[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'ExtremeWet_' + str(year_fut) + '_2C.tif'
save2File(msk_FutClim_2C_XWet_Binary[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'ExtremeWet_' + str(year_fut) + '_4C.tif'
save2File(msk_FutClim_4C_XWet_Binary[:, :], outname, nrows6m, ncols6m, geotr6m)

print("Water Security Threats and Threat Reduction by TRnat,TReng")
print("  Contemporary")

outname = out_dir + 'RiverThreats_TiClimVar_Contemp_CDF.tif'
Ti_ClimVul_2005_CDF = np.where(Threat_nan == 1, 0, Ti_ClimVul_2005_CDF)
save2File(Ti_ClimVul_2005_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'ThreatReduction_TRnat_Contemp_CDF.tif'
TRnat_ClimVul_2005_CDF = np.where(Threat_nan == 1, 0, TRnat_ClimVul_2005_CDF)
save2File(TRnat_ClimVul_2005_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'ThreatReduction_TReng_Contemp_CDF.tif'
TReng_ClimVul_2005_CDF = np.where(Threat_nan == 1, 0, TReng_ClimVul_2005_CDF)
save2File(TReng_ClimVul_2005_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

print("  Future Climates..")
print("   2C")

outname = out_dir + 'RiverThreats_TiClimVar_' + str(year_fut) + '_2C_CDF.tif'
Ti_ClimVul_year_fut_2C_CDF = np.where(Threat_nan == 1, 0, Ti_ClimVul_year_fut_2C_CDF)
save2File(Ti_ClimVul_year_fut_2C_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'ThreatReduction_TRnat_' + str(year_fut) + '_2C_CDF.tif'
TRnat_ClimVul_year_fut_2C_CDF = np.where(Threat_nan == 1, 0, TRnat_ClimVul_year_fut_2C_CDF)
save2File(TRnat_ClimVul_year_fut_2C_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'ThreatReduction_TReng_' + str(year_fut) + '_2C_CDF.tif'
TReng_ClimVul_year_fut_2C_CDF = np.where(Threat_nan == 1, 0, TReng_ClimVul_year_fut_2C_CDF)
save2File(TReng_ClimVul_year_fut_2C_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

print("   4C")

outname = out_dir + 'RiverThreats_TiClimVar_' + str(year_fut) + '_4C_CDF.tif'
Ti_ClimVul_year_fut_4C_CDF = np.where(Threat_nan == 1, 0, Ti_ClimVul_year_fut_4C_CDF)
save2File(Ti_ClimVul_year_fut_4C_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'ThreatReduction_TRnat_' + str(year_fut) + '_4C_CDF.tif'
TRnat_ClimVul_year_fut_4C_CDF = np.where(Threat_nan == 1, 0, TRnat_ClimVul_year_fut_4C_CDF)
save2File(TRnat_ClimVul_year_fut_4C_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'ThreatReduction_TReng_' + str(year_fut) + '_4C_CDF.tif'
TReng_ClimVul_year_fut_4C_CDF = np.where(Threat_nan == 1, 0, TReng_ClimVul_year_fut_4C_CDF)
save2File(TReng_ClimVul_year_fut_4C_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

print("Water Security Threats and Threat Reduction Change Categories")

outname = out_dir + 'RiverThreats_TiClimVar_' + str(year_fut) + '_2C_ChangeCat.tif'
TiClimVar_Change_year_fut_2C = np.where(Threat_nan == 1, 0, TiClimVar_Change_year_fut_2C)
save2File(TiClimVar_Change_year_fut_2C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'ThreatReduction_TRnat_' + str(year_fut) + '_2C_ChangeCat.tif'
TRnat_Change_year_fut_2C = np.where(Threat_nan == 1, 0, TRnat_Change_year_fut_2C)
save2File(TRnat_Change_year_fut_2C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'ThreatReduction_TReng_' + str(year_fut) + '_2C_ChangeCat.tif'
TReng_Change_year_fut_2C = np.where(Threat_nan == 1, 0, TReng_Change_year_fut_2C)
save2File(TReng_Change_year_fut_2C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'RiverThreats_TiClimVar_' + str(year_fut) + '_4C_ChangeCat.tif'
TiClimVar_Change_year_fut_4C = np.where(Threat_nan == 1, 0, TiClimVar_Change_year_fut_4C)
save2File(TiClimVar_Change_year_fut_4C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'ThreatReduction_TRnat_' + str(year_fut) + '_4C_ChangeCat.tif'
TRnat_Change_year_fut_4C = np.where(Threat_nan == 1, 0, TRnat_Change_year_fut_4C)
save2File(TRnat_Change_year_fut_4C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'ThreatReduction_TReng_' + str(year_fut) + '_4C_ChangeCat.tif'
TReng_Change_year_fut_4C = np.where(Threat_nan == 1, 0, TReng_Change_year_fut_4C)
save2File(TReng_Change_year_fut_4C[:, :], outname, nrows6m, ncols6m, geotr6m)

# %% [markdown]
# ## Downstream Population DENSITY under Climate Vulnerability (<i>ClimVar<sub>contemp</sub> , ClimVar<sub>future</sub></i>), <i>Climate Impacted Ti</i>, <i>Climate Impacted TRnat</i> and <i>Climate Impacted TReng</i>
#
# Population denisty is used to create map graphics in the report

# %%
dwnp_2020_den = dwnp_2020 / CellArea6m
dwnp_year_fut_den = dwnp_year_fut / CellArea6m

# > 0.7 for TRnat and TReng = HIGH Capacity (BLUE)
# < 0.3 for TRnat and TReng = LOW Capacity (RED)

print("Create Low-Mod-High arrays..")
print("  Contemporary")
dwnpopden_TiORIG2020_low = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 < 0.3, dwnp_2020_den, 0))
dwnpopden_TiORIGyear_fut_low = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut < 0.3, dwnp_year_fut_den, 0))
dwnpopden_TiORIG2020_mod = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.3, np.where(Ti_2005 < 0.7, dwnp_2020_den, 0), 0))
dwnpopden_TiORIGyear_fut_mod = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.3, np.where(Ti_year_fut < 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_TiORIG2020_high = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.7, dwnp_2020_den, 0))
dwnpopden_TiORIGyear_fut_high = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_den, 0))

dwnpopden_CV2020_low = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.3, dwnp_2020_den, 0))
dwnpopden_Ti2020_low = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.3, dwnp_2020_den, 0))
dwnpopden_TRnat2020_high = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.7, dwnp_2020_den, 0))
dwnpopden_TReng2020_high = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.7, dwnp_2020_den, 0))

dwnpopden_CV2020_mod = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.3, np.where(TS_Contemp_CV_CDF < 0.7, dwnp_2020_den, 0), 0))
dwnpopden_Ti2020_mod = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.3, np.where(Ti_ClimVul_2005_CDF < 0.7, dwnp_2020_den, 0), 0))
dwnpopden_TRnat2020_mod = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.7, np.where(TRnat_ClimVul_2005_CDF >= 0.3, dwnp_2020_den, 0), 0))
dwnpopden_TReng2020_mod = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.7, np.where(TReng_ClimVul_2005_CDF >= 0.3, dwnp_2020_den, 0), 0))

dwnpopden_CV2020_high = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, dwnp_2020_den, 0))
dwnpopden_Ti2020_high = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, dwnp_2020_den, 0))
dwnpopden_TRnat2020_low = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, dwnp_2020_den, 0))
dwnpopden_TReng2020_low = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, dwnp_2020_den, 0))

print("  2C")
dwnpopden_CVyear_fut_2C_low = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF < 0.3, dwnp_year_fut_den, 0))
dwnpopden_Tiyear_fut_2C_low = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_den, 0))
dwnpopden_TRnatyear_fut_2C_high = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_den, 0))
dwnpopden_TRengyear_fut_2C_high = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_den, 0))

dwnpopden_CVyear_fut_2C_mod = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.3, np.where(TS_FutClim_2C_CV_CDF < 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_Tiyear_fut_2C_mod = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.3, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_TRnatyear_fut_2C_mod = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.7, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TRengyear_fut_2C_mod = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.7, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_den, 0), 0))

dwnpopden_CVyear_fut_2C_high = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut_den, 0))
dwnpopden_Tiyear_fut_2C_high = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_den, 0))
dwnpopden_TRnatyear_fut_2C_low = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_den, 0))
dwnpopden_TRengyear_fut_2C_low = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_den, 0))

print("  4C")
dwnpopden_CVyear_fut_4C_low = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF < 0.3, dwnp_year_fut_den, 0))
dwnpopden_Tiyear_fut_4C_low = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_den, 0))
dwnpopden_TRnatyear_fut_4C_high = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_den, 0))
dwnpopden_TRengyear_fut_4C_high = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_den, 0))

dwnpopden_CVyear_fut_4C_mod = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.3, np.where(TS_FutClim_4C_CV_CDF < 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_Tiyear_fut_4C_mod = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.3, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_TRnatyear_fut_4C_mod = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.7, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TRengyear_fut_4C_mod = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.7, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_den, 0), 0))

dwnpopden_CVyear_fut_4C_high = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut_den, 0))
dwnpopden_Tiyear_fut_4C_high = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_den, 0))
dwnpopden_TRnatyear_fut_4C_low = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_den, 0))
dwnpopden_TRengyear_fut_4C_low = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_den, 0))

print("Create Change Classes..")

dwnpopden_TiORIG_StaysLowModThreat = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 < 0.7, np.where(Ti_year_fut < 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_TiORIG_StaysHiThreat = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.7, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_TiORIG_fromLowModThreat2Hi = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 < 0.7, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_TiORIG_ConH_FutL = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.7, np.where(Ti_year_fut < 0.7, dwnp_year_fut_den, 0), 0))

print("  2C")

TiClimVar_StaysHiThreat_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, 1, 0), 0))
TiClimVar_fromLowModThreat2Hi_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, 2, 0), 0))
TiClimVar_fromHiThreat2LowMod_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, 3, 0), 0))
TiClimVar_StaysLowModThreat_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, 4, 0), 0))
TiClimVar_Change_year_fut_2C = TiClimVar_StaysLowModThreat_2C + TiClimVar_StaysHiThreat_2C + TiClimVar_fromLowModThreat2Hi_2C + TiClimVar_fromHiThreat2LowMod_2C

TRnat_StaysLowCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, 1, 0), 0))
TRnat_fromModHiCapacity2Low_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, 2, 0), 0))
TRnat_fromLowCapacity2ModHi_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, 3, 0), 0))
TRnat_StaysModHiCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, 4, 0), 0))
TRnat_Change_year_fut_2C = TRnat_StaysLowCapacity_2C + TRnat_fromModHiCapacity2Low_2C + TRnat_fromLowCapacity2ModHi_2C + TRnat_StaysModHiCapacity_2C

TReng_StaysLowCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, 1, 0), 0))
TReng_fromModHiCapacity2Low_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, 2, 0), 0))
TReng_fromLowCapacity2ModHi_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, 3, 0), 0))
TReng_StaysModHiCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, 4, 0), 0))
TReng_Change_year_fut_2C = TReng_StaysLowCapacity_2C + TReng_fromModHiCapacity2Low_2C + TReng_fromLowCapacity2ModHi_2C + TReng_StaysModHiCapacity_2C

dwnpopden_CV_StaysLowModThreat_2C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.7, np.where(TS_FutClim_2C_CV_CDF < 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_CV_StaysHiThreat_2C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_CV_fromLowModThreat2Hi_2C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.7, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_CV_fromHiThreat2LowMod_2C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, np.where(TS_FutClim_2C_CV_CDF < 0.7, dwnp_year_fut_den, 0), 0))

dwnpopden_TiCV_StaysLowModThreat_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_TiCV_StaysHiThreat_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_TiCV_fromLowModThreat2Hi_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_TiCV_fromHiThreat2LowMod_2C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, dwnp_year_fut_den, 0), 0))

dwnpopden_TRnat_StaysLowCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TRnat_StaysModHiCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TRnat_fromLowCapacity2ModHi_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TRnat_fromModHiCapacity2Low_2C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_den, 0), 0))

dwnpopden_TReng_StaysLowCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TReng_StaysModHiCapacity_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TReng_fromLowCapacity2ModHi_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TReng_fromModHiCapacity2Low_2C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_den, 0), 0))

ratio_Q_CDF_2C = TS_FutClim_2C_CV_CDF / TS_Contemp_CV_CDF

print("  4C")

TiClimVar_StaysHiThreat_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, 1, 0), 0))
TiClimVar_fromLowModThreat2Hi_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, 2, 0), 0))
TiClimVar_fromHiThreat2LowMod_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, 3, 0), 0))
TiClimVar_StaysLowModThreat_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, 4, 0), 0))
TiClimVar_Change_year_fut_4C = TiClimVar_StaysLowModThreat_4C + TiClimVar_StaysHiThreat_4C + TiClimVar_fromLowModThreat2Hi_4C + TiClimVar_fromHiThreat2LowMod_4C

TRnat_StaysLowCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, 1, 0), 0))
TRnat_fromModHiCapacity2Low_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, 2, 0), 0))
TRnat_fromLowCapacity2ModHi_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, 3, 0), 0))
TRnat_StaysModHiCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, 4, 0), 0))
TRnat_Change_year_fut_4C = TRnat_StaysLowCapacity_4C + TRnat_fromModHiCapacity2Low_4C + TRnat_fromLowCapacity2ModHi_4C + TRnat_StaysModHiCapacity_4C

TReng_StaysLowCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, 1, 0), 0))
TReng_fromModHiCapacity2Low_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, 2, 0), 0))
TReng_fromLowCapacity2ModHi_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, 3, 0), 0))
TReng_StaysModHiCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, 4, 0), 0))
TReng_Change_year_fut_4C = TReng_StaysLowCapacity_4C + TReng_fromModHiCapacity2Low_4C + TReng_fromLowCapacity2ModHi_4C + TReng_StaysModHiCapacity_4C

dwnpopden_CV_StaysLowModThreat_4C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.7, np.where(TS_FutClim_4C_CV_CDF < 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_CV_StaysHiThreat_4C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_CV_fromLowModThreat2Hi_4C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.7, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_CV_fromHiThreat2LowMod_4C = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, np.where(TS_FutClim_4C_CV_CDF < 0.7, dwnp_year_fut_den, 0), 0))

dwnpopden_TiCV_StaysLowModThreat_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_TiCV_StaysHiThreat_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_TiCV_fromLowModThreat2Hi_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_den, 0), 0))
dwnpopden_TiCV_fromHiThreat2LowMod_4C = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, dwnp_year_fut_den, 0), 0))

dwnpopden_TRnat_StaysLowCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TRnat_StaysModHiCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TRnat_fromLowCapacity2ModHi_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TRnat_fromModHiCapacity2Low_4C = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.3, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_den, 0), 0))

dwnpopden_TReng_StaysLowCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TReng_StaysModHiCapacity_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TReng_fromLowCapacity2ModHi_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_den, 0), 0))
dwnpopden_TReng_fromModHiCapacity2Low_4C = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.3, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_den, 0), 0))

ratio_Q_CDF_4C = TS_FutClim_4C_CV_CDF / TS_Contemp_CV_CDF

# %% [markdown]
# ## Extremely DRY: Downstream Population DENSITY under Climate Vulnerability (<i>ClimVar<sub>contemp</sub> , ClimVar<sub>future</sub>></i>), <i>Climate Impacted Ti</i>, <i>Climate Impacted TRnat</i> and <i>Climate Impacted TReng</i>

# %%
dwnp_2020_den_XDry = np.where(msk_Contemp_XDry > 0, dwnp_2020 / CellArea6m, 0)
dwnp_year_fut_2C_den_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnp_year_fut / CellArea6m, 0)
dwnp_year_fut_4C_den_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnp_year_fut / CellArea6m, 0)

# > 0.7 for TRnat and TReng = HIGH Capacity (BLUE)
# < 0.3 for TRnat and TReng = LOW Capacity (RED)

print("Create Low-Mod-High arrays..")
print("  Contemporary")
dwnpopden_TiORIG2020_low_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 < 0.3, dwnp_2020_den_XDry, 0))
dwnpopden_TiORIG2020_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.3, np.where(Ti_2005 < 0.7, dwnp_2020_den_XDry, 0), 0))
dwnpopden_TiORIG2020_high_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.7, dwnp_2020_den_XDry, 0))

dwnpopden_TiORIGyear_fut_2C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut < 0.3, dwnp_year_fut_2C_den_XDry, 0))
dwnpopden_TiORIGyear_fut_2C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.3, np.where(Ti_year_fut < 0.7, dwnp_year_fut_2C_den_XDry, 0), 0))
dwnpopden_TiORIGyear_fut_2C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_2C_den_XDry, 0))

dwnpopden_TiORIGyear_fut_4C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut < 0.3, dwnp_year_fut_4C_den_XDry, 0))
dwnpopden_TiORIGyear_fut_4C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.3, np.where(Ti_year_fut < 0.7, dwnp_year_fut_4C_den_XDry, 0), 0))
dwnpopden_TiORIGyear_fut_4C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_4C_den_XDry, 0))

dwnpopden_CV2020_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.3, dwnp_2020_den_XDry, 0))
dwnpopden_Ti2020_low_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.3, dwnp_2020_den_XDry, 0))
dwnpopden_TRnat2020_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.7, dwnp_2020_den_XDry, 0))
dwnpopden_TReng2020_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.7, dwnp_2020_den_XDry, 0))

dwnpopden_CV2020_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.3, np.where(TS_Contemp_CV_CDF < 0.7, dwnp_2020_den_XDry, 0), 0))
dwnpopden_Ti2020_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.3, np.where(Ti_ClimVul_2005_CDF < 0.7, dwnp_2020_den_XDry, 0), 0))
dwnpopden_TRnat2020_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.7, np.where(TRnat_ClimVul_2005_CDF >= 0.3, dwnp_2020_den_XDry, 0), 0))
dwnpopden_TReng2020_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.7, np.where(TReng_ClimVul_2005_CDF >= 0.3, dwnp_2020_den_XDry, 0), 0))

dwnpopden_CV2020_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, dwnp_2020_den_XDry, 0))
dwnpopden_Ti2020_high_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, dwnp_2020_den_XDry, 0))
dwnpopden_TRnat2020_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, dwnp_2020_den_XDry, 0))
dwnpopden_TReng2020_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, dwnp_2020_den_XDry, 0))

print("  2C")
dwnpopden_CVyear_fut_2C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF < 0.3, dwnp_year_fut_2C_den_XDry, 0))
dwnpopden_Tiyear_fut_2C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_den_XDry, 0))
dwnpopden_TRnatyear_fut_2C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_den_XDry, 0))
dwnpopden_TRengyear_fut_2C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_den_XDry, 0))

dwnpopden_CVyear_fut_2C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.3, np.where(TS_FutClim_2C_CV_CDF < 0.7, dwnp_year_fut_2C_den_XDry, 0), 0))
dwnpopden_Tiyear_fut_2C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.3, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, dwnp_year_fut_2C_den_XDry, 0), 0))
dwnpopden_TRnatyear_fut_2C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.7, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_2C_den_XDry, 0), 0))
dwnpopden_TRengyear_fut_2C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.7, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_2C_den_XDry, 0), 0))

dwnpopden_CVyear_fut_2C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut_2C_den_XDry, 0))
dwnpopden_Tiyear_fut_2C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_den_XDry, 0))
dwnpopden_TRnatyear_fut_2C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_den_XDry, 0))
dwnpopden_TRengyear_fut_2C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_den_XDry, 0))

print("  4C")
dwnpopden_CVyear_fut_4C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF < 0.3, dwnp_year_fut_4C_den_XDry, 0))
dwnpopden_Tiyear_fut_4C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_den_XDry, 0))
dwnpopden_TRnatyear_fut_4C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_den_XDry, 0))
dwnpopden_TRengyear_fut_4C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_den_XDry, 0))

dwnpopden_CVyear_fut_4C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.3, np.where(TS_FutClim_4C_CV_CDF < 0.7, dwnp_year_fut_4C_den_XDry, 0), 0))
dwnpopden_Tiyear_fut_4C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.3, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, dwnp_year_fut_4C_den_XDry, 0), 0))
dwnpopden_TRnatyear_fut_4C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.7, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_4C_den_XDry, 0), 0))
dwnpopden_TRengyear_fut_4C_mod_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.7, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_4C_den_XDry, 0), 0))

dwnpopden_CVyear_fut_4C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut_4C_den_XDry, 0))
dwnpopden_Tiyear_fut_4C_high_XDry = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_den_XDry, 0))
dwnpopden_TRnatyear_fut_4C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_den_XDry, 0))
dwnpopden_TRengyear_fut_4C_low_XDry = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_den_XDry, 0))

print("Create Change Classes..")

print("  2C")

dwnpopden_CV_StaysLowModThreat_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_CV_StaysLowModThreat_2C, 0)
dwnpopden_CV_StaysHiThreat_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_CV_StaysHiThreat_2C, 0)
dwnpopden_CV_fromLowModThreat2Hi_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_CV_fromLowModThreat2Hi_2C, 0)
dwnpopden_CV_fromHiThreat2LowMod_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_CV_fromHiThreat2LowMod_2C, 0)

dwnpopden_TiCV_StaysLowModThreat_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_TiCV_StaysLowModThreat_2C, 0)
dwnpopden_TiCV_StaysHiThreat_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_TiCV_StaysHiThreat_2C, 0)
dwnpopden_TiCV_fromLowModThreat2Hi_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_TiCV_fromLowModThreat2Hi_2C, 0)
dwnpopden_TiCV_fromHiThreat2LowMod_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_TiCV_fromHiThreat2LowMod_2C, 0)

dwnpopden_TRnat_StaysLowCapacity_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_TRnat_StaysLowCapacity_2C, 0)
dwnpopden_TRnat_StaysModHiCapacity_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_TRnat_StaysModHiCapacity_2C, 0)
dwnpopden_TRnat_fromLowCapacity2ModHi_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_TRnat_fromLowCapacity2ModHi_2C, 0)
dwnpopden_TRnat_fromModHiCapacity2Low_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_TRnat_fromModHiCapacity2Low_2C, 0)

dwnpopden_TReng_StaysLowCapacity_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_TReng_StaysLowCapacity_2C, 0)
dwnpopden_TReng_StaysModHiCapacity_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_TReng_StaysModHiCapacity_2C, 0)
dwnpopden_TReng_fromLowCapacity2ModHi_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_TReng_fromLowCapacity2ModHi_2C, 0)
dwnpopden_TReng_fromModHiCapacity2Low_2C_XDry = np.where(msk_FutClim_2C_XDry > 0, dwnpopden_TReng_fromModHiCapacity2Low_2C, 0)

print("  4C")

dwnpopden_CV_StaysLowModThreat_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_CV_StaysLowModThreat_4C, 0)
dwnpopden_CV_StaysHiThreat_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_CV_StaysHiThreat_4C, 0)
dwnpopden_CV_fromLowModThreat2Hi_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_CV_fromLowModThreat2Hi_4C, 0)
dwnpopden_CV_fromHiThreat2LowMod_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_CV_fromHiThreat2LowMod_4C, 0)

dwnpopden_TiCV_StaysLowModThreat_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_TiCV_StaysLowModThreat_4C, 0)
dwnpopden_TiCV_StaysHiThreat_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_TiCV_StaysHiThreat_4C, 0)
dwnpopden_TiCV_fromLowModThreat2Hi_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_TiCV_fromLowModThreat2Hi_4C, 0)
dwnpopden_TiCV_fromHiThreat2LowMod_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_TiCV_fromHiThreat2LowMod_4C, 0)

dwnpopden_TRnat_StaysLowCapacity_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_TRnat_StaysLowCapacity_4C, 0)
dwnpopden_TRnat_StaysModHiCapacity_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_TRnat_StaysModHiCapacity_4C, 0)
dwnpopden_TRnat_fromLowCapacity2ModHi_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_TRnat_fromLowCapacity2ModHi_4C, 0)
dwnpopden_TRnat_fromModHiCapacity2Low_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_TRnat_fromModHiCapacity2Low_4C, 0)

dwnpopden_TReng_StaysLowCapacity_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_TReng_StaysLowCapacity_4C, 0)
dwnpopden_TReng_StaysModHiCapacity_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_TReng_StaysModHiCapacity_4C, 0)
dwnpopden_TReng_fromLowCapacity2ModHi_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_TReng_fromLowCapacity2ModHi_4C, 0)
dwnpopden_TReng_fromModHiCapacity2Low_4C_XDry = np.where(msk_FutClim_4C_XDry > 0, dwnpopden_TReng_fromModHiCapacity2Low_4C, 0)

#ratio_Q_CDF_4C_XDry = TS_FutClim_4C_CV_CDF / TS_Contemp_CV_CDF

# %% [markdown]
# ## Extremely WET: Downstream Population DENSITY under Climate Vulnerability (<i>ClimVar<sub>contemp</sub> , ClimVar<sub>future</sub>></i>), <i>Climate Impacted Ti</i>, <i>Climate Impacted TRnat</i> and <i>Climate Impacted TReng</i>

# %%
dwnp_2020_den_XWet = np.where(msk_Contemp_XWet > 0, dwnp_2020 / CellArea6m, 0)
dwnp_year_fut_2C_den_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnp_year_fut / CellArea6m, 0)
dwnp_year_fut_4C_den_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnp_year_fut / CellArea6m, 0)

# > 0.7 for TRnat and TReng = HIGH Capacity (BLUE)
# < 0.3 for TRnat and TReng = LOW Capacity (RED)

print("Create Low-Mod-High arrays..")
print("  Contemporary")
dwnpopden_TiORIG2020_low_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 < 0.3, dwnp_2020_den_XWet, 0))
dwnpopden_TiORIG2020_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.3, np.where(Ti_2005 < 0.7, dwnp_2020_den_XWet, 0), 0))
dwnpopden_TiORIG2020_high_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_2005 >= 0.7, dwnp_2020_den_XWet, 0))

dwnpopden_TiORIGyear_fut_2C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut < 0.3, dwnp_year_fut_2C_den_XWet, 0))
dwnpopden_TiORIGyear_fut_2C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.3, np.where(Ti_year_fut < 0.7, dwnp_year_fut_2C_den_XWet, 0), 0))
dwnpopden_TiORIGyear_fut_2C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_2C_den_XWet, 0))

dwnpopden_TiORIGyear_fut_4C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut < 0.3, dwnp_year_fut_4C_den_XWet, 0))
dwnpopden_TiORIGyear_fut_4C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.3, np.where(Ti_year_fut < 0.7, dwnp_year_fut_4C_den_XWet, 0), 0))
dwnpopden_TiORIGyear_fut_4C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_year_fut >= 0.7, dwnp_year_fut_4C_den_XWet, 0))

dwnpopden_CV2020_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF < 0.3, dwnp_2020_den_XWet, 0))
dwnpopden_Ti2020_low_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF < 0.3, dwnp_2020_den_XWet, 0))
dwnpopden_TRnat2020_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF >= 0.7, dwnp_2020_den_XWet, 0))
dwnpopden_TReng2020_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF >= 0.7, dwnp_2020_den_XWet, 0))

dwnpopden_CV2020_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.3, np.where(TS_Contemp_CV_CDF < 0.7, dwnp_2020_den_XWet, 0), 0))
dwnpopden_Ti2020_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.3, np.where(Ti_ClimVul_2005_CDF < 0.7, dwnp_2020_den_XWet, 0), 0))
dwnpopden_TRnat2020_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.7, np.where(TRnat_ClimVul_2005_CDF >= 0.3, dwnp_2020_den_XWet, 0), 0))
dwnpopden_TReng2020_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.7, np.where(TReng_ClimVul_2005_CDF >= 0.3, dwnp_2020_den_XWet, 0), 0))

dwnpopden_CV2020_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_Contemp_CV_CDF >= 0.7, dwnp_2020_den_XWet, 0))
dwnpopden_Ti2020_high_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_2005_CDF >= 0.7, dwnp_2020_den_XWet, 0))
dwnpopden_TRnat2020_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_2005_CDF < 0.3, dwnp_2020_den_XWet, 0))
dwnpopden_TReng2020_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_2005_CDF < 0.3, dwnp_2020_den_XWet, 0))

print("  2C")
dwnpopden_CVyear_fut_2C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF < 0.3, dwnp_year_fut_2C_den_XWet, 0))
dwnpopden_Tiyear_fut_2C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_den_XWet, 0))
dwnpopden_TRnatyear_fut_2C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_den_XWet, 0))
dwnpopden_TRengyear_fut_2C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_den_XWet, 0))

dwnpopden_CVyear_fut_2C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.3, np.where(TS_FutClim_2C_CV_CDF < 0.7, dwnp_year_fut_2C_den_XWet, 0), 0))
dwnpopden_Tiyear_fut_2C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.3, np.where(Ti_ClimVul_year_fut_2C_CDF < 0.7, dwnp_year_fut_2C_den_XWet, 0), 0))
dwnpopden_TRnatyear_fut_2C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.7, np.where(TRnat_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_2C_den_XWet, 0), 0))
dwnpopden_TRengyear_fut_2C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.7, np.where(TReng_ClimVul_year_fut_2C_CDF >= 0.3, dwnp_year_fut_2C_den_XWet, 0), 0))

dwnpopden_CVyear_fut_2C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_2C_CV_CDF >= 0.7, dwnp_year_fut_2C_den_XWet, 0))
dwnpopden_Tiyear_fut_2C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_2C_CDF >= 0.7, dwnp_year_fut_2C_den_XWet, 0))
dwnpopden_TRnatyear_fut_2C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_den_XWet, 0))
dwnpopden_TRengyear_fut_2C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_2C_CDF < 0.3, dwnp_year_fut_2C_den_XWet, 0))

print("  4C")
dwnpopden_CVyear_fut_4C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF < 0.3, dwnp_year_fut_4C_den_XWet, 0))
dwnpopden_Tiyear_fut_4C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_den_XWet, 0))
dwnpopden_TRnatyear_fut_4C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_den_XWet, 0))
dwnpopden_TRengyear_fut_4C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_den_XWet, 0))

dwnpopden_CVyear_fut_4C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.3, np.where(TS_FutClim_4C_CV_CDF < 0.7, dwnp_year_fut_4C_den_XWet, 0), 0))
dwnpopden_Tiyear_fut_4C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.3, np.where(Ti_ClimVul_year_fut_4C_CDF < 0.7, dwnp_year_fut_4C_den_XWet, 0), 0))
dwnpopden_TRnatyear_fut_4C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.7, np.where(TRnat_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_4C_den_XWet, 0), 0))
dwnpopden_TRengyear_fut_4C_mod_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.7, np.where(TReng_ClimVul_year_fut_4C_CDF >= 0.3, dwnp_year_fut_4C_den_XWet, 0), 0))

dwnpopden_CVyear_fut_4C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(TS_FutClim_4C_CV_CDF >= 0.7, dwnp_year_fut_4C_den_XWet, 0))
dwnpopden_Tiyear_fut_4C_high_XWet = np.where(flow_mask == 1, 0.000, np.where(Ti_ClimVul_year_fut_4C_CDF >= 0.7, dwnp_year_fut_4C_den_XWet, 0))
dwnpopden_TRnatyear_fut_4C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TRnat_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_den_XWet, 0))
dwnpopden_TRengyear_fut_4C_low_XWet = np.where(flow_mask == 1, 0.000, np.where(TReng_ClimVul_year_fut_4C_CDF < 0.3, dwnp_year_fut_4C_den_XWet, 0))

print("Create Change Classes..")

print("  2C")

dwnpopden_CV_StaysLowModThreat_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_CV_StaysLowModThreat_2C, 0)
dwnpopden_CV_StaysHiThreat_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_CV_StaysHiThreat_2C, 0)
dwnpopden_CV_fromLowModThreat2Hi_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_CV_fromLowModThreat2Hi_2C, 0)
dwnpopden_CV_fromHiThreat2LowMod_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_CV_fromHiThreat2LowMod_2C, 0)

dwnpopden_TiCV_StaysLowModThreat_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TiCV_StaysLowModThreat_2C, 0)
dwnpopden_TiCV_StaysHiThreat_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TiCV_StaysHiThreat_2C, 0)
dwnpopden_TiCV_fromLowModThreat2Hi_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TiCV_fromLowModThreat2Hi_2C, 0)
dwnpopden_TiCV_fromHiThreat2LowMod_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TiCV_fromHiThreat2LowMod_2C, 0)

dwnpopden_TRnat_StaysLowCapacity_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TRnat_StaysLowCapacity_2C, 0)
dwnpopden_TRnat_StaysModHiCapacity_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TRnat_StaysModHiCapacity_2C, 0)
dwnpopden_TRnat_fromLowCapacity2ModHi_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TRnat_fromLowCapacity2ModHi_2C, 0)
dwnpopden_TRnat_fromModHiCapacity2Low_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TRnat_fromModHiCapacity2Low_2C, 0)

dwnpopden_TReng_StaysLowCapacity_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TReng_StaysLowCapacity_2C, 0)
dwnpopden_TReng_StaysModHiCapacity_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TReng_StaysModHiCapacity_2C, 0)
dwnpopden_TReng_fromLowCapacity2ModHi_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TReng_fromLowCapacity2ModHi_2C, 0)
dwnpopden_TReng_fromModHiCapacity2Low_2C_XWet = np.where(msk_FutClim_2C_XWet > 0, dwnpop_TReng_fromModHiCapacity2Low_2C, 0)

print("  4C")

dwnpopden_CV_StaysLowModThreat_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_CV_StaysLowModThreat_4C, 0)
dwnpopden_CV_StaysHiThreat_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_CV_StaysHiThreat_4C, 0)
dwnpopden_CV_fromLowModThreat2Hi_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_CV_fromLowModThreat2Hi_4C, 0)
dwnpopden_CV_fromHiThreat2LowMod_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_CV_fromHiThreat2LowMod_4C, 0)

dwnpopden_TiCV_StaysLowModThreat_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TiCV_StaysLowModThreat_4C, 0)
dwnpopden_TiCV_StaysHiThreat_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TiCV_StaysHiThreat_4C, 0)
dwnpopden_TiCV_fromLowModThreat2Hi_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TiCV_fromLowModThreat2Hi_4C, 0)
dwnpopden_TiCV_fromHiThreat2LowMod_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TiCV_fromHiThreat2LowMod_4C, 0)

dwnpopden_TRnat_StaysLowCapacity_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TRnat_StaysLowCapacity_4C, 0)
dwnpopden_TRnat_StaysModHiCapacity_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TRnat_StaysModHiCapacity_4C, 0)
dwnpopden_TRnat_fromLowCapacity2ModHi_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TRnat_fromLowCapacity2ModHi_4C, 0)
dwnpopden_TRnat_fromModHiCapacity2Low_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TRnat_fromModHiCapacity2Low_4C, 0)

dwnpopden_TReng_StaysLowCapacity_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TReng_StaysLowCapacity_4C, 0)
dwnpopden_TReng_StaysModHiCapacity_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TReng_StaysModHiCapacity_4C, 0)
dwnpopden_TReng_fromLowCapacity2ModHi_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TReng_fromLowCapacity2ModHi_4C, 0)
dwnpopden_TReng_fromModHiCapacity2Low_4C_XWet = np.where(msk_FutClim_4C_XWet > 0, dwnpop_TReng_fromModHiCapacity2Low_4C, 0)

# %% [markdown]
# ## Output Downstream Population Density GeoTIFFs for Map Creation

# %%
outname = out_dir + 'dwnpopden_TiORIG_StaysLowModThreat.tif'
save2File(dwnpopden_TiORIG_StaysLowModThreat[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TiORIG_StaysHiThreat.tif'
save2File(dwnpopden_TiORIG_StaysHiThreat[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TiORIG_fromLowModThreat2Hi.tif'
save2File(dwnpopden_TiORIG_fromLowModThreat2Hi[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TiORIG_fromHiThreat2LowMod.tif'
save2File(dwnpopden_TiORIG_ConH_FutL[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_CV_StaysLowModThreat_2C.tif'
save2File(dwnpopden_CV_StaysLowModThreat_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_CV_StaysHiThreat_2C.tif'
save2File(dwnpopden_CV_StaysHiThreat_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_CV_fromLowModThreat2Hi_2C.tif'
save2File(dwnpopden_CV_fromLowModThreat2Hi_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_CV_fromHiThreat2LowMod_2C.tif'
save2File(dwnpopden_CV_fromHiThreat2LowMod_2C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_CV_StaysLowModThreat_4C.tif'
save2File(dwnpopden_CV_StaysLowModThreat_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_CV_StaysHiThreat_4C.tif'
save2File(dwnpopden_CV_StaysHiThreat_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_CV_fromLowModThreat2Hi_4C.tif'
save2File(dwnpopden_CV_fromLowModThreat2Hi_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_CV_fromHiThreat2LowMod_4C.tif'
save2File(dwnpopden_CV_fromHiThreat2LowMod_4C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_TiCV_StaysLowModThreat_2C.tif'
save2File(dwnpopden_TiCV_StaysLowModThreat_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TiCV_StaysHiThreat_2C.tif'
save2File(dwnpopden_TiCV_StaysHiThreat_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TiCV_fromLowModThreat2Hi_2C.tif'
save2File(dwnpopden_TiCV_fromLowModThreat2Hi_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TiCV_fromHiThreat2LowMod_2C.tif'
save2File(dwnpopden_TiCV_fromHiThreat2LowMod_2C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_TiCV_StaysLowModThreat_4C.tif'
save2File(dwnpopden_TiCV_StaysLowModThreat_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TiCV_StaysHiThreat_4C.tif'
save2File(dwnpopden_TiCV_StaysHiThreat_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TiCV_fromLowModThreat2Hi_4C.tif'
save2File(dwnpopden_TiCV_fromLowModThreat2Hi_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TiCV_fromHiThreat2LowMod_4C.tif'
save2File(dwnpopden_TiCV_fromHiThreat2LowMod_4C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_TRnat_StaysLowCapacity_2C.tif'
save2File(dwnpopden_TRnat_StaysLowCapacity_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TRnat_StaysModHiCapacity_2C.tif'
save2File(dwnpopden_TRnat_StaysModHiCapacity_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TRnat_fromLowCapacity2ModHi_2C.tif'
save2File(dwnpopden_TRnat_fromLowCapacity2ModHi_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TRnat_fromModHiCapacity2Low_2C.tif'
save2File(dwnpopden_TRnat_fromModHiCapacity2Low_2C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_TRnat_StaysLowCapacity_4C.tif'
save2File(dwnpopden_TRnat_StaysLowCapacity_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TRnat_StaysModHiCapacity_4C.tif'
save2File(dwnpopden_TRnat_StaysModHiCapacity_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TRnat_fromLowCapacity2ModHi_4C.tif'
save2File(dwnpopden_TRnat_fromLowCapacity2ModHi_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TRnat_fromModHiCapacity2Low_4C.tif'
save2File(dwnpopden_TRnat_fromModHiCapacity2Low_4C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_TReng_StaysLowCapacity_2C.tif'
save2File(dwnpopden_TReng_StaysLowCapacity_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TReng_StaysModHiCapacity_2C.tif'
save2File(dwnpopden_TReng_StaysModHiCapacity_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TReng_fromLowCapacity2ModHi_2C.tif'
save2File(dwnpopden_TReng_fromLowCapacity2ModHi_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TReng_fromModHiCapacity2Low_2C.tif'
save2File(dwnpopden_TReng_fromModHiCapacity2Low_2C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_TReng_StaysLowCapacity_4C.tif'
save2File(dwnpopden_TReng_StaysLowCapacity_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TReng_StaysModHiCapacity_4C.tif'
save2File(dwnpopden_TReng_StaysModHiCapacity_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TReng_fromLowCapacity2ModHi_4C.tif'
save2File(dwnpopden_TReng_fromLowCapacity2ModHi_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TReng_fromModHiCapacity2Low_4C.tif'
save2File(dwnpopden_TReng_fromModHiCapacity2Low_4C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_CV2020_low.tif'
save2File(dwnpopden_CV2020_low[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_CV' + str(year_fut) + '_2C_low.tif'
save2File(dwnpopden_CVyear_fut_2C_low[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_CV' + str(year_fut) + '_4C_low.tif'
save2File(dwnpopden_CVyear_fut_4C_low[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_Ti2020_low.tif'
save2File(dwnpopden_Ti2020_low[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_Ti' + str(year_fut) + '_2C_low.tif'
save2File(dwnpopden_Tiyear_fut_2C_low[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_Ti' + str(year_fut) + '_4C_low.tif'
save2File(dwnpopden_Tiyear_fut_4C_low[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_TRnat2020_low.tif'
save2File(dwnpopden_TRnat2020_low[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TRnat' + str(year_fut) + '_2C_low.tif'
save2File(dwnpopden_TRnatyear_fut_2C_low[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TRnat' + str(year_fut) + '_4C_low.tif'
save2File(dwnpopden_TRnatyear_fut_4C_low[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_TReng2020_low.tif'
save2File(dwnpopden_TReng2020_low[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TReng' + str(year_fut) + '_2C_low.tif'
save2File(dwnpopden_TRengyear_fut_2C_low[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TReng' + str(year_fut) + '_4C_low.tif'
save2File(dwnpopden_TRengyear_fut_4C_low[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_CV2020_mod.tif'
save2File(dwnpopden_CV2020_mod[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_CV' + str(year_fut) + '_2C_mod.tif'
save2File(dwnpopden_CVyear_fut_2C_mod[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_CV' + str(year_fut) + '_4C_mod.tif'
save2File(dwnpopden_CVyear_fut_4C_mod[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_Ti2020_mod.tif'
save2File(dwnpopden_Ti2020_mod[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_Ti' + str(year_fut) + '_2C_mod.tif'
save2File(dwnpopden_Tiyear_fut_2C_mod[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_Ti' + str(year_fut) + '_4C_mod.tif'
save2File(dwnpopden_Tiyear_fut_4C_mod[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_TRnat2020_mod.tif'
save2File(dwnpopden_TRnat2020_mod[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TRnat' + str(year_fut) + '_2C_mod.tif'
save2File(dwnpopden_TRnatyear_fut_2C_mod[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TRnat' + str(year_fut) + '_4C_mod.tif'
save2File(dwnpopden_TRnatyear_fut_4C_mod[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_TReng2020_mod.tif'
save2File(dwnpopden_TReng2020_mod[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TReng' + str(year_fut) + '_2C_mod.tif'
save2File(dwnpopden_TRengyear_fut_2C_mod[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TReng' + str(year_fut) + '_4C_mod.tif'
save2File(dwnpopden_TRengyear_fut_4C_mod[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_CV2020_high.tif'
save2File(dwnpopden_CV2020_high[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_CV' + str(year_fut) + '_2C_high.tif'
save2File(dwnpopden_CVyear_fut_2C_high[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_CV' + str(year_fut) + '_4C_high.tif'
save2File(dwnpopden_CVyear_fut_4C_high[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpop_Ti2020_high.tif'
save2File(dwnpop_Ti2020_high[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_Ti2020_high.tif'
save2File(dwnpopden_Ti2020_high[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_Ti' + str(year_fut) + '_2C_high.tif'
save2File(dwnpopden_Tiyear_fut_2C_high[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_Ti' + str(year_fut) + '_4C_high.tif'
save2File(dwnpopden_Tiyear_fut_4C_high[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_TRnat2020_high.tif'
save2File(dwnpopden_TRnat2020_high[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TRnat' + str(year_fut) + '_2C_high.tif'
save2File(dwnpopden_TRnatyear_fut_2C_high[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TRnat' + str(year_fut) + '_4C_high.tif'
save2File(dwnpopden_TRnatyear_fut_4C_high[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'dwnpopden_TReng2020_high.tif'
save2File(dwnpopden_TReng2020_high[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TReng' + str(year_fut) + '_2C_high.tif'
save2File(dwnpopden_TRengyear_fut_2C_high[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'dwnpopden_TReng' + str(year_fut) + '_4C_high.tif'
save2File(dwnpopden_TRengyear_fut_4C_high[:, :], outname, nrows6m, ncols6m, geotr6m)

# %% [markdown]
# ## Output Future +2C and +4C GeoTIFFs

# %%
outname = out_dir + 'Ti_ClimVul_2005_InterIntra.tif'
save2File(Ti_ClimVul_2005[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TRnat_ClimVul_2005_InterIntra.tif'
save2File(TRnat_ClimVul_2005[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TReng_ClimVul_2005_InterIntra.tif'
save2File(TReng_ClimVul_2005[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'Ti_ClimVul_2005_InterIntra_CDF.tif'
save2File(Ti_ClimVul_2005_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TRnat_ClimVul_2005_InterIntra_CDF.tif'
save2File(TRnat_ClimVul_2005_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TReng_ClimVul_2005_InterIntra_CDF.tif'
save2File(TReng_ClimVul_2005_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'Ti_ClimVul_' + str(year_fut) + '_2C_InterIntra.tif'
save2File(Ti_ClimVul_year_fut_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TRnat_ClimVul_' + str(year_fut) + '_2C_InterIntra.tif'
save2File(TRnat_ClimVul_year_fut_2C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TReng_ClimVul_' + str(year_fut) + '_2C_InterIntra.tif'
save2File(TReng_ClimVul_year_fut_2C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'Ti_ClimVul_' + str(year_fut) + '_2C_InterIntra_CDF.tif'
save2File(Ti_ClimVul_year_fut_2C_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TRnat_ClimVul_' + str(year_fut) + '_2C_InterIntra_CDF.tif'
save2File(TRnat_ClimVul_year_fut_2C_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TReng_ClimVul_' + str(year_fut) + '_2C_InterIntra_CDF.tif'
save2File(TReng_ClimVul_year_fut_2C_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'Ti_ClimVul_2005_InterIntra.tif'
save2File(Ti_ClimVul_2005[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TRnat_ClimVul_2005_InterIntra.tif'
save2File(TRnat_ClimVul_2005[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TReng_ClimVul_2005_InterIntra.tif'
save2File(TReng_ClimVul_2005[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'Ti_ClimVul_2005_InterIntra_CDF.tif'
save2File(Ti_ClimVul_2005_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TRnat_ClimVul_2005_InterIntra_CDF.tif'
save2File(TRnat_ClimVul_2005_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TReng_ClimVul_2005_InterIntra_CDF.tif'
save2File(TReng_ClimVul_2005_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'Ti_ClimVul_' + str(year_fut) + '_4C_InterIntra.tif'
save2File(Ti_ClimVul_year_fut_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TRnat_ClimVul_' + str(year_fut) + '_4C_InterIntra.tif'
save2File(TRnat_ClimVul_year_fut_4C[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TReng_ClimVul_' + str(year_fut) + '_4C_InterIntra.tif'
save2File(TReng_ClimVul_year_fut_4C[:, :], outname, nrows6m, ncols6m, geotr6m)

outname = out_dir + 'Ti_ClimVul_' + str(year_fut) + '_4C_InterIntra_CDF.tif'
save2File(Ti_ClimVul_year_fut_4C_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TRnat_ClimVul_' + str(year_fut) + '_4C_InterIntra_CDF.tif'
save2File(TRnat_ClimVul_year_fut_4C_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
outname = out_dir + 'TReng_ClimVul_' + str(year_fut) + '_4C_InterIntra_CDF.tif'
save2File(TReng_ClimVul_year_fut_4C_CDF[:, :], outname, nrows6m, ncols6m, geotr6m)
